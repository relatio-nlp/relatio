# %% [markdown]
# ### Settings and Libraries

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

from collections import Counter
from sklearn.cluster import KMeans

import numpy as np 
from numpy.linalg import norm

from typing import Dict, List, NamedTuple, Optional, Tuple, Union
import numpy as np
from copy import deepcopy

import gensim.downloader as api
#model = api.load("glove-wiki-gigaword-300")

# %% [markdown]
# ### All functions

# %%
UsedRoles = {'roles_considered': ['ARGO', 'B-V', 'B-ARGM-NEG', 'B-ARGM-MOD', 'ARG1', 'ARG2'],
             'roles_with_embeddings': ['ARGO', 'ARG1', 'ARG2'],
             'roles_with_entities': ['ARGO', 'ARG1', 'ARG2']}

# %%
import sys
sys.path.append('../code')


# Utils
#..................................................................................................................
#..................................................................................................................


def split_into_sentences(
    docs: List[str]
) -> List[str]:
    
    """
    
    A function that splits a list of documents into sentences (using the SpaCy sentence splitter).
    
    Args:
        docs: list of docs
        
    Returns:
        List of sentences
        
    """
    
    sentences = []
    doc_indices = []
    
    for index, doc in enumerate(docs):
        for sent in nlp(doc).sents:
            sent = str(sent)
            sentences = sentences + [sent]
            doc_indices = doc_indices + [index]
    
    return doc_indices, sentences


from utils import preprocess


# Semantic Role Labeling
#..................................................................................................................
#..................................................................................................................

# link to choose the SRL model 
# https://storage.googleapis.com/allennlp-public-models/YOUR-PREFERRED-MODEL

# Would be nice to track the semantic role labeling's progress (given how long it takes) +
# code needs to be refactored (remove modals = True)

# Require of the user a model path and the text data, that's all.

from semantic_role_labeling import SRL, extract_roles, extract_role_per_sentence, postprocess_roles


# Named Entity Recognition
#..................................................................................................................
#..................................................................................................................


def mine_entities(
    sentences: List[str],
    ent_labels: Optional[List[str]] = ['PERSON', 'NORP', 'ORG', 'GPE', 'EVENT']
) -> List[Tuple[str, int]]:
    
    """
    
    A function that goes through sentences and counts named entities found in the corpus.
    
    Args:
        sentences: list of sentences
        ent_labels: list of entity labels to be considered (see SPaCy documentation)
        
    Returns:
        List of tuples with the named entity and its associated frequency on the corpus
    
    """

    entities_all = []

    for sentence in sentences:
        sentence = nlp(sentence)
        for ent in sentence.ents:
            if ent.label_ in ent_labels:
                entity = [ent.text]
                entities_all = entity + entities_all

    entities_all = preprocess(entities_all) 

    entity_counts = Counter(entities_all)
    entities_sorted = sorted(entity_counts.items(), key=lambda x: x[1], reverse=True)

    return entities_sorted


def pick_top_entities(
    entities_sorted: List[Tuple[str,int]],
    top_n: Optional[int] = 0
) -> List[str]:
   
    """
    
    A function that returns the top n most frequent named entities in the corpus.
    
    Args:
        entities_sorted: list of tuples (named_entity, frequency)
        top_n: number of named entities to keep (default is top 10% and is specified with top_n = 0)
        
    Returns:
        List of most frequent named entities
    
    """
    
    if top_n == 0:
        top_n = round(len(entities_sorted)/10)
    
    entities = []

    for entity in entities_sorted:
        entities = entities + [entity[0]]
    
    return entities[0:top_n]


def is_subsequence(
    v2: list, 
    v1: list
) -> bool:
    
    """
    
    Check whether v2 is a subsequence of v1.
    
    Args:
        v2/v1: lists of elements
        
    Returns:
        a boolean
    
    Example:
        >>> v1 = ['the', 'united', 'states', 'of', 'america']\n
        ... v2 = ['united', 'states', 'of', 'europe']\n
        ... is_subsequence(v2,v1)
        False
    
    """
    it = iter(v1)
    return all(c in it for c in v2) 


def map_entities(
    statements: List[dict],
    entities: list,
    UsedRoles: dict
) -> Tuple[dict, List[dict]]:
    
    """
    
    A function that goes through statements and identifies pre-defined named entities within postprocessed semantic roles.
    
    Args:
        statements: list of dictionaries of postprocessed semantic roles
        entities: user-defined list of named entities 
        roles: a list of roles with named entities (default = ARG0 and ARG1)
        UsedRoles: dict with the specifics of the pipeline for each role
        
    Returns:
        entity_index: dictionary containing statements indices with entities for each role
        roles_copy: new list of postprocessed semantic roles (without the named entities mined since they will not be embedded)
    
    """
    
    roles = UsedRoles['roles_with_entities']
    
    entity_index = {role:{entity:np.asarray([], dtype=int) for entity in entities} for role in roles}
    
    roles_copy = deepcopy(statements)
    
    for i, statement in enumerate(statements):
        for role, tokens in statements[i].items():
            if role in roles:
                for entity in entities:
                    if is_subsequence(entity.split(), tokens)  == True: 
                        entity_index[role][entity] = np.append(entity_index[role][entity], [i]) 
                        roles_copy[i][role] = []
    
    return entity_index, roles_copy


# Vectors and Clustering
#..................................................................................................................
#..................................................................................................................

def count_words(
    sentences: List[str]
) -> dict:
    
    """
    
    A function that computes word frequencies in a list of sentences.
    
    Args:
        sentences: list of sentences
        
    Returns:
        A dictionary {"word": frequency}
    
    """
    
    words = []
    
    for sentence in sentences:
        words = words + sentence.split()

    word_count_dict = dict(Counter(words))
    
    return word_count_dict


def compute_sif_weights(
    word_count_dict: dict,
    alpha: Optional[float] = 0.001
) -> dict:
    
    """
    
    A function that computes SIF weights based on word frequencies.
    
    Args:
        word_count_dict: a dictionary {"word": frequency}
        alpha: regularization parameter (see original paper)
        
    Returns:
        A dictionary {"word": SIF weight}
    
    """
    
    sif_dict = {}
    
    for word, count in word_count_dict.items():
        sif_dict[word] = alpha / (alpha + count)

    return sif_dict


class USE:
    def __init__(self, path: str):
        self._embed = hub.load(path)

    def __call__(self, tokens: List[str]) -> np.ndarray:
        return self._embed([" ".join(tokens)]).numpy()[0]


class SIF_word2vec:
    def __init__(
        self, path: str, sentences = List[str], alpha: Optional[float] = 0.001, normalize: bool = True
    ):

        self._model = Word2Vec.load(path)

        self._word_count_dict = count_words(sentences)
        
        self._sif_dict = compute_sif_weights(self._word_count_dict, alpha)
        
        self._vocab = self._model.wv.vocab

        self._normalize = normalize

    def __call__(self, tokens: List[str]):
        res = np.mean(
            [self._sif_dict[token] * self._model.wv[token] for token in tokens], axis=0
        )
        if self._normalize:
            res = res / norm(res)  
        return res
    

class SIF_keyed_vectors:
    def __init__(
        self, path: str, sentences = List[str], alpha: Optional[float] = 0.001, normalize: bool = True
    ):

        self._model = api.load(path)

        self._word_count_dict = count_words(sentences)
        
        self._sif_dict = compute_sif_weights(self._word_count_dict, alpha)
        
        self._vocab = self._model.vocab

        self._normalize = normalize

    def __call__(self, tokens: List[str]):
        res = np.mean(
            [self._sif_dict[token] * self._model[token] for token in tokens], axis=0
        )
        if self._normalize:
            res = res / norm(res)  
        return res


def get_vector(
    tokens: List[str],
    model: Union[USE, SIF_word2vec, SIF_keyed_vectors]
):
    
    """
    
    A function that computes an embedding vector for a list of tokens.
    
    Args:
        tokens: list of string tokens to embed
        model: trained embedding model 
        (e.g. either Universal Sentence Encoders, a full gensim Word2Vec model or gensim Keyed Vectors)
        
    Returns:
        A two-dimensional numpy array (1,dimension of the embedding space)
    
    """
    
    if not isinstance(model, (USE, SIF_word2vec, SIF_keyed_vectors)):
        raise TypeError("Union[USE, SIF_Word2Vec, SIF_keyed_vectors]")
    
    if isinstance(model, SIF_word2vec) or isinstance(model, SIF_keyed_vectors): 
        if not tokens:
            res = None
        elif any(token not in model._sif_dict for token in tokens):
            res = None
        elif any(token not in model._vocab for token in tokens): 
            res = None 
        else:
            res = model(tokens)
            res = np.array([res])
    else:
            res = model(tokens)
            res = np.array([res])
        
    return res


from utils import get_role_counts


def train_cluster_model(
    postproc_roles,
    model: Union[USE, SIF_word2vec, SIF_keyed_vectors],
    n_clusters,
    UsedRoles = dict,
    random_state: Optional[int] = 0
):
    
    """
    
    A function to train a kmeans model on the corpus.
    
    Args:
        postproc_roles: list of statements
        model: trained embedding model 
        (e.g. either Universal Sentence Encoders, a full gensim Word2Vec model or gensim Keyed Vectors)
        n_clusters: number of clusters
        UsedRoles: dict with the specifics of the pipeline for each role
        random_state: seed for replication (default is 0)
        
    Returns:
        A sklearn kmeans model
    
    """
    
    roles = UsedRoles['roles_with_embeddings']
    
    role_counts = get_role_counts(postproc_roles, roles = roles) 

    role_counts = [role.split() for role in list(role_counts)]

    vecs = None
    for role in role_counts:
        if vecs is None:
            vecs = get_vector(role, model)
        else:
            temp = get_vector(role, model)
            if temp is not None:
                vecs = np.concatenate((vecs, temp), axis=0)
        
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state).fit(vecs)
    
    return kmeans


def get_clusters(
    postproc_roles: List[dict],
    model: Union[USE, SIF_word2vec, SIF_keyed_vectors],
    kmeans,
    UsedRoles = dict
) -> List[dict]:
    
    """
    
    A function which predicts clusters based on a pre-trained kmeans model.
    
    Args:
        postproc_roles: list of statements
        model: trained embedding model 
        (e.g. either Universal Sentence Encoders, a full gensim Word2Vec model or gensim Keyed Vectors)
        kmeans = a pre-trained sklearn kmeans model
        UsedRoles: dict with the specifics of the pipeline for each role
        
    Returns:
        A list of dictionaries with the predicted cluster for each role
    
    """

    roles = UsedRoles['roles_with_embeddings']
    
    clustering_res = []
    
    for statement in postproc_roles:
        temp = {}
        for role, tokens in statement.items():
            if role in roles:
                vec = get_vector(tokens, model)
                if vec is not None:
                    clu = kmeans.predict(vec)
                    temp[role] = int(clu)
        clustering_res = clustering_res + [temp]

    return clustering_res


def label_clusters_most_freq(
    clustering_res: List[dict],
    postproc_roles: List[dict]
) -> dict:
    
    """
    
    A function which labels clusters by their most frequent term.
    
    Args:
        clustering_res: list of dictionaries with the predicted cluster for each role
        postproc_roles: list of statements
        
    Returns:
        A dictionary associating to each cluster number a label (e.g. the most frequent term in this cluster)
    
    """

    temp = {}
    labels = {}

    for i,statement in enumerate(clustering_res):
        for role, cluster in statement.items():
            tokens = ' '.join(postproc_roles[i][role])
            cluster_num = cluster
            if cluster_num not in temp:
                temp[cluster_num] = [tokens]
            else:
                temp[cluster_num] = temp[cluster_num] + [tokens]

    for cluster_num, tokens in temp.items():
        token_counts = Counter(tokens)
        token_freq = sorted(token_counts.items(), key=lambda x: x[1], reverse=True)
        most_freq_token = token_freq[0][0]
        labels[cluster_num] = most_freq_token

    return labels


# Wrappers
#..................................................................................................................
#..................................................................................................................


def build_narrative_model(
    srl_res: List[dict],
    sentences: List[str],
    embeddings_type = str,
    embeddings_path = str,
    UsedRoles = dict
):
    
    if embeddings_type not in ['gensim_keyed_vectors', 'gensim_full_model', 'USE']:
        raise TypeError("Only three types of embeddings accepted: gensim_keyed_vectors, gensim_full_model, USE")

    # Process SRL
    print('Processing srl output...')
    
    roles, sentence_index = extract_roles(srl_res, start = 0)
    postproc_roles = postprocess_roles(roles)
    
    # Named Entities
    print('Processing named entities...')

    entities_sorted = mine_entities(sentences)
    entities = pick_top_entities(entities_sorted)
    entity_index, postproc_roles_without_entities = map_entities(statements = postproc_roles,
                                                                 entities = entities,
                                                                 UsedRoles = UsedRoles)
    
    # Embeddings and clustering
    print('Loading embeddings model...')
    sentences = preprocess(sentences)
    
    if embeddings_type == 'gensim_keyed_vectors':
        model = SIF_keyed_vectors(path = embeddings_path, sentences = sentences)
    if embeddings_type == 'gensim_full_model':
        model = SIF_word2vec(path = embeddings_path, sentences = sentences)
    if embeddings_type == 'USE':
        model = USE(path = embeddings_path)
    
    print('Clustering remaining arguments...')
    kmeans = train_cluster_model(postproc_roles_without_entities, 
                                 model, 
                                 n_clusters = 5, 
                                 UsedRoles=UsedRoles)
    
    clustering_res = get_clusters(postproc_roles_without_entities, 
                                  model, 
                                  kmeans, 
                                  UsedRoles=UsedRoles)
    
    labels = label_clusters_most_freq(clustering_res=clustering_res, 
                                      postproc_roles=postproc_roles_without_entities)
    
    # Wrap up 
    narrative_model = {}
    narrative_model['entities'] = entities
    narrative_model['embeddings_model'] = model
    narrative_model['cluster_model'] = kmeans
    narrative_model['cluster_labels'] = labels
    narrative_model['UsedRoles'] = UsedRoles
                    
    return narrative_model
 
    
def get_narratives(
    srl_res: List[dict],
    doc_index: List[int],
    narrative_model: dict
):
    
    """
    
    A wrapper function to obtain the final mined narratives.
    
    Args:
        srl_res: sentences labeled with their semantic roles 
        doc_index: list of indices to keep track of original documents
        UsedRoles: dict with the specifics of the pipeline for each role
        
    Returns:
        A list of dictionaries with the mined narratives.
    
    """

    final_statements = []    
    
    # Process SRL
    print('Processing srl output...')
    roles, sentence_index = extract_roles(srl_res)
    postproc_roles = postprocess_roles(roles)
    
    # Named Entities
    print('Processing named entities...')
    entity_index, postproc_roles_without_entities = map_entities(statements = postproc_roles,
                                                                 entities = narrative_model['entities'],
                                                                 UsedRoles = narrative_model['UsedRoles'])
    
    # Embeddings
    print('Clustering remaining arguments...')
    clustering_res = get_clusters(postproc_roles_without_entities, 
                                  narrative_model['embeddings_model'], 
                                  narrative_model['cluster_model'], 
                                  UsedRoles=narrative_model['UsedRoles'])
        
    # Raw statements
    for statement in postproc_roles:
        temp = {}
        for role, tokens in statement.items():
            name = role + '-RAW'
            if type(tokens)!=bool:
                temp[name] = ' '.join(tokens)
            else:
                temp[name] = tokens
        final_statements = final_statements + [temp]
    
    # Clusters
    for i,statement in enumerate(clustering_res):
        for role, cluster in statement.items():
            final_statements[i][role] = narrative_model['cluster_labels'][cluster]
       
    # Named entities
    for role in narrative_model['UsedRoles']['roles_with_entities']: 
        for token, indices in entity_index[role].items():
            for index in indices:
                final_statements[index][role] = token
      
    # Original sentence
    for i,index in enumerate(sentence_index):
        final_statements[i]['sentence'] = index
        
    # Original documents
    for i,index in enumerate(doc_index):
        final_statements[i]['doc'] = index
                
    return final_statements

# %% [markdown]
# ### Pipeline in Action

# %%
import pandas as pd

df = pd.read_csv('trump_tweets.csv')
splitted_text = df['text'].str.split()
indices = [i for i,value in enumerate(splitted_text) if 'RT' not in value]
df = df.loc[indices]
df['text'] = df['text'].str.replace(r"http\S+", "")
df['text'] = df['text'].str.replace(r"@\S+", "")
df = df[df['text'].str.strip() != '']
df = pd.DataFrame(list(zip(df.index, df.text)), columns = ['id', 'doc'])

docs = list(df['doc'])
# Out:
# /home/germain/miniconda3/envs/narrative-nlp/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   import sys
# /home/germain/miniconda3/envs/narrative-nlp/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
doc_index, sentences = split_into_sentences(docs[0:100])

# %%
srl = SRL("../srl-model-2018.05.25.tar.gz")
srl_res = srl(sentences=sentences, batch_size = 20)

# %%
narrative_model = build_narrative_model(srl_res = srl_res, 
                                        embeddings_type = "gensim_keyed_vectors",
                                        embeddings_path = "glove-wiki-gigaword-300",
                                        sentences = sentences, 
                                        UsedRoles = UsedRoles)
# Out:
# Processing srl output...
# Processing named entities...
# Loading embeddings model...
# 100%|██████████| 359/359 [00:00<00:00, 984153.68it/s]
# Clustering remaining arguments...

# %%
get_narratives(srl_res = srl_res, doc_index = doc_index, narrative_model = narrative_model)
# Out:
# Processing srl output...
# Processing named entities...
# Clustering remaining arguments...
# [{'ARGO-RAW': 'republicans and democrats',
#   'ARG1-RAW': 'our economic problems',
#   'B-V-RAW': 'created',
#   'ARG1': 'us',
#   'ARGO': 'democrats',
#   'sentence': 0,
#   'doc': 0},
#  {'ARG1-RAW': 'i',
#   'ARG2-RAW': 'thrilled to be back in the great city of charlotte north carolina with thousands of hardworking american patriots who love our country cherish our values respect our laws and always put america first',
#   'B-V-RAW': 'was',
#   'ARG1': 'we',
#   'ARG2': 'country',
#   'sentence': 1,
#   'doc': 1},
#  {'ARG1-RAW': 'i',
#   'ARG2-RAW': 'to be back in the great city of charlotte north carolina with thousands of hardworking american patriots who love our country cherish our values respect our laws and always put america first',
#   'B-V-RAW': 'thrilled',
#   'ARG1': 'we',
#   'ARG2': 'country',
#   'sentence': 1,
#   'doc': 1},
#  {'ARG1-RAW': 'i',
#   'ARG2-RAW': 'back in the great city of charlotte north carolina',
#   'B-V-RAW': 'be',
#   'ARG1': 'we',
#   'ARG2': 'hardworking american patriots who',
#   'sentence': 1,
#   'doc': 1},
#  {'ARGO-RAW': 'american patriots',
#   'B-V-RAW': 'hardworking',
#   'ARGO': 'hardworking american patriots who',
#   'sentence': 1,
#   'doc': 2},
#  {'ARGO-RAW': 'hardworking american patriots who',
#   'ARG1-RAW': 'our country',
#   'B-V-RAW': 'love',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'country',
#   'sentence': 1,
#   'doc': 2},
#  {'ARGO-RAW': 'hardworking american patriots who',
#   'ARG1-RAW': 'our values',
#   'B-V-RAW': 'cherish',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'us',
#   'sentence': 1,
#   'doc': 2},
#  {'ARGO-RAW': 'hardworking american patriots who',
#   'ARG1-RAW': 'our laws',
#   'B-V-RAW': 'respect',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'us',
#   'sentence': 1,
#   'doc': 3},
#  {'ARGO-RAW': 'hardworking american patriots who',
#   'ARG1-RAW': 'america first',
#   'B-V-RAW': 'put',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'us',
#   'sentence': 1,
#   'doc': 4},
#  {'ARG1-RAW': 'you',
#   'ARG2-RAW': 'for a wonderful evening',
#   'B-V-RAW': 'thank',
#   'ARG1': 'we',
#   'ARG2': 'we',
#   'sentence': 2,
#   'doc': 5},
#  {'sentence': 3, 'doc': 6},
#  {'ARG1-RAW': 'the unsolicited mail in ballot scam',
#   'ARG2-RAW': 'a major threat to our democracy amp',
#   'B-V-RAW': 'is',
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'ARG2': 'us',
#   'sentence': 4,
#   'doc': 6},
#  {'ARGO-RAW': 'the democrats',
#   'ARG1-RAW': 'it',
#   'B-V-RAW': 'know',
#   'ARG1': 'we',
#   'ARGO': 'democrats',
#   'sentence': 4,
#   'doc': 6},
#  {'ARGO-RAW': 'almost all recent elections',
#   'ARG1-RAW': 'this system',
#   'B-V-RAW': 'using',
#   'ARGO': 'us',
#   'ARG1': 'us',
#   'sentence': 5,
#   'doc': 7},
#  {'ARG1-RAW': 'far fewer ballots',
#   'B-V-RAW': 'count',
#   'ARG1': 'us',
#   'sentence': 5,
#   'doc': 7},
#  {'ARG1-RAW': 'almost all recent elections using this system even though much smaller amp with far fewer ballots to count',
#   'ARG2-RAW': 'being a disaster',
#   'B-V-RAW': 'ended',
#   'ARG1': 'us',
#   'ARG2': 'us',
#   'sentence': 5,
#   'doc': 7},
#  {'ARG1-RAW': 'almost all recent elections using this system even though much smaller amp with far fewer ballots to count',
#   'ARG2-RAW': 'a disaster',
#   'B-V-RAW': 'being',
#   'ARG1': 'us',
#   'ARG2': 'us',
#   'sentence': 5,
#   'doc': 7},
#  {'ARG1-RAW': 'ballots',
#   'B-V-RAW': 'missing',
#   'ARG1': 'ballots',
#   'sentence': 6,
#   'doc': 7},
#  {'ARG1-RAW': 'a little exercise',
#   'B-V-RAW': 'getting',
#   'ARG1': 'us',
#   'sentence': 7,
#   'doc': 8},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'thank',
#   'ARG1': 'we',
#   'sentence': 8,
#   'doc': 8},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'elise',
#   'ARG1': 'we',
#   'sentence': 8,
#   'doc': 8},
#  {'sentence': 9, 'doc': 8},
#  {'ARG1-RAW': 'the threshold identification of ballots to be even bigger than originally anticipated',
#   'B-V-RAW': 'turning',
#   'ARG1': 'us',
#   'sentence': 10,
#   'doc': 9},
#  {'ARG1-RAW': 'the threshold identification of ballots',
#   'ARG2-RAW': 'even bigger than originally anticipated',
#   'B-V-RAW': 'be',
#   'ARG1': 'ballots',
#   'ARG2': 'us',
#   'sentence': 10,
#   'doc': 10},
#  {'B-V-RAW': 'anticipated', 'sentence': 10, 'doc': 10},
#  {'ARG1-RAW': 'a very large number of ballots',
#   'B-V-RAW': 'impacted',
#   'ARG1': 'us',
#   'sentence': 11,
#   'doc': 11},
#  {'B-V-RAW': 'stay', 'sentence': 12, 'doc': 11},
#  {'sentence': 13, 'doc': 12},
#  {'ARGO-RAW': 'i',
#   'B-V-RAW': 'running',
#   'ARGO': 'we',
#   'sentence': 14,
#   'doc': 12},
#  {'sentence': 15, 'doc': 12},
#  {'ARG1-RAW': 'it',
#   'ARG2-RAW': 'worse',
#   'B-V-RAW': 'get',
#   'ARG1': 'we',
#   'ARG2': 'we',
#   'sentence': 16,
#   'doc': 13},
#  {'ARG1-RAW': 'it',
#   'ARG2-RAW': 'sustainable for our county',
#   'B-V-RAW': 'is',
#   'B-ARGM-NEG-RAW': True,
#   'ARG1': 'we',
#   'ARG2': 'us',
#   'sentence': 17,
#   'doc': 13},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'china',
#   'ARG1-RAW': 'us',
#   'B-V-RAW': 'own',
#   'ARGO': 'us',
#   'ARG1': 'us',
#   'sentence': 17,
#   'doc': 13},
#  {'sentence': 18, 'doc': 14},
#  {'ARGO-RAW': 'sudan',
#   'ARG1-RAW': 'to a peace and normalization agreement with israel',
#   'B-V-RAW': 'agreed',
#   'ARGO': 'us',
#   'ARG1': 'us',
#   'sentence': 19,
#   'doc': 14},
#  {'ARGO-RAW': 'that three arab countries',
#   'ARG1-RAW': 'so',
#   'B-V-RAW': 'done',
#   'ARGO': 'us',
#   'ARG1': 'we',
#   'sentence': 20,
#   'doc': 15},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARG1-RAW': 'more',
#   'B-V-RAW': 'follow',
#   'ARG1': 'us',
#   'sentence': 21,
#   'doc': 15},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'thank',
#   'ARG1': 'we',
#   'sentence': 22,
#   'doc': 16},
#  {'sentence': 23, 'doc': 17},
#  {'sentence': 24, 'doc': 17},
#  {'ARG1-RAW': 'nevada to be a cesspool of fake votes',
#   'B-V-RAW': 'turning',
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'sentence': 25,
#   'doc': 18},
#  {'ARG1-RAW': 'nevada',
#   'ARG2-RAW': 'a cesspool of fake votes',
#   'B-V-RAW': 'be',
#   'ARG1': 'ballots',
#   'ARG2': 'the unsolicited mail in ballot scam',
#   'sentence': 25,
#   'doc': 18},
#  {'ARG1-RAW': 'things that when released will be absolutely shocking',
#   'B-V-RAW': 'finding',
#   'ARG1': 'we',
#   'sentence': 26,
#   'doc': 18},
#  {'B-V-RAW': 'released', 'sentence': 26, 'doc': 19},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARG1-RAW': 'things that',
#   'ARG2-RAW': 'absolutely shocking',
#   'B-V-RAW': 'be',
#   'ARG1': 'we',
#   'ARG2': 'we',
#   'sentence': 26,
#   'doc': 19},
#  {'ARGO-RAW': 'wisconsin',
#   'ARG1-RAW': 'very good',
#   'B-V-RAW': 'looking',
#   'ARG1': 'we',
#   'ARGO': 'wisconsin',
#   'sentence': 27,
#   'doc': 20},
#  {'ARG1-RAW': 'a little time',
#   'B-V-RAW': 'needs',
#   'ARG1': 'we',
#   'sentence': 28,
#   'doc': 20},
#  {'B-ARGM-MOD-RAW': 'will', 'B-V-RAW': 'happen', 'sentence': 29, 'doc': 21},
#  {'ARG1-RAW': 'nobody',
#   'B-V-RAW': 'showing',
#   'ARG1': 'we',
#   'sentence': 30,
#   'doc': 21},
#  {'ARG1-RAW': 'speeches',
#   'ARG2-RAW': 'hate',
#   'B-V-RAW': 'laced',
#   'ARG1': 'ballots',
#   'ARG2': 'the unsolicited mail in ballot scam',
#   'sentence': 30,
#   'doc': 21},
#  {'sentence': 31, 'doc': 22},
#  {'sentence': 32, 'doc': 23},
#  {'ARGO-RAW': 'pennsylvania',
#   'ARG1-RAW': 'us',
#   'ARG2-RAW': 'from watching much of the ballot count',
#   'B-V-RAW': 'prevented',
#   'ARG1': 'us',
#   'ARG2': 'we',
#   'ARGO': 'pennsylvania',
#   'sentence': 33,
#   'doc': 23},
#  {'ARGO-RAW': 'us',
#   'ARG1-RAW': 'much of the ballot count',
#   'B-V-RAW': 'watching',
#   'ARGO': 'us',
#   'ARG1': 'ballots',
#   'sentence': 33,
#   'doc': 23},
#  {'sentence': 34, 'doc': 23},
#  {'B-V-RAW': 'landed', 'sentence': 35, 'doc': 24},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'see',
#   'ARG1': 'we',
#   'sentence': 36,
#   'doc': 24},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARG1-RAW': 'georgia',
#   'ARG2-RAW': 'a big presidential win',
#   'B-V-RAW': 'be',
#   'ARG2': 'ballots',
#   'ARG1': 'georgia',
#   'sentence': 37,
#   'doc': 24},
#  {'ARG1-RAW': 'it', 'B-V-RAW': 'was', 'ARG1': 'we', 'sentence': 37, 'doc': 25},
#  {'ARG1-RAW': 'you ohio',
#   'B-V-RAW': 'thank',
#   'ARG1': 'ohio',
#   'sentence': 38,
#   'doc': 26},
#  {'sentence': 39, 'doc': 27},
#  {'ARGO-RAW': 'you',
#   'ARG1-RAW': 'an election',
#   'B-V-RAW': 'certify',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 40,
#   'doc': 27},
#  {'ARG1-RAW': 'the numbers',
#   'B-V-RAW': 'certified',
#   'ARG1': 'us',
#   'sentence': 40,
#   'doc': 27},
#  {'ARG1-RAW': 'the numbers being certified',
#   'ARG2-RAW': 'verifiably wrong',
#   'B-V-RAW': 'are',
#   'ARG1': 'ballots',
#   'ARG2': 'the unsolicited mail in ballot scam',
#   'sentence': 40,
#   'doc': 28},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'you',
#   'ARG1-RAW': 'the real numbers',
#   'B-V-RAW': 'see',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 41,
#   'doc': 28},
#  {'ARGO-RAW': 'republicans',
#   'ARG1-RAW': 'pluses amp minuses',
#   'B-V-RAW': 'have',
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'ARGO': 'republicans',
#   'sentence': 42,
#   'doc': 29},
#  {'ARG1-RAW': 'one thing they never forget',
#   'ARG2-RAW': 'sure',
#   'B-V-RAW': 'is',
#   'ARG1': 'we',
#   'ARG2': 'we',
#   'sentence': 42,
#   'doc': 29},
#  {'ARGO-RAW': 'they',
#   'B-V-RAW': 'forget',
#   'ARGO': 'we',
#   'sentence': 42,
#   'doc': 30},
#  {'ARG2-RAW': 'in ohio',
#   'B-V-RAW': 'be',
#   'ARG2': 'ohio',
#   'sentence': 43,
#   'doc': 30},
#  {'ARG2-RAW': 'for wisconsin',
#   'B-V-RAW': 'leaving',
#   'ARG2': 'wisconsin',
#   'sentence': 43,
#   'doc': 31},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'see',
#   'ARG1': 'we',
#   'sentence': 44,
#   'doc': 32},
#  {'sentence': 45, 'doc': 32},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'unprecedented amounts of voter fraud',
#   'B-V-RAW': 'seen',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 46,
#   'doc': 32},
#  {'sentence': 47, 'doc': 32},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'to thwart the democratic process',
#   'B-V-RAW': 'acting',
#   'B-ARGM-NEG-RAW': True,
#   'ARGO': 'we',
#   'ARG1': 'ballots',
#   'sentence': 48,
#   'doc': 33},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'the democratic process',
#   'B-V-RAW': 'thwart',
#   'ARGO': 'we',
#   'ARG1': 'ballots',
#   'sentence': 48,
#   'doc': 33},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'to protect it',
#   'B-V-RAW': 'acting',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 48,
#   'doc': 34},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'it',
#   'B-V-RAW': 'protect',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 48,
#   'doc': 34},
#  {'sentence': 49, 'doc': 34},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARG1-RAW': 'the “ surrender caucus ” within the republican party',
#   'B-V-RAW': 'go',
#   'sentence': 50,
#   'doc': 35},
#  {'ARG1-RAW': 'of our nation',
#   'B-V-RAW': 'guardians',
#   'ARG1': 'us',
#   'sentence': 50,
#   'doc': 35},
#  {'ARG1-RAW': 'weak and ineffective “ guardians ” of our nation who',
#   'ARG2-RAW': 'willing to accept the certification of fraudulent presidential numbers',
#   'B-V-RAW': 'were',
#   'ARG2': 'ballots',
#   'sentence': 50,
#   'doc': 36},
#  {'ARGO-RAW': 'who',
#   'ARG1-RAW': 'the certification of fraudulent presidential numbers',
#   'B-V-RAW': 'accept',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'ballots',
#   'sentence': 50,
#   'doc': 36},
#  {'sentence': 51, 'doc': 37},
#  {'sentence': 52, 'doc': 37},
#  {'sentence': 53, 'doc': 38},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'thank',
#   'ARG1': 'we',
#   'sentence': 54,
#   'doc': 38},
#  {'ARGO-RAW': 'polls numbers',
#   'ARG1-RAW': 'very strong',
#   'B-V-RAW': 'looking',
#   'ARGO': 'ballots',
#   'ARG1': 'us',
#   'sentence': 55,
#   'doc': 38},
#  {'sentence': 56, 'doc': 39},
#  {'ARG1-RAW': 'massive red wave',
#   'B-V-RAW': 'coming',
#   'ARG1': 'us',
#   'sentence': 57,
#   'doc': 39},
#  {'ARGO-RAW': 'biden',
#   'B-V-RAW': 'lied',
#   'ARGO': 'ballots',
#   'sentence': 58,
#   'doc': 40},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'thank',
#   'ARG1': 'we',
#   'sentence': 59,
#   'doc': 40},
#  {'ARG1-RAW': 'you libertarians',
#   'B-V-RAW': 'thank',
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'sentence': 60,
#   'doc': 40},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'it all done and fast',
#   'B-V-RAW': 'getting',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 61,
#   'doc': 40},
#  {'ARG1-RAW': 'it all',
#   'B-V-RAW': 'done',
#   'ARG1': 'we',
#   'sentence': 61,
#   'doc': 41},
#  {'sentence': 62, 'doc': 41},
#  {'ARG1-RAW': 'the process',
#   'B-V-RAW': 'begun',
#   'ARG1': 'us',
#   'sentence': 63,
#   'doc': 41},
#  {'B-V-RAW': 'happening', 'sentence': 64, 'doc': 42},
#  {'ARG1-RAW': 'to georgia',
#   'B-V-RAW': 'heading',
#   'ARG1': 'georgia',
#   'sentence': 65,
#   'doc': 42},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'see',
#   'ARG1': 'we',
#   'sentence': 66,
#   'doc': 42},
#  {'ARG1-RAW': 'this',
#   'ARG2-RAW': 'good news',
#   'B-V-RAW': 'is',
#   'ARG1': 'we',
#   'ARG2': 'we',
#   'sentence': 67,
#   'doc': 43},
#  {'ARGO-RAW': 'it',
#   'ARG1-RAW': 'i won',
#   'B-V-RAW': 'means',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 67,
#   'doc': 43},
#  {'ARGO-RAW': 'i', 'B-V-RAW': 'won', 'ARGO': 'we', 'sentence': 67, 'doc': 44},
#  {'sentence': 68, 'doc': 44},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'see',
#   'ARG1': 'we',
#   'sentence': 69,
#   'doc': 45},
#  {'sentence': 70, 'doc': 45},
#  {'ARGO-RAW': 'i',
#   'ARG1-RAW': 'the election',
#   'B-V-RAW': 'won',
#   'ARGO': 'we',
#   'ARG1': 'ballots',
#   'sentence': 71,
#   'doc': 46},
#  {'sentence': 72, 'doc': 46},
#  {'sentence': 73, 'doc': 46},
#  {'ARGO-RAW': 'dominion',
#   'ARG1-RAW': 'our election',
#   'B-V-RAW': 'running',
#   'ARGO': 'us',
#   'ARG1': 'us',
#   'sentence': 74,
#   'doc': 47},
#  {'sentence': 75, 'doc': 47},
#  {'sentence': 76, 'doc': 48},
#  {'B-ARGM-MOD-RAW': '’ll',
#   'ARG1-RAW': 'they',
#   'ARG2-RAW': 'back',
#   'B-V-RAW': 'be',
#   'ARG1': 'we',
#   'ARG2': 'we',
#   'sentence': 77,
#   'doc': 49},
#  {'ARGO-RAW': 'they',
#   'ARG1-RAW': 'it',
#   'B-V-RAW': 'do',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 77,
#   'doc': 50},
#  {'ARG1-RAW': 'this',
#   'ARG2-RAW': 'much more then voter and campaign finance suppression',
#   'B-V-RAW': 'is',
#   'ARG1': 'we',
#   'ARG2': 'us',
#   'sentence': 78,
#   'doc': 51},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'thank',
#   'ARG1': 'we',
#   'sentence': 79,
#   'doc': 51},
#  {'sentence': 80, 'doc': 51},
#  {'ARGO-RAW': 'biden',
#   'ARG1-RAW': 'what a terrible thing',
#   'B-V-RAW': 'say',
#   'ARGO': 'ballots',
#   'ARG1': 'we',
#   'sentence': 81,
#   'doc': 52},
#  {'sentence': 82, 'doc': 53},
#  {'ARG1-RAW': 'i',
#   'ARG2-RAW': 'with kelly amp david',
#   'B-V-RAW': 'stand',
#   'ARG1': 'we',
#   'ARG2': 'hardworking american patriots who',
#   'sentence': 83,
#   'doc': 53},
#  {'ARG1-RAW': 'they',
#   'ARG2-RAW': 'both great',
#   'B-V-RAW': 'are',
#   'ARG1': 'we',
#   'ARG2': 'us',
#   'sentence': 84,
#   'doc': 54},
#  {'B-V-RAW': 'landed', 'sentence': 85, 'doc': 54},
#  {'sentence': 86, 'doc': 55},
#  {'sentence': 87, 'doc': 56},
#  {'ARGO-RAW': 'i', 'B-V-RAW': 'said', 'ARGO': 'we', 'sentence': 88, 'doc': 57},
#  {'B-ARGM-MOD-RAW': 'would',
#   'ARGO-RAW': 'the others',
#   'ARG1-RAW': 'a vaccine',
#   'B-V-RAW': 'announce',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'vaccine',
#   'sentence': 88,
#   'doc': 57},
#  {'ARGO-RAW': 'they',
#   'ARG1-RAW': 'the courage to do it before',
#   'B-V-RAW': 'have',
#   'B-ARGM-NEG-RAW': True,
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 88,
#   'doc': 57},
#  {'ARGO-RAW': 'they',
#   'ARG1-RAW': 'it',
#   'B-V-RAW': 'do',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 88,
#   'doc': 58},
#  {'B-ARGM-MOD-RAW': 'should',
#   'ARGO-RAW': 'the',
#   'ARG1-RAW': 'it',
#   'B-V-RAW': 'announced',
#   'ARGO': 'us',
#   'ARG1': 'we',
#   'sentence': 89,
#   'doc': 58},
#  {'ARG1-RAW': 'lives',
#   'B-V-RAW': 'saving',
#   'ARG1': 'hardworking american patriots who',
#   'sentence': 89,
#   'doc': 59},
#  {'sentence': 90, 'doc': 60},
#  {'ARGO-RAW': 'abc wapo',
#   'ARG1-RAW': 'me down points',
#   'B-V-RAW': 'had',
#   'ARG1': 'we',
#   'sentence': 91,
#   'doc': 60},
#  {'ARG1-RAW': 'i', 'B-V-RAW': 'won', 'ARG1': 'we', 'sentence': 91, 'doc': 61},
#  {'ARGO-RAW': 'the polls',
#   'ARG1-RAW': 'us points down',
#   'B-V-RAW': 'had',
#   'ARGO': 'ballots',
#   'ARG1': 'us',
#   'sentence': 92,
#   'doc': 62},
#  {'ARGO-RAW': 'i', 'B-V-RAW': 'won', 'ARGO': 'we', 'sentence': 92, 'doc': 62},
#  {'ARG1-RAW': 'fox news and quinnipiac',
#   'ARG2-RAW': 'wrong on everything',
#   'B-V-RAW': 'were',
#   'ARG1': 'ballots',
#   'ARG2': 'we',
#   'sentence': 93,
#   'doc': 63},
#  {'sentence': 94, 'doc': 63},
#  {'ARG1-RAW': 'nbc wsj',
#   'ARG2-RAW': 'so inaccurate with their polls on me that it really is tampering with an election',
#   'B-V-RAW': 'were',
#   'ARG2': 'we',
#   'sentence': 95,
#   'doc': 63},
#  {'ARG1-RAW': 'it',
#   'ARG2-RAW': 'tampering with an election',
#   'B-V-RAW': 'is',
#   'ARG1': 'we',
#   'ARG2': 'the unsolicited mail in ballot scam',
#   'sentence': 95,
#   'doc': 63},
#  {'ARGO-RAW': 'it',
#   'ARG1-RAW': 'with an election',
#   'B-V-RAW': 'tampering',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 95,
#   'doc': 64},
#  {'ARG1-RAW': 'they',
#   'ARG2-RAW': 'so far off in their polling and in their attempt to suppress that they should be called out for election interference',
#   'B-V-RAW': 'were',
#   'ARG1': 'we',
#   'ARG2': 'us',
#   'sentence': 96,
#   'doc': 64},
#  {'ARG1-RAW': 'that',
#   'B-V-RAW': 'suppress',
#   'ARG1': 'we',
#   'sentence': 96,
#   'doc': 64},
#  {'B-ARGM-MOD-RAW': 'should',
#   'ARG1-RAW': 'they',
#   'ARG2-RAW': 'for election interference',
#   'B-V-RAW': 'called',
#   'ARG1': 'we',
#   'ARG2': 'the unsolicited mail in ballot scam',
#   'sentence': 96,
#   'doc': 64},
#  {'ARG1-RAW': 'that amp',
#   'B-V-RAW': 'announce',
#   'ARG1': 'us',
#   'sentence': 97,
#   'doc': 64},
#  {'ARG1-RAW': 'our great stopthesteal group of senators',
#   'B-V-RAW': 'joined',
#   'sentence': 97,
#   'doc': 64},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'they',
#   'ARG1-RAW': 'the ridiculous electoral college certification of biden',
#   'B-V-RAW': 'fight',
#   'ARGO': 'we',
#   'ARG1': 'ballots',
#   'sentence': 98,
#   'doc': 64},
#  {'ARGO-RAW': 'you',
#   'ARG1-RAW': 'numbers that have now proven to be wrong and in many cases fraudulent',
#   'B-V-RAW': 'certify',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 99,
#   'doc': 65},
#  {'ARG1-RAW': 'to be wrong',
#   'B-V-RAW': 'proven',
#   'ARG1': 'we',
#   'sentence': 99,
#   'doc': 65},
#  {'ARG1-RAW': 'that',
#   'ARG2-RAW': 'wrong',
#   'B-V-RAW': 'be',
#   'ARG1': 'we',
#   'ARG2': 'we',
#   'sentence': 99,
#   'doc': 66},
#  {'ARG1-RAW': 'joe biden',
#   'ARG2-RAW': 'president',
#   'B-V-RAW': 'were',
#   'ARG2': 'hardworking american patriots who',
#   'ARG1': 'joe biden',
#   'sentence': 100,
#   'doc': 66},
#  {'B-ARGM-MOD-RAW': 'would',
#   'ARGO-RAW': 'you',
#   'ARG1-RAW': 'the vaccine',
#   'B-V-RAW': 'have',
#   'B-ARGM-NEG-RAW': True,
#   'ARGO': 'we',
#   'ARG1': 'vaccine',
#   'sentence': 100,
#   'doc': 66},
#  {'B-ARGM-MOD-RAW': 'would',
#   'ARGO-RAW': 'the',
#   'ARG1-RAW': 'it',
#   'B-V-RAW': 'approved',
#   'ARGO': 'us',
#   'ARG1': 'we',
#   'sentence': 100,
#   'doc': 66},
#  {'B-ARGM-MOD-RAW': 'would',
#   'ARGO-RAW': 'the bureaucracy',
#   'ARG1-RAW': 'millions of lives',
#   'B-V-RAW': 'destroyed',
#   'ARGO': 'the unsolicited mail in ballot scam',
#   'ARG1': 'us',
#   'sentence': 101,
#   'doc': 67},
#  {'ARGO-RAW': 'the and the democrats',
#   'ARG1-RAW': 'to have me get a vaccine win prior to the election',
#   'B-V-RAW': 'want',
#   'B-ARGM-NEG-RAW': True,
#   'ARGO': 'democrats',
#   'ARG1': 'vaccine',
#   'sentence': 102,
#   'doc': 67},
#  {'ARGO-RAW': 'the and the democrats',
#   'ARG1-RAW': 'me get a vaccine win prior to the election',
#   'B-V-RAW': 'have',
#   'ARGO': 'democrats',
#   'ARG1': 'vaccine',
#   'sentence': 102,
#   'doc': 68},
#  {'ARGO-RAW': 'me',
#   'ARG1-RAW': 'a vaccine win',
#   'B-V-RAW': 'get',
#   'ARGO': 'we',
#   'ARG1': 'vaccine',
#   'sentence': 102,
#   'doc': 68},
#  {'ARG1-RAW': 'it',
#   'B-V-RAW': 'came',
#   'ARG1': 'we',
#   'sentence': 102,
#   'doc': 69},
#  {'ARGO-RAW': 'i',
#   'B-V-RAW': 'said',
#   'ARGO': 'we',
#   'sentence': 103,
#   'doc': 69},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'who',
#   'ARG1-RAW': 'for governor of the great state of ohio',
#   'B-V-RAW': 'running',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'ohio',
#   'sentence': 104,
#   'doc': 69},
#  {'B-ARGM-MOD-RAW': 'will',
#   'B-V-RAW': 'contested',
#   'sentence': 105,
#   'doc': 69},
#  {'ARG1-RAW': 'another vaccine',
#   'B-V-RAW': 'announced',
#   'ARG1': 'vaccine',
#   'sentence': 106,
#   'doc': 69},
#  {'sentence': 107, 'doc': 70},
#  {'ARG1-RAW': 'that these great discoveries which will end the china plague all took place on my watch',
#   'B-V-RAW': 'remember',
#   'ARG1': 'us',
#   'sentence': 108,
#   'doc': 71},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'these great discoveries which',
#   'ARG1-RAW': 'the china plague',
#   'B-V-RAW': 'end',
#   'ARGO': 'us',
#   'ARG1': 'us',
#   'sentence': 108,
#   'doc': 71},
#  {'ARG1-RAW': 'these great discoveries which will end the china plague all',
#   'ARG2-RAW': 'place',
#   'B-V-RAW': 'took',
#   'ARG1': 'us',
#   'ARG2': 'us',
#   'sentence': 108,
#   'doc': 71},
#  {'ARG1-RAW': 'the fake recount',
#   'B-V-RAW': 'going',
#   'ARG1': 'ballots',
#   'sentence': 109,
#   'doc': 71},
#  {'ARGO-RAW': 'the fake recount going on in georgia',
#   'ARG1-RAW': 'nothing',
#   'B-V-RAW': 'means',
#   'ARG1': 'we',
#   'ARGO': 'georgia',
#   'sentence': 109,
#   'doc': 72},
#  {'ARGO-RAW': 'they',
#   'ARG1-RAW': 'signatures to be looked at and verified',
#   'B-V-RAW': 'allowing',
#   'B-ARGM-NEG-RAW': True,
#   'ARGO': 'we',
#   'ARG1': 'ballots',
#   'sentence': 109,
#   'doc': 72},
#  {'ARG1-RAW': 'at',
#   'B-V-RAW': 'looked',
#   'ARG1': 'us',
#   'sentence': 109,
#   'doc': 73},
#  {'ARG1-RAW': 'signatures',
#   'B-V-RAW': 'verified',
#   'ARG1': 'ballots',
#   'sentence': 109,
#   'doc': 73},
#  {'ARG1-RAW': 'the unconstitutional consent decree',
#   'B-V-RAW': 'break',
#   'ARG1': 'ballots',
#   'sentence': 110,
#   'doc': 73},
#  {'B-V-RAW': 'get', 'sentence': 111, 'doc': 73},
#  {'ARG1-RAW': 'so', 'B-V-RAW': 'do', 'ARG1': 'we', 'sentence': 111, 'doc': 74},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'see',
#   'ARG1': 'we',
#   'sentence': 112,
#   'doc': 74},
#  {'sentence': 113, 'doc': 74},
#  {'sentence': 114, 'doc': 74},
#  {'sentence': 115, 'doc': 75},
#  {'ARG1-RAW': 'it',
#   'B-V-RAW': 'watched',
#   'ARG1': 'we',
#   'sentence': 116,
#   'doc': 75},
#  {'ARGO-RAW': 'the vice president',
#   'ARG1-RAW': 'the power to reject fraudulently chosen electors',
#   'B-V-RAW': 'has',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'ballots',
#   'sentence': 117,
#   'doc': 75},
#  {'ARGO-RAW': 'the vice president',
#   'ARG1-RAW': 'fraudulently chosen electors',
#   'B-V-RAW': 'reject',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'ballots',
#   'sentence': 117,
#   'doc': 75},
#  {'ARG1-RAW': 'electors',
#   'B-V-RAW': 'chosen',
#   'ARG1': 'ballots',
#   'sentence': 117,
#   'doc': 75},
#  {'ARG1-RAW': 'this',
#   'ARG2-RAW': 'a rigged election',
#   'B-V-RAW': 'was',
#   'ARG1': 'we',
#   'ARG2': 'ballots',
#   'sentence': 118,
#   'doc': 75},
#  {'ARG1-RAW': 'election',
#   'B-V-RAW': 'rigged',
#   'ARG1': 'ballots',
#   'sentence': 118,
#   'doc': 75},
#  {'ARGO-RAW': 'no republican poll watchers',
#   'B-V-RAW': 'allowed',
#   'ARGO': 'ballots',
#   'sentence': 119,
#   'doc': 75},
#  {'ARGO-RAW': 'machine',
#   'B-V-RAW': 'voting',
#   'ARGO': 'us',
#   'sentence': 119,
#   'doc': 76},
#  {'B-V-RAW': 'glitches', 'sentence': 119, 'doc': 76},
#  {'ARG1-RAW': 'they got caught cheating',
#   'B-V-RAW': 'meaning',
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'sentence': 119,
#   'doc': 76},
#  {'ARG1-RAW': 'they',
#   'ARG2-RAW': 'caught cheating',
#   'B-V-RAW': 'got',
#   'ARG1': 'we',
#   'ARG2': 'the unsolicited mail in ballot scam',
#   'sentence': 119,
#   'doc': 76},
#  {'ARG1-RAW': 'they',
#   'ARG2-RAW': 'cheating',
#   'B-V-RAW': 'caught',
#   'ARG1': 'we',
#   'ARG2': 'the unsolicited mail in ballot scam',
#   'sentence': 119,
#   'doc': 77},
#  {'ARGO-RAW': 'they',
#   'B-V-RAW': 'cheating',
#   'ARGO': 'we',
#   'sentence': 119,
#   'doc': 77},
#  {'ARG1-RAW': 'election',
#   'B-V-RAW': 'ended',
#   'ARG1': 'ballots',
#   'sentence': 119,
#   'doc': 77},
#  {'ARGO-RAW': 'law enforcement',
#   'B-V-RAW': 'watching',
#   'ARGO': 'us',
#   'sentence': 120,
#   'doc': 78},
#  {'ARG1-RAW': 'law enforcement',
#   'B-V-RAW': 'involved',
#   'ARG1': 'us',
#   'sentence': 120,
#   'doc': 79},
#  {'sentence': 121, 'doc': 80},
#  {'ARG1-RAW': 'you wisconsin',
#   'B-V-RAW': 'thank',
#   'ARG1': 'wisconsin',
#   'sentence': 122,
#   'doc': 80},
#  {'ARGO-RAW': 'tweet that',
#   'ARG1-RAW': 'backlash against fox news',
#   'B-V-RAW': 'exposed',
#   'ARGO': 'the unsolicited mail in ballot scam',
#   'ARG1': 'us',
#   'sentence': 123,
#   'doc': 80},
#  {'ARG1-RAW': 'reports that dominion machines are not working in certain republican strongholds for over an hour',
#   'ARG2-RAW': 'out of the th congressional district of georgia',
#   'B-V-RAW': 'coming',
#   'ARG1': 'us',
#   'ARG2': 'georgia',
#   'sentence': 124,
#   'doc': 81},
#  {'ARGO-RAW': 'dominion machines',
#   'B-V-RAW': 'working',
#   'B-ARGM-NEG-RAW': True,
#   'ARGO': 'us',
#   'sentence': 124,
#   'doc': 82},
#  {'ARG1-RAW': 'ballots',
#   'B-V-RAW': 'left',
#   'ARG1': 'ballots',
#   'sentence': 125,
#   'doc': 83},
#  {'ARGO-RAW': 'they',
#   'ARG1-RAW': 'them',
#   'B-V-RAW': 'count',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 125,
#   'doc': 84},
#  {'ARG1-RAW': 'you',
#   'B-V-RAW': 'thank',
#   'ARG1': 'we',
#   'sentence': 126,
#   'doc': 85},
#  {'ARG1-RAW': 'this',
#   'ARG2-RAW': 'the most important election in the history of our country',
#   'B-V-RAW': 'is',
#   'ARG1': 'we',
#   'ARG2': 'country',
#   'sentence': 127,
#   'doc': 86},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'we',
#   'ARG1-RAW': 'to bring back your jobs lower drug prices support our police protect the a defend our borders',
#   'B-V-RAW': 'continue',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 128,
#   'doc': 86},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'your jobs',
#   'B-V-RAW': 'bring',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 128,
#   'doc': 87},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'our police',
#   'B-V-RAW': 'support',
#   'ARGO': 'we',
#   'ARG1': 'hardworking american patriots who',
#   'sentence': 128,
#   'doc': 87},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'the a',
#   'B-V-RAW': 'protect',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 128,
#   'doc': 88},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'our borders',
#   'B-V-RAW': 'defend',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 128,
#   'doc': 88},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'more products are proudly stamped with the phrase made in the usa',
#   'B-V-RAW': 'ensure',
#   'ARGO': 'we',
#   'ARG1': 'us',
#   'sentence': 128,
#   'doc': 88},
#  {'ARG1-RAW': 'more products',
#   'ARG2-RAW': 'with the phrase made in the usa',
#   'B-V-RAW': 'stamped',
#   'ARG1': 'us',
#   'ARG2': 'us',
#   'sentence': 128,
#   'doc': 88},
#  {'ARGO-RAW': 'we',
#   'B-V-RAW': 'withdrew',
#   'ARGO': 'we',
#   'sentence': 129,
#   'doc': 88},
#  {'ARGO-RAW': 'we',
#   'B-V-RAW': 'won',
#   'ARGO': 'we',
#   'sentence': 129,
#   'doc': 88},
#  {'sentence': 130, 'doc': 89},
#  {'B-V-RAW': 'get', 'sentence': 131, 'doc': 89},
#  {'sentence': 132, 'doc': 89},
#  {'ARG1-RAW': 'i',
#   'ARG2-RAW': 'president',
#   'B-V-RAW': 'am',
#   'ARG1': 'we',
#   'ARG2': 'hardworking american patriots who',
#   'sentence': 133,
#   'doc': 90},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARG1-RAW': 'i',
#   'ARG2-RAW': 'with the heroes of law enforcement',
#   'B-V-RAW': 'stand',
#   'ARG1': 'we',
#   'ARG2': 'hardworking american patriots who',
#   'sentence': 133,
#   'doc': 90},
#  {'sentence': 134, 'doc': 90},
#  {'ARG1-RAW': 'washington',
#   'ARG2-RAW': 'with people who do n’t want to see an election victory stolen by emboldened radical left democrats',
#   'B-V-RAW': 'inundated',
#   'ARG1': 'hardworking american patriots who',
#   'ARG2': 'democrats',
#   'sentence': 135,
#   'doc': 90},
#  {'ARGO-RAW': 'people who',
#   'ARG1-RAW': 'to see an election victory stolen by emboldened radical left democrats',
#   'B-V-RAW': 'want',
#   'B-ARGM-NEG-RAW': True,
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'democrats',
#   'sentence': 135,
#   'doc': 90},
#  {'ARGO-RAW': 'who',
#   'ARG1-RAW': 'an election victory stolen by emboldened radical left democrats',
#   'B-V-RAW': 'see',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'democrats',
#   'sentence': 135,
#   'doc': 91},
#  {'ARGO-RAW': 'by emboldened radical left democrats',
#   'ARG1-RAW': 'an election victory',
#   'B-V-RAW': 'stolen',
#   'ARG1': 'ballots',
#   'ARGO': 'democrats',
#   'sentence': 135,
#   'doc': 91},
#  {'ARG1-RAW': 'radical left democrats',
#   'B-V-RAW': 'emboldened',
#   'ARG1': 'democrats',
#   'sentence': 135,
#   'doc': 91},
#  {'ARGO-RAW': 'our country',
#   'ARG1-RAW': 'enough',
#   'B-V-RAW': 'had',
#   'ARG1': 'we',
#   'ARGO': 'country',
#   'sentence': 136,
#   'doc': 92},
#  {'B-ARGM-MOD-RAW': 'wo',
#   'ARGO-RAW': 'they',
#   'ARG1-RAW': 'it',
#   'B-V-RAW': 'take',
#   'B-ARGM-NEG-RAW': True,
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 136,
#   'doc': 92},
#  {'ARGO-RAW': 'we',
#   'ARG2-RAW': 'you from the oval office',
#   'B-V-RAW': 'hear',
#   'ARGO': 'we',
#   'ARG2': 'hardworking american patriots who',
#   'sentence': 137,
#   'doc': 93},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'you',
#   'B-V-RAW': 'love',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 137,
#   'doc': 94},
#  {'ARG1-RAW': 'america great again',
#   'B-V-RAW': 'make',
#   'ARG1': 'us',
#   'sentence': 138,
#   'doc': 95},
#  {'ARG1-RAW': 'america',
#   'B-V-RAW': 'great',
#   'ARG1': 'us',
#   'sentence': 138,
#   'doc': 96},
#  {'sentence': 139, 'doc': 96},
#  {'ARGO-RAW': 'top pollster',
#   'B-V-RAW': 'finds',
#   'ARGO': 'ballots',
#   'sentence': 140,
#   'doc': 96},
#  {'sentence': 141, 'doc': 97},
#  {'sentence': 142, 'doc': 97},
#  {'sentence': 143, 'doc': 97},
#  {'sentence': 144, 'doc': 98},
#  {'sentence': 145, 'doc': 98},
#  {'sentence': 146, 'doc': 99},
#  {'sentence': 147},
#  {'sentence': 148},
#  {'ARGO-RAW': 'president trump',
#   'ARG1-RAW': 'we would be getting a vaccine by the end of the year',
#   'ARG2-RAW': 'us',
#   'B-V-RAW': 'told',
#   'ARGO': 'hardworking american patriots who',
#   'ARG2': 'us',
#   'ARG1': 'vaccine',
#   'sentence': 149},
#  {'B-ARGM-MOD-RAW': 'would',
#   'ARGO-RAW': 'we',
#   'ARG1-RAW': 'a vaccine',
#   'B-V-RAW': 'getting',
#   'ARGO': 'we',
#   'ARG1': 'vaccine',
#   'sentence': 149},
#  {'ARGO-RAW': 'people',
#   'ARG2-RAW': 'at him',
#   'B-V-RAW': 'laughed',
#   'ARGO': 'us',
#   'ARG2': 'hardworking american patriots who',
#   'sentence': 149},
#  {'ARG1-RAW': 'we',
#   'ARG2-RAW': 'here',
#   'B-V-RAW': 'are',
#   'ARG1': 'we',
#   'ARG2': 'we',
#   'sentence': 149},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'fda approval',
#   'B-V-RAW': 'getting',
#   'ARGO': 'we',
#   'ARG1': 'ballots',
#   'sentence': 149},
#  {'ARG1-RAW': 'he',
#   'ARG2-RAW': 'right',
#   'B-V-RAW': 'was',
#   'ARG1': 'hardworking american patriots who',
#   'ARG2': 'we',
#   'sentence': 150},
#  {'sentence': 151},
#  {'ARGO-RAW': 'i',
#   'ARG1-RAW': 'the democrats and even more importantly the weak and ineffective rino section of the republican party are looking at the thousands of people pouring into dc',
#   'B-V-RAW': 'hope',
#   'ARGO': 'we',
#   'ARG1': 'democrats',
#   'sentence': 152},
#  {'ARGO-RAW': 'the democrats and even more importantly the weak and ineffective rino section of the republican party',
#   'ARG1-RAW': 'at the thousands of people pouring into dc',
#   'B-V-RAW': 'looking',
#   'ARG1': 'us',
#   'ARGO': 'democrats',
#   'sentence': 152},
#  {'ARG1-RAW': 'the thousands of people',
#   'B-V-RAW': 'pouring',
#   'ARG1': 'us',
#   'sentence': 152},
#  {'B-ARGM-MOD-RAW': 'wo',
#   'ARG1-RAW': 'they',
#   'ARG2-RAW': 'for a landslide election victory to be stolen',
#   'B-V-RAW': 'stand',
#   'B-ARGM-NEG-RAW': True,
#   'ARG1': 'we',
#   'ARG2': 'ballots',
#   'sentence': 153},
#  {'ARG1-RAW': 'a landslide election victory',
#   'B-V-RAW': 'stolen',
#   'ARG1': 'ballots',
#   'sentence': 153},
#  {'sentence': 154},
#  {'sentence': 155},
#  {'sentence': 156},
#  {'sentence': 157},
#  {'ARG1-RAW': 'people better',
#   'B-V-RAW': 'make',
#   'ARG1': 'we',
#   'sentence': 158},
#  {'ARG2-RAW': 'amazing but seldom talked about by the media',
#   'B-V-RAW': 'are',
#   'ARG2': 'we',
#   'sentence': 159},
#  {'ARG1-RAW': 'mortality rate',
#   'ARG2-RAW': 'down',
#   'B-V-RAW': 'is',
#   'ARG1': 'us',
#   'ARG2': 'us',
#   'sentence': 160},
#  {'ARG1-RAW': 'voter fraud in detroit',
#   'ARG2-RAW': 'rampant',
#   'B-V-RAW': 'is',
#   'ARG1': 'hardworking american patriots who',
#   'ARG2': 'the unsolicited mail in ballot scam',
#   'sentence': 161},
#  {'ARG1-RAW': 'voter fraud in detroit',
#   'B-V-RAW': 'been',
#   'ARG1': 'hardworking american patriots who',
#   'sentence': 161},
#  {'sentence': 162},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'a vaccine',
#   'B-V-RAW': 'have',
#   'ARGO': 'we',
#   'ARG1': 'vaccine',
#   'sentence': 163},
#  {'sentence': 164},
#  {'sentence': 165},
#  {'ARG1-RAW': 'antifa',
#   'ARG2-RAW': 'a terrorist organization',
#   'B-V-RAW': 'is',
#   'ARG2': 'us',
#   'sentence': 166},
#  {'B-V-RAW': 'stay', 'sentence': 166},
#  {'ARGO-RAW': 'law enforcement',
#   'ARG1-RAW': 'you',
#   'B-V-RAW': 'watching',
#   'ARGO': 'us',
#   'ARG1': 'we',
#   'sentence': 167},
#  {'ARG1-RAW': 'we',
#   'ARG2-RAW': 'big progress',
#   'B-V-RAW': 'making',
#   'ARG1': 'we',
#   'ARG2': 'us',
#   'sentence': 168},
#  {'sentence': 169},
#  {'ARG2-RAW': 'in next week',
#   'B-V-RAW': 'come',
#   'ARG2': 'us',
#   'sentence': 170},
#  {'ARG1-RAW': 'america great again',
#   'B-V-RAW': 'make',
#   'ARG1': 'us',
#   'sentence': 171},
#  {'ARG1-RAW': 'america', 'B-V-RAW': 'great', 'ARG1': 'us', 'sentence': 171},
#  {'sentence': 172},
#  {'ARG1-RAW': 'to grow',
#   'B-V-RAW': 'continues',
#   'ARG1': 'us',
#   'sentence': 173},
#  {'ARG1-RAW': 'evidence of voter fraud',
#   'B-V-RAW': 'grow',
#   'ARG1': 'us',
#   'sentence': 173},
#  {'ARG1-RAW': 'dead people on the pennsylvania voters roll and many thousands all over the country',
#   'ARG2-RAW': 'evidence of voter fraud',
#   'B-V-RAW': 'including',
#   'ARG2': 'us',
#   'ARG1': 'country',
#   'sentence': 173},
#  {'ARG1-RAW': 'voters',
#   'ARG2-RAW': 'the pennsylvania',
#   'B-V-RAW': 'roll',
#   'ARG1': 'ballots',
#   'ARG2': 'pennsylvania',
#   'sentence': 173},
#  {'ARG1-RAW': 'an artificial number of votes in favor of joe biden',
#   'B-V-RAW': 'been',
#   'ARG1': 'joe biden',
#   'sentence': 174},
#  {'sentence': 175},
#  {'ARG1-RAW': 'almost zero ballots',
#   'B-V-RAW': 'rejected',
#   'ARG1': 'us',
#   'sentence': 176},
#  {'sentence': 177},
#  {'sentence': 178},
#  {'B-ARGM-MOD-RAW': 'must',
#   'ARG1-RAW': 'signature check on envelopes',
#   'B-V-RAW': 'have',
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'sentence': 179},
#  {'sentence': 180},
#  {'ARGO-RAW': 'dems',
#   'B-V-RAW': 'fighting',
#   'ARGO': 'the unsolicited mail in ballot scam',
#   'sentence': 181},
#  {'ARG1-RAW': 'they',
#   'ARG2-RAW': 'caught',
#   'B-V-RAW': 'got',
#   'ARG1': 'we',
#   'ARG2': 'hardworking american patriots who',
#   'sentence': 181},
#  {'ARG1-RAW': 'they', 'B-V-RAW': 'caught', 'ARG1': 'we', 'sentence': 181},
#  {'sentence': 182},
#  {'B-ARGM-MOD-RAW': 'must',
#   'ARG1-RAW': 'republicans',
#   'ARG2-RAW': 'tough',
#   'B-V-RAW': 'get',
#   'ARG2': 'we',
#   'ARG1': 'republicans',
#   'sentence': 183},
#  {'ARG1-RAW': 'the vote tabulations',
#   'B-V-RAW': 'saw',
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'sentence': 184},
#  {'ARG1-RAW': 'no', 'B-V-RAW': 'is', 'ARG1': 'we', 'sentence': 185},
#  {'ARGO-RAW': 'way biden',
#   'ARG1-RAW': 'votes',
#   'B-V-RAW': 'got',
#   'ARGO': 'we',
#   'ARG1': 'ballots',
#   'sentence': 186},
#  {'ARG1-RAW': 'this',
#   'ARG2-RAW': 'a rigged election',
#   'B-V-RAW': 'was',
#   'ARG1': 'we',
#   'ARG2': 'ballots',
#   'sentence': 187},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'i',
#   'B-V-RAW': 'speaking',
#   'ARGO': 'we',
#   'sentence': 188},
#  {'sentence': 189},
#  {'sentence': 190},
#  {'ARG1-RAW': 'we',
#   'ARG2-RAW': 'win',
#   'B-V-RAW': 'will',
#   'ARG1': 'we',
#   'ARG2': 'ballots',
#   'sentence': 191},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'we',
#   'B-V-RAW': 'win',
#   'ARGO': 'we',
#   'sentence': 191},
#  {'sentence': 192},
#  {'ARG1-RAW': 'for massive ballot counting abuse',
#   'B-V-RAW': 'watch',
#   'ARG1': 'ballots',
#   'sentence': 193},
#  {'sentence': 194},
#  {'ARG1-RAW': 'i told you so',
#   'B-V-RAW': 'remember',
#   'ARG1': 'hardworking american patriots who',
#   'sentence': 195},
#  {'ARGO-RAW': 'i',
#   'ARG1-RAW': 'you so',
#   'B-V-RAW': 'told',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 195},
#  {'sentence': 196},
#  {'sentence': 197},
#  {'sentence': 198},
#  {'sentence': 199},
#  {'sentence': 200},
#  {'sentence': 201},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'statehouse republicans proud strong and honest',
#   'ARG1-RAW': 'this travesty stand',
#   'B-V-RAW': 'let',
#   'B-ARGM-NEG-RAW': True,
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'ARGO': 'republicans',
#   'sentence': 202},
#  {'ARG1-RAW': 'this travesty',
#   'B-V-RAW': 'stand',
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'sentence': 202},
#  {'ARG1-RAW': 'like they are setting up a big “ voter dump ” against the republican candidates',
#   'B-V-RAW': 'looks',
#   'sentence': 203},
#  {'ARGO-RAW': 'they',
#   'ARG1-RAW': 'a big “ voter dump ” against the republican candidates',
#   'B-V-RAW': 'setting',
#   'ARGO': 'we',
#   'sentence': 203},
#  {'ARG2-RAW': 'to see how many votes they need',
#   'B-V-RAW': 'waiting',
#   'ARG2': 'we',
#   'sentence': 204},
#  {'ARG1-RAW': 'how many votes they need',
#   'B-V-RAW': 'see',
#   'ARG1': 'we',
#   'sentence': 204},
#  {'ARGO-RAW': 'they',
#   'ARG1-RAW': 'how many votes',
#   'B-V-RAW': 'need',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 204},
#  {'sentence': 205},
#  {'sentence': 206},
#  {'sentence': 207},
#  {'ARG1-RAW': '’s three day extension of the mail in ballot deadline',
#   'ARG2-RAW': 'a constitutional travesty',
#   'B-V-RAW': 'is',
#   'ARG1': 'us',
#   'ARG2': 'ballots',
#   'sentence': 208},
#  {'sentence': 209},
#  {'ARGO-RAW': 'legal scholars',
#   'B-V-RAW': 'agree',
#   'ARGO': 'us',
#   'sentence': 210},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARG1-RAW': 'these charts',
#   'B-V-RAW': 'use',
#   'ARG1': 'us',
#   'sentence': 211},
#  {'ARG1-RAW': 'the election',
#   'ARG2-RAW': 'a hoax',
#   'B-V-RAW': 'was',
#   'ARG1': 'ballots',
#   'ARG2': 'the unsolicited mail in ballot scam',
#   'sentence': 212},
#  {'ARG1-RAW': 'you', 'B-V-RAW': 'thank', 'ARG1': 'we', 'sentence': 213},
#  {'B-ARGM-MOD-RAW': 'will', 'B-V-RAW': 'go', 'sentence': 214},
#  {'ARG1-RAW': 'daytime',
#   'B-V-RAW': 'weekend',
#   'ARG1': 'the unsolicited mail in ballot scam',
#   'sentence': 215},
#  {'ARGO-RAW': 'they',
#   'ARG1-RAW': 'it',
#   'B-V-RAW': 'get',
#   'B-ARGM-NEG-RAW': True,
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 216},
#  {'sentence': 217},
#  {'ARG1-RAW': 'the late great roger ailes',
#   'ARG2-RAW': 'seriously missed',
#   'B-V-RAW': 'is',
#   'ARG2': 'we',
#   'sentence': 218},
#  {'ARG1-RAW': 'the late great roger ailes',
#   'B-V-RAW': 'missed',
#   'sentence': 218},
#  {'ARGO-RAW': 'i',
#   'ARG1-RAW': 'legal votes',
#   'B-V-RAW': 'won',
#   'ARGO': 'we',
#   'ARG1': 'ballots',
#   'sentence': 218},
#  {'ARG1-RAW': 'andrew mccabe continue to get away with totally criminal activity',
#   'B-V-RAW': 'let',
#   'B-ARGM-NEG-RAW': True,
#   'ARG1': 'we',
#   'sentence': 219},
#  {'ARGO-RAW': 'andrew mccabe',
#   'ARG1-RAW': 'to get away with totally criminal activity',
#   'B-V-RAW': 'continue',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'we',
#   'sentence': 219},
#  {'ARGO-RAW': 'andrew mccabe',
#   'ARG1-RAW': 'with totally criminal activity',
#   'B-V-RAW': 'get',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'us',
#   'sentence': 219},
#  {'ARGO-RAW': 'he',
#   'ARG1-RAW': 'what',
#   'B-V-RAW': 'did',
#   'ARGO': 'hardworking american patriots who',
#   'ARG1': 'we',
#   'sentence': 220},
#  {'B-ARGM-MOD-RAW': 'should',
#   'ARG1-RAW': 'to happen to our country again',
#   'B-V-RAW': 'allowed',
#   'B-ARGM-NEG-RAW': True,
#   'ARG1': 'country',
#   'sentence': 220},
#  {'ARG1-RAW': 'what he did',
#   'ARG2-RAW': 'to our country',
#   'B-V-RAW': 'happen',
#   'ARG1': 'we',
#   'ARG2': 'country',
#   'sentence': 220},
#  {'sentence': 221},
#  {'ARG1-RAW': 'to have found another ballots from fulton county',
#   'B-V-RAW': 'happened',
#   'ARG1': 'hardworking american patriots who',
#   'sentence': 222},
#  {'ARG1-RAW': 'another ballots from fulton county',
#   'B-V-RAW': 'found',
#   'ARG1': 'hardworking american patriots who',
#   'sentence': 222},
#  {'ARGO-RAW': 'we', 'B-V-RAW': 'go', 'ARGO': 'we', 'sentence': 223},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARG1-RAW': 'no lockdowns other than those done by certain democrat governors',
#   'B-V-RAW': 'be',
#   'ARG1': 'us',
#   'sentence': 224},
#  {'ARGO-RAW': 'by certain democrat governors',
#   'ARG1-RAW': 'those',
#   'B-V-RAW': 'done',
#   'ARGO': 'ballots',
#   'ARG1': 'we',
#   'sentence': 224},
#  {'sentence': 225},
#  {'sentence': 226},
#  {'ARGO-RAW': 'nate simington a very smart and qualified individual',
#   'ARG1-RAW': 'his senate hearing',
#   'B-V-RAW': 'having',
#   'ARG1': 'hardworking american patriots who',
#   'sentence': 227},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'republicans',
#   'ARG1-RAW': 'him',
#   'ARG2-RAW': 'to the fcc',
#   'B-V-RAW': 'confirm',
#   'ARG1': 'hardworking american patriots who',
#   'ARG2': 'ballots',
#   'ARGO': 'republicans',
#   'sentence': 228},
#  {'ARGO-RAW': 'we',
#   'ARG1-RAW': 'action on this very important nomination',
#   'B-V-RAW': 'need',
#   'ARGO': 'we',
#   'ARG1': 'ballots',
#   'sentence': 229},
#  {'ARG1-RAW': 'pennsylvania party leadership votes',
#   'ARG2-RAW': 'this week',
#   'B-V-RAW': 'are',
#   'ARG2': 'us',
#   'ARG1': 'pennsylvania',
#   'sentence': 230},
#  {'ARGO-RAW': 'i',
#   'ARG1-RAW': 'they pick very tough and smart fighters',
#   'B-V-RAW': 'hope',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 231},
#  {'ARGO-RAW': 'they',
#   'ARG1-RAW': 'very tough and smart fighters',
#   'B-V-RAW': 'pick',
#   'ARGO': 'we',
#   'ARG1': 'we',
#   'sentence': 231},
#  {'ARG1-RAW': 'we',
#   'ARG2-RAW': 'win',
#   'B-V-RAW': 'will',
#   'ARG1': 'we',
#   'ARG2': 'ballots',
#   'sentence': 232},
#  {'B-ARGM-MOD-RAW': 'will',
#   'ARGO-RAW': 'we',
#   'B-V-RAW': 'win',
#   'ARGO': 'we',
#   'sentence': 232},
#  {'B-ARGM-MOD-RAW': 'should',
#   'ARGO-RAW': 'rino mitt romney',
#   'ARG1-RAW': 'this',
#   'B-V-RAW': 'read',
#   'ARGO': 'ballots',
#   'ARG1': 'we',
#   'sentence': 233},
#  {'ARG1-RAW': 'i',
#   'ARG2-RAW': 'sure however that he feels he got slaughtering by obama “ fair and square ”',
#   'B-V-RAW': '’m',
#   'ARG1': 'we',
#   'sentence': 234},
#  {'ARGO-RAW': 'he',
#   'ARG1-RAW': 'he got slaughtering by obama “ fair and square ”',
#   'B-V-RAW': 'feels',
#   'ARGO': 'hardworking american patriots who',
#   'sentence': 234},
#  {'ARGO-RAW': 'he',
#   'ARG1-RAW': 'slaughtering by obama “ fair and square',
#   'B-V-RAW': 'got',
#   'ARGO': 'hardworking american patriots who',
#   'sentence': 234},
#  {'ARGO-RAW': 'by obama',
#   'B-V-RAW': 'slaughtering',
#   'ARGO': 'ballots',
#   'sentence': 234},
#  {'sentence': 235}]
