# %% [markdown]
# ### Settings and Libraries

# %%
from pipeline import *

# %% [markdown]
# ### Pipeline in Action (with keyed vectors)

# %%
df = pd.read_csv('trump_tweets_cleaned.csv')
df = df[['id', 'text_clean']]
df.columns = ['id', 'doc']
train_data = df.iloc[0:100]

stop_words = list(stopwords.words('english'))

# %%
split_sentences = split_into_sentences(train_data)
# Out:
# Splitting into sentences...
# 100%|██████████| 100/100 [00:00<00:00, 112.56it/s]

# %%
srl_res = run_srl(path = "../srl-model-2018.05.25.tar.gz",
                  sentences=split_sentences[1],
                  save_to_disk = None,
                  batch_size = 20)
# Out:
# Loading SRL model...
# Running semantic role labeling...

# %%
narrative_model = build_narrative_model(srl_res = srl_res, 
                                        embeddings_type = "gensim_keyed_vectors",
                                        embeddings_path = "glove-wiki-gigaword-300",
                                        #roles_considered = ['ARGO', 'B-V', 'B-ARGM-NEG', 'B-ARGM-MOD', 'ARG1'],
                                        #roles_with_embeddings = ['ARGO'],
                                        #roles_with_entities = ['ARG1', 'ARG2'],
                                        #dimension_reduce_verbs = False,
                                        # n_clusters = [0],
                                        sentences = split_sentences[1],
                                        save_to_disk = None,
                                        max_length = 4,
                                        remove_punctuation = True,
                                        remove_digits = True,
                                        remove_chars = '',
                                        stop_words = stop_words,
                                        lowercase = True,
                                        strip = True,
                                        remove_whitespaces = True,
                                        lemmatize = True,
                                        stem = False,
                                        tags_to_keep = None,
                                        remove_n_letter_words = 1)
# Out:
# Processing srl output...
# Counting verbs...
# Processing named entities...
# Loading embeddings model...
# Clustering remaining arguments...
# Number of clusters eventually chosen: 1

# %%
final_statements = get_narratives(srl_res = srl_res,
                                  doc_index = split_sentences[0],
                                  narrative_model = narrative_model,
                                  save_to_disk = None,
                                  cluster_labeling = 'most_similar')

final_statements
# Out:
# Processing srl output...
# Dimension reduction of verbs...
# Processing named entities...
# Clustering remaining arguments...
#                      doc  sentence  statement              narrative-CLEANED  \
# 1      98454970654916608         0          1             republican make so
# 6    1234653427789070336         1          6                so love country
# 7    1234653427789070336         1          7                  so cherish so
# 8    1234653427789070336         1          8                  so respect so
# 9    1234653427789070336         1          9                      so put so
# 13   1304875170860015617         4         13                      so use so
# 41   1319683876046934016        17         41             sudan agree israel
# 53   1325889532840062976        23         53              adamlaxalt get so
# 58   1325891490636320768        24         58               wisconsin see so
# 108  1317063921375842305        49        108                      so see so
# 133  1328328547598000130        68        133                       so go so
# 140  1320162252868255745        74        140                   biden say so
# 150  1325961445062938625        81        150  pfizer announce would vaccine
# 175  1346469204740902915        90        175                    amp join so
# 190  1325961672343875585        94        190          so destroyed would so
# 208  1328341927641681922       100        208                      so end so
# 211  1328338241284616193       101        211                   fake mean so
# 226  1346488314157797389       110        226                   so reject so
# 243  1326031379151327232       116        243             so expose fox news
# 278  1346578706437963777       128        278          radical left steal so
# 290  1329521429575049231       133        290              democrat steal so
# 357  1331987171700510720       173        357                   biden get so
# 405  1326194143132082178       203        405           andrew mccabe get so
#
#                                          narrative-RAW  \
# 1          republican democrat create economic problem
# 6            hardworking american patriot love country
# 7           hardworking american patriot cherish value
# 8             hardworking american patriot respect law
# 9       hardworking american patriot put america first
# 13                   almost recent election use system
# 41    sudan agree peace normalization agreement israel
# 53      adamlaxalt find thing release absolutely shock
# 58                                 wisconsin look good
# 108                            poll number look strong
# 133                              dominion run election
# 140                           biden say terrible thing
# 150               pfizer others announce would vaccine
# 175  kloeffler amp sendavidperdue join great group ...
# 190           bureaucracy destroyed would million life
# 208                   great discovery end china plague
# 211               fake recount go georgia mean nothing
# 226  vice president reject fraudulently chosen elector
# 243                     tweet expose backlash fox news
# 278  embolden radical left democrat steal election ...
# 290                            democrat stole election
# 357                                 way biden get vote
# 405        andrew mccabe get totally criminal activity
#
#                            ARGO-RAW           ARGO    B-V-RAW B-V-CLEANED  \
# 1               republican democrat     republican     create        make
# 6      hardworking american patriot             so       love        love
# 7      hardworking american patriot             so    cherish     cherish
# 8      hardworking american patriot             so    respect     respect
# 9      hardworking american patriot             so        put         put
# 13           almost recent election             so        use         use
# 41                            sudan          sudan      agree       agree
# 53                       adamlaxalt     adamlaxalt       find         get
# 58                        wisconsin      wisconsin       look         see
# 108                     poll number             so       look         see
# 133                        dominion             so        run          go
# 140                           biden          biden        say         say
# 150                   pfizer others         pfizer   announce    announce
# 175    kloeffler amp sendavidperdue            amp       join        join
# 190                     bureaucracy             so  destroyed   destroyed
# 208                 great discovery             so        end         end
# 211         fake recount go georgia           fake       mean        mean
# 226                  vice president             so     reject      reject
# 243                           tweet             so     expose      expose
# 278  embolden radical left democrat   radical left      steal       steal
# 290                        democrat       democrat      stole       steal
# 357                       way biden          biden        get         get
# 405                   andrew mccabe  andrew mccabe        get         get
#
#     B-ARGM-NEG-RAW B-ARGM-NEG-CLEANED B-ARGM-MOD-RAW  \
# 1
# 6
# 7
# 8
# 9
# 13
# 41
# 53
# 58
# 108
# 133
# 140
# 150                                            would
# 175
# 190                                            would
# 208
# 211
# 226
# 243
# 278
# 290
# 357
# 405
#
#                                  ARG1-RAW      ARG1 ARG2-RAW ARG2
# 1                        economic problem        so
# 6                                 country   country
# 7                                   value        so
# 8                                     law        so
# 9                           america first        so
# 13                                 system        so
# 41   peace normalization agreement israel    israel
# 53         thing release absolutely shock        so
# 58                                   good        so
# 108                                strong        so
# 133                              election        so
# 140                        terrible thing        so
# 150                               vaccine   vaccine
# 175                   great group senator        so
# 190                          million life        so
# 208                          china plague        so
# 211                               nothing        so
# 226           fraudulently chosen elector        so
# 243                     backlash fox news  fox news
# 278                      election victory        so
# 290                              election        so
# 357                                  vote        so
# 405             totally criminal activity        so

# %%
df_sents = pd.DataFrame({'doc': split_sentences[0], 'sentence': split_sentences[1]})

# %%
inspect_label(final_statements, 
              label = 'election', 
              role = 'ARGO')
# Out:
# Series([], Name: ARGO-RAW, dtype: int64)

# %%
inspect_narrative(final_statements, narrative = final_statements['narrative-CLEANED'].iloc[0])
# Out:
# republican democrat create economic problem    1
# Name: narrative-RAW, dtype: int64
