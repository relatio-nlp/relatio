# %%
from pipeline import *
stop_words = list(stopwords.words('english'))

# %%
# Load the Trump tweets data

df = pd.read_csv('TrumpTweets/trump_tweets_cleaned.csv')
df = df[['id', 'text_clean']]
df.columns = ['id', 'doc']

# %%
# Split into sentences (example on 100 trump tweets)

split_sentences = split_into_sentences(df.iloc[0:100], 
                                       save_to_disk = None, 
                                       progress_bar = True)
# Out:
# Splitting into sentences...
# 100%|██████████| 100/100 [00:00<00:00, 101.73it/s]

# %%
# Run SRL (example on a 100 trump tweets)

srl_res = run_srl(path = "../srl-model-2018.05.25.tar.gz",
                  sentences=split_sentences[1],
                  save_to_disk = None,
                  batch_size = 20, 
                  progress_bar = True)
# Out:
# /home/germain/miniconda3/envs/narrative-nlp/lib/python3.7/site-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# Running SRL...
# 100%|██████████| 11/11 [01:16<00:00,  6.96s/it]

# %%
# Build narrative_model based on srl_res, embeddings and entities (example on a 100 Trump tweets).
# Full modularity for clustering. List of lists: arguments in each sublist are clustered together.
# Default: we cluster all arguments together.

narrative_model = build_narrative_model(srl_res = srl_res,
                                        sentences = split_sentences[1], # list of sentences
                                        roles_considered = ['ARGO', 'B-V', 'B-ARGM-NEG', 'B-ARGM-MOD', 'ARG1', 'ARG2'],
                                        roles_with_embeddings = [['ARGO','ARG1', 'ARG2']],
                                        embeddings_type = 'gensim_keyed_vectors',
                                        embeddings_path = 'glove-wiki-gigaword-300',
                                        n_clusters = [2],
                                        verbose = 0,
                                        roles_with_entities = ['ARGO', 'ARG1', 'ARG2'],
                                        top_n_entities = 10,
                                        dimension_reduce_verbs = True,
                                        save_to_disk = None,
                                        max_length = 4,
                                        remove_punctuation = True,
                                        remove_digits = True,
                                        remove_chars = '',
                                        stop_words = stop_words,
                                        lowercase = True,
                                        strip = True,
                                        remove_whitespaces = True,
                                        lemmatize = True,
                                        stem = False,
                                        tags_to_keep = None,
                                        remove_n_letter_words = 1, 
                                        progress_bar = True)
# Out:
# Processing SRL...
# 100%|██████████| 220/220 [00:00<00:00, 7485.33it/s]
# Cleaning SRL...
# 100%|██████████| 439/439 [00:01<00:00, 261.14it/s]
# Computing role frequencies...
# 100%|██████████| 439/439 [00:00<00:00, 354778.32it/s]
# Mining named entities...
# 100%|██████████| 220/220 [00:01<00:00, 150.07it/s]
# Mapping named entities...
# 100%|██████████| 439/439 [00:00<00:00, 32702.82it/s]

# %%
# Get narratives based on the narrative_model and srl_res.

final_statements = get_narratives(srl_res = srl_res,
                                  doc_index = split_sentences[0], # doc names
                                  narrative_model = narrative_model,
                                  save_to_disk = None,
                                  cluster_labeling = 'most_frequent',
                                  progress_bar = True)

final_statements
# Out:
# Processing SRL...
# 100%|██████████| 220/220 [00:00<00:00, 6973.60it/s]
# Cleaning SRL...
# 100%|██████████| 439/439 [00:00<00:00, 1644.09it/s]
# Processing raw arguments...
# 100%|██████████| 439/439 [00:00<00:00, 325490.45it/s]
# Cleaning verbs...
# 100%|██████████| 439/439 [00:00<00:00, 2382.30it/s]
# Mapping named entities...
# 100%|██████████| 439/439 [00:00<00:00, 19474.35it/s]
# Assigning clusters to roles...
# 100%|██████████| 439/439 [00:00<00:00, 3717.84it/s]
#                      doc  sentence  statement  \
# 1      98454970654916608         0          1
# 6    1234653427789070336         1          6
# 7    1234653427789070336         1          7
# 8    1234653427789070336         1          8
# 9    1234653427789070336         1          9
# 13   1304875170860015617         4         13
# 41   1319683876046934016        17         41
# 53   1325889532840062976        23         53
# 58   1325891490636320768        24         58
# 108  1317063921375842305        49        108
# 133  1328328547598000130        68        133
# 140  1320162252868255745        74        140
# 150  1325961445062938625        81        150
# 175  1346469204740902915        90        175
# 190  1325961672343875585        94        190
# 208  1328341927641681922       100        208
# 211  1328338241284616193       101        211
# 226  1346488314157797389       110        226
# 243  1326031379151327232       116        243
# 278  1346578706437963777       128        278
# 290  1329521429575049231       133        290
# 357  1331987171700510720       173        357
# 405  1326194143132082178       203        405
#
#                                      narrative-CLEANED  \
# 1           election make hardworking american patriot
# 6            hardworking american patriot love country
# 7    hardworking american patriot cherish hardworki...
# 8    hardworking american patriot respect hardworki...
# 9    hardworking american patriot put hardworking a...
# 13   hardworking american patriot use hardworking a...
# 41   hardworking american patriot agree hardworking...
# 53                    get hardworking american patriot
# 58          wisconsin see hardworking american patriot
# 108          election see hardworking american patriot
# 133                               election go election
# 140          election say hardworking american patriot
# 150  hardworking american patriot announce would va...
# 175                  join hardworking american patriot
# 190  election destroyed would hardworking american ...
# 208  hardworking american patriot end hardworking a...
# 211          georgia mean hardworking american patriot
# 226                           election reject election
# 243                           election expose election
# 278                            election steal election
# 290                            election steal election
# 357          hardworking american patriot get election
# 405          election get hardworking american patriot
#
#                                          narrative-RAW  \
# 1          republican democrat create economic problem
# 6            hardworking american patriot love country
# 7           hardworking american patriot cherish value
# 8             hardworking american patriot respect law
# 9       hardworking american patriot put america first
# 13                   almost recent election use system
# 41    sudan agree peace normalization agreement israel
# 53      adamlaxalt find thing release absolutely shock
# 58                                 wisconsin look good
# 108                            poll number look strong
# 133                              dominion run election
# 140                           biden say terrible thing
# 150               pfizer others announce would vaccine
# 175  kloeffler amp sendavidperdue join great group ...
# 190           bureaucracy destroyed would million life
# 208                   great discovery end china plague
# 211               fake recount go georgia mean nothing
# 226  vice president reject fraudulently chosen elector
# 243                     tweet expose backlash fox news
# 278  embolden radical left democrat steal election ...
# 290                            democrat stole election
# 357                                 way biden get vote
# 405        andrew mccabe get totally criminal activity
#
#                            ARGO-RAW                          ARGO    B-V-RAW  \
# 1               republican democrat                      election     create
# 6      hardworking american patriot  hardworking american patriot       love
# 7      hardworking american patriot  hardworking american patriot    cherish
# 8      hardworking american patriot  hardworking american patriot    respect
# 9      hardworking american patriot  hardworking american patriot        put
# 13           almost recent election  hardworking american patriot        use
# 41                            sudan  hardworking american patriot      agree
# 53                       adamlaxalt                                     find
# 58                        wisconsin                     wisconsin       look
# 108                     poll number                      election       look
# 133                        dominion                      election        run
# 140                           biden                      election        say
# 150                   pfizer others  hardworking american patriot   announce
# 175    kloeffler amp sendavidperdue                                     join
# 190                     bureaucracy                      election  destroyed
# 208                 great discovery  hardworking american patriot        end
# 211         fake recount go georgia                       georgia       mean
# 226                  vice president                      election     reject
# 243                           tweet                      election     expose
# 278  embolden radical left democrat                      election      steal
# 290                        democrat                      election      stole
# 357                       way biden  hardworking american patriot        get
# 405                   andrew mccabe                      election        get
#
#     B-V-CLEANED B-ARGM-NEG-RAW B-ARGM-NEG-CLEANED B-ARGM-MOD-RAW  \
# 1          make
# 6          love
# 7       cherish
# 8       respect
# 9           put
# 13          use
# 41        agree
# 53          get
# 58          see
# 108         see
# 133          go
# 140         say
# 150    announce                                            would
# 175        join
# 190   destroyed                                            would
# 208         end
# 211        mean
# 226      reject
# 243      expose
# 278       steal
# 290       steal
# 357         get
# 405         get
#
#                                  ARG1-RAW                          ARG1  \
# 1                        economic problem  hardworking american patriot
# 6                                 country                       country
# 7                                   value  hardworking american patriot
# 8                                     law  hardworking american patriot
# 9                           america first  hardworking american patriot
# 13                                 system  hardworking american patriot
# 41   peace normalization agreement israel  hardworking american patriot
# 53         thing release absolutely shock  hardworking american patriot
# 58                                   good  hardworking american patriot
# 108                                strong  hardworking american patriot
# 133                              election                      election
# 140                        terrible thing  hardworking american patriot
# 150                               vaccine                       vaccine
# 175                   great group senator  hardworking american patriot
# 190                          million life  hardworking american patriot
# 208                          china plague  hardworking american patriot
# 211                               nothing  hardworking american patriot
# 226           fraudulently chosen elector                      election
# 243                     backlash fox news                      election
# 278                      election victory                      election
# 290                              election                      election
# 357                                  vote                      election
# 405             totally criminal activity  hardworking american patriot
#
#     ARG2-RAW ARG2
# 1
# 6
# 7
# 8
# 9
# 13
# 41
# 53
# 58
# 108
# 133
# 140
# 150
# 175
# 190
# 208
# 211
# 226
# 243
# 278
# 290
# 357
# 405

# %%
df_sents = pd.DataFrame({'doc': split_sentences[0], 'sentence': split_sentences[1]})

# %%
inspect_label(final_statements, 
              label = 'election', 
              role = 'ARGO')
# Out:
# embolden radical left democrat    1
# biden                             1
# tweet                             1
# poll number                       1
# dominion                          1
# vice president                    1
# bureaucracy                       1
# republican democrat               1
# democrat                          1
# andrew mccabe                     1
# Name: ARGO-RAW, dtype: int64

# %%
inspect_narrative(final_statements, narrative = 'election cherish election')
# Out:
# Series([], Name: narrative-RAW, dtype: int64)

# %%
# Building alternative narratives (with raw verbs for instance)

narrative_format = ['ARGO', 'B-V-RAW', 'B-ARGM-NEG-RAW', 'ARG1']
final_statements['narrative'] = final_statements[narrative_format].agg(' '.join, axis=1)
final_statements['narrative'] = final_statements['narrative'].apply(remove_extra_whitespaces)
final_statements['narrative'].value_counts().head(n=20)
# Out:
# hardworking american patriot agree hardworking american patriot      1
# election say hardworking american patriot                            1
# find hardworking american patriot                                    1
# election stole election                                              1
# election look hardworking american patriot                           1
# election run election                                                1
# hardworking american patriot get election                            1
# hardworking american patriot use hardworking american patriot        1
# join hardworking american patriot                                    1
# hardworking american patriot cherish hardworking american patriot    1
# wisconsin look hardworking american patriot                          1
# georgia mean hardworking american patriot                            1
# hardworking american patriot end hardworking american patriot        1
# election create hardworking american patriot                         1
# election reject election                                             1
# election steal election                                              1
# election get hardworking american patriot                            1
# election expose election                                             1
# hardworking american patriot announce vaccine                        1
# election destroyed hardworking american patriot                      1
# Name: narrative, dtype: int64

# %%
# Loading output previously saved to disk (for the entire Trump tweets corpus)

with open('TrumpTweets/split_sentences.json', 'r') as f:
    split_sentences = json.load(f)
    
with open('TrumpTweets/srl_res.json', 'r') as f:
    srl_res = json.load(f)

# %%
import pandas as pd
df = pd.read_csv('TrumpTweets/final_df.csv')
df
# Out:
#                        doc  sentence  statement           narrative-CLEANED  \
# 0        98454970654916608         0          1    democrat create economic
# 1      1234653427789070336         1          6        patriot love country
# 2      1234653427789070336         1          7       patriot cherish value
# 3      1234653427789070336         1          8         patriot respect law
# 4      1234653427789070336         1          9   patriot put america first
# ...                    ...       ...        ...                         ...
# 12495  1213145418093223937     68595     150158  trump question work others
# 12496  1213149809378578432     68602     150179          case dismiss trial
# 12497  1213078681750573056     68606     150194   iran lose not negotiation
# 12498  1319384118849949702     68612     150209           biden fail delphi
# 12499  1319345719829008387     68614     150211      suburban want security
#
#                                         narrative-RAW  \
# 0         republican democrat create economic problem
# 1           hardworking american patriot love country
# 2          hardworking american patriot cherish value
# 3            hardworking american patriot respect law
# 4      hardworking american patriot put america first
# ...                                               ...
# 12495                       trump question aid number
# 12496                motion dismiss impeachment trial
# 12497                       iran lose not negotiation
# 12498                  obama biden fail worker delphi
# 12499         suburban woman want safety amp security
#
#                            ARGO-RAW      ARGO   B-V-RAW B-ARGM-NEG-RAW  \
# 0               republican democrat  democrat    create            NaN
# 1      hardworking american patriot   patriot      love            NaN
# 2      hardworking american patriot   patriot   cherish            NaN
# 3      hardworking american patriot   patriot   respect            NaN
# 4      hardworking american patriot   patriot       put            NaN
# ...                             ...       ...       ...            ...
# 12495                         trump     trump  question            NaN
# 12496                        motion      case   dismiss            NaN
# 12497                          iran      iran      lose            not
# 12498                   obama biden     biden      fail            NaN
# 12499                suburban woman  suburban      want            NaN
#
#       B-ARGM-MOD-RAW             ARG1-RAW           ARG1 ARG2-RAW    ARG2
# 0                NaN     economic problem       economic      NaN     NaN
# 1                NaN              country        country      NaN     NaN
# 2                NaN                value          value      NaN     NaN
# 3                NaN                  law            law      NaN     NaN
# 4                NaN        america first  america first      NaN     NaN
# ...              ...                  ...            ...      ...     ...
# 12495            NaN                  aid           work   number  others
# 12496            NaN    impeachment trial          trial      NaN     NaN
# 12497            NaN          negotiation    negotiation      NaN     NaN
# 12498            NaN        worker delphi         delphi      NaN     NaN
# 12499            NaN  safety amp security       security      NaN     NaN
#
# [12500 rows x 14 columns]

# %%
set(df['ARGO'])
# Out:
# {nan,
#  'ag',
#  'work',
#  'texas',
#  'cardinaldolan',
#  'tony fauci',
#  'njtransit',
#  'dirty',
#  'rinos',
#  'reporting',
#  'today',
#  'weekend daytime',
#  'abe',
#  'roy',
#  'due process',
#  'libya',
#  'rivlin',
#  'huffpost',
#  'rally',
#  'gaga',
#  'obrien',
#  'celebrity apprenticenbc',
#  'filthy',
#  'pelosis',
#  'danny',
#  'complete',
#  'frankluntz',
#  'crooked',
#  'clinton puppet',
#  'steel',
#  'cia',
#  'frank vandersloot',
#  'jamie',
#  'greece',
#  'world health',
#  'nyjets',
#  'walter',
#  'salmond',
#  'la david johnson',
#  'miamiherald',
#  'jimhagedornmn',
#  'scarborough',
#  'angelina jolie',
#  'american hero',
#  'forever',
#  'next',
#  'state election',
#  'forbes',
#  'trumpgolfdc',
#  'state supreme court',
#  'dummy',
#  'bobbyjindal',
#  'atlantic city',
#  'dominion',
#  'putin',
#  'voter',
#  'david',
#  'tony',
#  'constitutional',
#  'kimberly klacik',
#  'obama gang',
#  'fall',
#  'trade',
#  'columbia',
#  'lebron',
#  'richhudson',
#  'caronavirus',
#  'pataki',
#  'natl bedminster',
#  'rep amp',
#  'usfda',
#  'tony romo',
#  'voter identification',
#  'bipartisan',
#  'jeff johnson',
#  'nikki',
#  'california',
#  'gsa',
#  'colorado',
#  'icig michael atkinson',
#  'lawrence',
#  'eliot',
#  'judgejeanine pirro',
#  'flotus',
#  'john kasich',
#  'absentee',
#  'brazil',
#  'american',
#  'sba',
#  'credibility',
#  'football',
#  'msnbc amp',
#  'plane',
#  'tuesday',
#  'billion',
#  'ows',
#  'va',
#  'shady eric',
#  'kevin cernekee',
#  'trump imitation syndrome',
#  'afghanistan',
#  'insideedition',
#  'ron',
#  'rubio',
#  'katherinewebb',
#  'cuomo',
#  'license',
#  'trumpcollection',
#  'north',
#  'bezos',
#  'todayshow',
#  'gretawire',
#  'harry',
#  'presidential proclamation',
#  'team',
#  'allenwest',
#  'game',
#  'brazilian',
#  'cdc',
#  'protester',
#  'david horowitz',
#  'catholic',
#  'snap',
#  'trump hater',
#  'lbj',
#  'clinton amp',
#  'baton rouge',
#  'realbencarson',
#  'fema',
#  'bolton',
#  'knowledge',
#  'stuart',
#  'jon',
#  'bill',
#  'melaniatrump',
#  'rowanne',
#  'lanny',
#  'cuba',
#  'flotus melania',
#  'campaign',
#  'brande',
#  'corrupt adam',
#  'ukraine',
#  'impeachment',
#  'cummings',
#  'union',
#  'woodward',
#  'marjorie',
#  'trump',
#  'fake news usa',
#  'win',
#  'ariemanuel',
#  'border patrol',
#  'secure',
#  'cap',
#  'pan handle',
#  'congress amp',
#  'jeffhorwitz',
#  'zegarelli',
#  'dummy billmaher',
#  'napolitano',
#  'radical left new york',
#  'blue ribbon commission',
#  'rakutentraveljp',
#  'buffett',
#  'chucktodd',
#  'trumpwaikiki',
#  'nato',
#  'lou dobbs',
#  'mccabes',
#  'howard',
#  'british',
#  'camp',
#  'hb',
#  'venezuela',
#  'loisweiss',
#  'sovereign',
#  'podesta',
#  'knicks',
#  'troy balderson',
#  'majority',
#  'rino ben sasse',
#  'great american',
#  'state department',
#  'washingtonpost',
#  'germany',
#  'repeal',
#  'chinavirus',
#  'opposition party',
#  'presient obama',
#  'unionleader',
#  'quinnipiacpoll',
#  'view',
#  'mccain',
#  'statesman',
#  'mistake',
#  'history',
#  'andy pettitte',
#  'poll',
#  'tlaib',
#  'lane',
#  'glenn',
#  'gm',
#  'trumplasvegas',
#  'ap',
#  'ivankatrump',
#  'obama campaign',
#  'iran nuke',
#  'congress house',
#  'tweet',
#  'tommy',
#  'vindman',
#  'open',
#  'jr',
#  'wsj',
#  'anything',
#  'iamstevent',
#  'bashar assad',
#  'dorian',
#  'fox news',
#  'ron estes',
#  'martin bashirdont',
#  'ken frazier',
#  'jonhuntsman',
#  'huffingtonpost',
#  'graydon',
#  'dishonest washington post',
#  'debate',
#  'po',
#  'big pharma',
#  'scandal',
#  'gun control',
#  'neither',
#  'nasty',
#  'blue wave',
#  'gov',
#  'max',
#  'head',
#  'doctor',
#  'seal',
#  'pres',
#  'guatemala',
#  'hotel amp',
#  'public',
#  'doralresort',
#  'vt',
#  'usdot',
#  'obamas irs',
#  'bruce willis',
#  'shirley',
#  'wsj wall street journal',
#  'dossier',
#  'demsi',
#  'unity',
#  'mccarthy',
#  'tax cut bill',
#  'troy',
#  'season',
#  'trumpferrypoint',
#  'sleazebag bashirlive',
#  'goangelo',
#  'small business',
#  'curtis stone',
#  'killer',
#  'marcos maidana',
#  'comeys',
#  'kevin',
#  'horrible',
#  'morty zuckerman',
#  'briankempga',
#  'kelly',
#  'nasa',
#  'john lewis',
#  'fentanyl',
#  'ebola',
#  'lamb',
#  'stevedoocy holy',
#  'economy',
#  'goal',
#  'middle eastern',
#  'white house counsel',
#  'fighter',
#  'muslim brotherhood',
#  'mariano rivera',
#  'graham',
#  'whitehouse',
#  'christopher',
#  'great',
#  'bobby jindal',
#  'congesswoman omar',
#  'jasonlewis',
#  'george osborne',
#  'hate',
#  'meetthepress',
#  'bidens',
#  'arab league',
#  'trumppanama',
#  'corrupt news',
#  'government',
#  'politics',
#  'gretchen',
#  'brennan',
#  'gary johnson',
#  'angelo',
#  'state senate',
#  'ukrainian',
#  'man',
#  'rahm emanuel',
#  'flake',
#  'snowden',
#  'city',
#  'cruz',
#  'pete',
#  'kennedy',
#  'hank greenberg',
#  'mitch',
#  'smilotweets',
#  'oscar',
#  'bensasse',
#  'montana',
#  'taiwan',
#  'pres obama',
#  'msnbc',
#  'mueller',
#  'zell',
#  'apprentice',
#  'comey amp',
#  'herschel',
#  'liberty',
#  'chairman amp',
#  'loser',
#  'italy',
#  'barry',
#  'senate intelligence committee',
#  'liljon',
#  'nobody',
#  'pennsylvania',
#  'hud',
#  'system',
#  'championship',
#  'john cahill',
#  'president',
#  'mattis',
#  'seanhannity',
#  'cbo',
#  'kremlin',
#  'judiciary committee',
#  'broke',
#  'sanctuary',
#  'kemp',
#  'xi jinping',
#  'politico',
#  'signature verification',
#  'leadership',
#  'men',
#  'biden',
#  'world',
#  'keith',
#  'fraud',
#  'top',
#  'governorperry',
#  'autism',
#  'govholcomb',
#  'trump collection',
#  'nj',
#  'brady',
#  'barackobama sr',
#  'ray',
#  'senschumer',
#  'cohens',
#  'politician',
#  'lindsey',
#  'senatecommerce',
#  'jeff zucker',
#  'mark zuckerberg',
#  'mesa',
#  'boehner',
#  'lester holt',
#  'tower',
#  'robert',
#  'charleshurt',
#  'true',
#  'wisdom',
#  'notice',
#  'wwe',
#  'tax increase',
#  'young',
#  'illegals',
#  'caravan',
#  'sean',
#  'harvard',
#  'total',
#  'crazy',
#  'barackobama mittromney',
#  'piece',
#  'dem john bell',
#  'schiff',
#  'huffington',
#  'mcconnell',
#  'unemployment',
#  'fusion gps',
#  'morning joe panel',
#  'concast',
#  'samuelljackson',
#  'tony la russa',
#  'clint',
#  'trumpdoral',
#  'cnns',
#  'waiver product',
#  'vanity fair',
#  'ukraine amp',
#  'hoaxsters',
#  'nbc',
#  'mercedesschlapp',
#  'michelle fischbachmn',
#  'amnesty',
#  'favorite',
#  'protestors',
#  'cnn',
#  'brooklyn',
#  'japan',
#  'extremist',
#  'atlanta',
#  'communist party',
#  'cbs',
#  'doug burgum',
#  'michael forbes',
#  'good',
#  'connecticut',
#  'durbin',
#  'newtown',
#  'dow',
#  'commission',
#  'michelle fischbach',
#  'kavanough',
#  'drew peterson',
#  'sue kruczek',
#  'roger penske',
#  'baker',
#  'newtgingrich',
#  'trump administration',
#  'wh counsel',
#  'obamacare amp',
#  'keep america safe',
#  'star',
#  'barrack obama',
#  'brave american',
#  'news',
#  'historic',
#  'joebiden',
#  'golf invitational',
#  'hurricane hanna',
#  'san francisco',
#  'south dakota',
#  'dope',
#  'control',
#  'breitbart',
#  'rick saccone',
#  'result',
#  'ethanol industry',
#  'eye',
#  'fisa',
#  'morocco',
#  'fast',
#  'stephenbaldwins',
#  'angela',
#  'chrysler',
#  'montgomery',
#  'strzok',
#  'climate',
#  'lockdown',
#  'lynda',
#  'energy',
#  'huckabee',
#  'dave',
#  'dailybeast',
#  'pennstate',
#  'faith',
#  'evers',
#  'common core',
#  'fisa court',
#  'celebrate',
#  'scott brown',
#  'kasich',
#  'trump intl washington dc',
#  'border amp',
#  'richard mourdock',
#  'complacent',
#  'need',
#  'abuse',
#  'syria amp',
#  'dennis',
#  'team hillary',
#  'djt foundation',
#  'strong border',
#  'weirdo tom steyer',
#  'grant',
#  'thereval',
#  'dishonest',
#  'rudygiuliani',
#  'upstate new york',
#  'sleepy joe biden',
#  'advantage',
#  'probe',
#  'pegula',
#  'nation',
#  'icig',
#  'piersmorgan',
#  'carrier',
#  'rnc',
#  'dave hughes',
#  'bill kristol',
#  'kay',
#  'miss usa',
#  'newsweek',
#  'jebbush',
#  'mayor',
#  'ne',
#  'wacko john brennan',
#  'endorsement',
#  'muslim',
#  'broken',
#  'tuckercarlson',
#  'bmw',
#  'dc',
#  'repub',
#  'treasury',
#  'ag lynch',
#  'anguilla',
#  'israel',
#  'ag schneiderman',
#  'highway',
#  'tom ridge',
#  'wacko john bolton',
#  'teamcavuto',
#  'executive chef',
#  'nordstrom',
#  'thomas binion',
#  'lee',
#  'jeb',
#  'secretarysonny',
#  'brent musburger',
#  'migop',
#  'foxsports',
#  'stacey abrams',
#  'harris',
#  'heroin',
#  'fendi casa',
#  'gas price',
#  'schumer',
#  'tv show',
#  'shifty',
#  'hudgov',
#  'order',
#  'rush limbaugh',
#  'steven',
#  'anthonyweiner',
#  'vp',
#  'tremendous',
#  'west point',
#  'golf',
#  'reg',
#  'mikepence',
#  'big',
#  'sebelius',
#  'usmca',
#  'jp morgan',
#  'ncgop',
#  'moderna',
#  'stephenmoore',
#  'nytimes',
#  'keystone pipeline',
#  'stimulus',
#  'death',
#  'coronavirus',
#  'terry',
#  'rutgers',
#  'tppatriots',
#  'fannie',
#  'medium',
#  'macmillers',
#  'conservative',
#  'coore',
#  'swing state',
#  'lobster',
#  'christian',
#  'jimbrownnfl',
#  'stephenbaldwin',
#  'emergency',
#  'acu',
#  'wta',
#  'christyforca',
#  'presidency',
#  'european union',
#  'matt',
#  'steyer',
#  'dailycaller',
#  'growth',
#  'kill',
#  'easy',
#  'fda',
#  'massive',
#  'post',
#  'republican establishment',
#  'liar',
#  'abc news',
#  'verizon',
#  'spy',
#  'danamira',
#  'funding',
#  'boxer',
#  'john kelly',
#  'rocky',
#  'iraq war',
#  'nypd surveillance program',
#  'new poll',
#  'request',
#  'baltimore police',
#  'drumstick',
#  'glenn simpson',
#  'rove',
#  'oprah winfrey',
#  'maniac',
#  'mittromney',
#  'jason',
#  'leakin',
#  'wiener',
#  'ronald',
#  'sony',
#  'philbryantms',
#  'kayleigh mcenany',
#  'steve',
#  'development bank',
#  'sandy',
#  'joan',
#  'troybalderson',
#  'solid',
#  'fake cnn',
#  'fracking',
#  'left',
#  'historic change',
#  'watergate',
#  'susan',
#  'fake news washington post',
#  'irs',
#  'labor',
#  'william quigley',
#  'ricksantorum',
#  'bishop',
#  'tmz harveylevintmz',
#  'african american unemployment',
#  'elton john',
#  'forbesinspector',
#  'nominee',
#  'jim',
#  'lady melania',
#  'jared kushner',
#  'usacehq',
#  'australia',
#  'mark esper',
#  'cnn amp',
#  'incompetent',
#  'thisweekabc',
#  'airplane',
#  'univision',
#  'doj amp',
#  'met',
#  'martin dempsey',
#  'sleepy',
#  'rio',
#  'new',
#  'blm',
#  'nydailynews',
#  'briankempga pennsylvania',
#  'record',
#  'crowd',
#  'establishment',
#  'nfl',
#  'rand',
#  'way',
#  'inflation',
#  'billmaher',
#  'att',
#  'jpmorgan',
#  'interview',
#  'rep',
#  'california gold',
#  'greenland',
#  'mcmaster',
#  'lou',
#  'curt schilling',
#  'great guy',
#  'billy long',
#  'repdandonovan',
#  'california amp',
#  'snoopdogg',
#  'al sisi',
#  'bullshit',
#  'bret',
#  'dark knight',
#  'thad',
#  'vanityfair',
#  'sanctuary city',
#  'terrific',
#  'low energy',
#  'swamp',
#  'drudge report',
#  'colin',
#  'shep',
#  'already',
#  'expedia',
#  'abc',
#  'cryin',
#  'house committee',
#  'navy',
#  'repubs',
#  'breitbartnews biden',
#  'vattenfallgroup',
#  'barack',
#  'delta',
#  'tonight',
#  'market',
#  'family',
#  'business',
#  'deplorables',
#  'kurd',
#  'obiden',
#  'shadey james comey',
#  'english',
#  'nba',
#  'bbc',
#  'al megrahi',
#  'trump rally',
#  'amaze',
#  'health insurance',
#  'maduro',
#  'ovation',
#  'obsma',
#  'florida state',
#  'tennessee',
#  'congressman',
#  'little bob corker',
#  'golf magazine',
#  'clapper',
#  'johnkasich',
#  'gop',
#  'spring',
#  'visa lottery',
#  'big ten football',
#  'tucker',
#  'local',
#  'trumpgolfdcs',
#  'adam schiffty schiff',
#  'dumb',
#  'adam shifty schiff',
#  'corrupt joe bidens',
#  'al capone',
#  'alabama',
#  'republican party',
#  'star apprenticenbc',
#  'donaldjtrumpjr',
#  'nice guy',
#  'big crowd',
#  'trump supporter',
#  'rate',
#  'architect',
#  'george bush',
#  'govwalker',
#  'tomorrow',
#  'pete dye',
#  'robert pattinson',
#  'traitor snowden',
#  'lamestream',
#  'barney frank',
#  'asia',
#  'china virus',
#  'sarah jessica parker',
#  'dirt',
#  'perduesenate',
#  'incredible',
#  'martin gugino',
#  'ny state',
#  'real',
#  'harvey',
#  'jewish',
#  'peterose',
#  'oprah',
#  'markwarnerva',
#  'anonymous',
#  'gov cuomo',
#  'tax',
#  'southern',
#  'immigration',
#  'swiss',
#  'clinton news network',
#  'time',
#  'senate',
#  'andersoncooper',
#  'rescue',
#  'girardi',
#  'law',
#  'nut job',
#  'jobless',
#  'criminal justice',
#  'weiner',
#  'goldberg',
#  'starbucks',
#  'communist',
#  'spending',
#  'european',
#  'egyptian',
#  'george',
#  'repadamschiff',
#  'non',
#  'trace',
#  'thegarybusey',
#  'jennifer',
#  'shelton school',
#  'michael isikoff',
#  'budget',
#  'speaker',
#  'tesla',
#  'donald duck',
#  'brand new',
#  'inspire',
#  'judy',
#  'yankeed',
#  'censor',
#  'wikileaks',
#  'antifa scum',
#  'catch',
#  'dems amp',
#  'henry ford health system',
#  'megynkelly',
#  'politically correct',
#  'france',
#  'ted nugent',
#  'weak',
#  'toyota',
#  'jefferson',
#  'room',
#  'trump parc stamford',
#  'news outlet',
#  'proud',
#  'rush',
#  'xi amp',
#  'josh',
#  'mariabartiromo',
#  'saudi',
#  'bain',
#  'sec',
#  'kamala harris',
#  'dineshdsouza',
#  'boston',
#  'liddle',
#  'celebapprentice',
#  'mini mike bloomberg',
#  'charles krauthammer',
#  'spain',
#  'committee',
#  'rosenstein',
#  'scottforflorida',
#  'website',
#  'princeton',
#  'john sununu',
#  'erin brady',
#  'nymag',
#  'jeep',
#  'ben',
#  'judd',
#  'msm',
#  'megan',
#  'hike',
#  'impeach',
#  'iranian',
#  'rep tlaib',
#  'cnbc',
#  'tiffany',
#  'jeter amp',
#  'kamalaharris',
#  'henrymcmaster',
#  'gabriel',
#  'melania trump',
#  'open border',
#  'usa',
#  'leezeldin',
#  'postal system',
#  'democrat',
#  'scaramucci',
#  'missusa',
#  'reality',
#  'petraeus',
#  'mccabe',
#  'hydroxychloroquine',
#  'ag barr',
#  'missuniverse',
#  'hizballah',
#  'jon ossof',
#  'frank',
#  'dateline nbc',
#  'morty zuckermans nydailynews',
#  'da nang',
#  'spell',
#  'angry democrat',
#  'pelosi',
#  'ed schultz',
#  'contesti',
#  'fake journalism',
#  'nelson',
#  'yankee',
#  'hogan',
#  'murielbowser',
#  'hire',
#  'richard',
#  'tripadvisor',
#  'united',
#  'nrcc digital',
#  'robb report',
#  'rjc',
#  'cooper',
#  'mlb',
#  'pol',
#  'tv',
#  'turnberry',
#  'lindseygrahamsc',
#  'mayor amp',
#  'federal court',
#  'herman',
#  'anndromney',
#  'service',
#  'reform',
#  'co',
#  'assad',
#  'rosie odonnell',
#  'un',
#  'republican house',
#  'louisiana',
#  'yates',
#  'allen',
#  'million',
#  'russia',
#  'release',
#  'homeland',
#  'vera',
#  'security',
#  'trumpsoho',
#  'spa',
#  'yuan',
#  'consumer sentiment',
#  'warner',
#  'gianna',
#  'nomination',
#  'mayorbowser',
#  'minneapolis city council',
#  'blackdog',
#  'barrett',
#  'question',
#  'crooked amp',
#  'trumpgolfla',
#  'dem ossoff',
#  'pastor brunson',
#  'boost',
#  'jonathan gruber',
#  'numerous',
#  'davidbrody',
#  'strong',
#  'heidi',
#  'sudan',
#  'crime',
#  'steve scully',
#  'vicente fox',
#  'dan sullivan',
#  'congresswoman wilsond',
#  'roger goodell',
#  'loudon',
#  'google',
#  'alec',
#  'el salvador',
#  'joke',
#  'king',
#  'blumenthal',
#  'duncan',
#  'volunteer',
#  'alex rodriguez',
#  'school',
#  'mike huckebee',
#  'letterman',
#  'trumpchicago',
#  'large',
#  'al',
#  'eric',
#  'voting',
#  'dicky durbin',
#  'genius',
#  'alexsalmond',
#  'hunter',
#  'barbarajwalters',
#  'champion',
#  'staff',
#  'reckless',
#  ...}
