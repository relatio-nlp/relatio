# %% [markdown]
# # An introduction to `relatio`
# **Runtime $\sim$ 20min**
#
# ----------------------------
#
# This is a short demo of the package `relatio`.  It takes as input a text corpus and outputs a list of narrative statements. The pipeline is unsupervised: the user does not need to specify narratives beforehand. Narrative statements are defined as tuples of semantic roles with a (agent, verb, patient, attribute) structure.
#
# Here, we present the main wrapper functions to quickly obtain narrative statements from a corpus.
#
# For further details, please refer to the paper: ["Text Semantics Capture Political and Economic Narratives"](https://arxiv.org/abs/2108.01720)
#
# ----------------------------
#
# We provide datasets that have already been split into sentences and annotated by our team.
#
# The datasets are provided in three different formats:
#  1. `raw` (unprocessed)
#  2. `split_sentences` (as a list of sentences)
#  3. `srl` (as a list of annotated sentences by the semantic role labeler)
#
# In this tutorial, we work with the Trump Tweet Archive corpus.
#
# ----------------------------

# %%
# Get list of available datasets

from relatio.datasets import list_datasets

print(list_datasets())

# Download Trump Tweet Archive in "raw" format

from relatio.datasets import load_trump_data

df = load_trump_data("raw")

print(df.head())
# Out:
#     List of available datasets:
#
#     Trump Tweet Archive
#     - function call: load_trump_data()
#     - format: 'raw', 'split_sentences', 'srl_res'
#     - allennlp version: 0.9
#     - srl model: srl-model-2018.05.25.tar.gz
#
#              id                                                doc
# 0  9.845497e+16  Republicans and Democrats have both created ou...
# 1  1.234653e+18  I was thrilled to be back in the Great city of...
# 2  1.304875e+18  The Unsolicited Mail In Ballot Scam is a major...
# 3  1.223641e+18            Getting a little exercise this morning!
# 4  1.215248e+18                                   Thank you Elise!

# %% [markdown]
# ## Step 1: Split into sentences
#
# ----------------------------
#
# For any new corpus, the first thing you will want to do is to split the corpus into sentences.
#
# We do this on the first 100 tweets.
#
# The output is two lists: one with an index for the document and one with the resulting split sentences.
#
# ----------------------------

# %%
from relatio.utils import split_into_sentences

split_sentences = split_into_sentences(
    df.iloc[0:100], progress_bar=True
)

for i in range(5):
    print('Document id: %s' %split_sentences[0][i])
    print('Sentence: %s \n' %split_sentences[1][i])
# Out:
# Splitting into sentences...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 346.16it/s]
# Document id: 9.84549706549166e+16
# Sentence: Republicans and Democrats have both created our economic problems.
#
# Document id: 1.23465342778907e+18
# Sentence: I was thrilled to be back in the Great city of Charlotte, North Carolina with thousands of hardworking American Patriots who love our Country, cherish our values, respect our laws, and always put AMERICA FIRST!
#
# Document id: 1.23465342778907e+18
# Sentence: Thank you for a wonderful evening!!
#
# Document id: 1.30487517086002e+18
# Sentence: The Unsolicited Mail In Ballot Scam is a major threat to our Democracy, &amp; the Democrats know it.
#
# Document id: 1.30487517086002e+18
# Sentence: Almost all recent elections using this system, even though much smaller &amp; with far fewer Ballots to count, have ended up being a disaster.

# %% [markdown]
# ## Step 2: Annotate semantic roles
#
# ----------------------------
#
# Once the corpus is split into sentences. You can feed it to the semantic role labeler.
#
# The output is a list of json objects which contain the semantic role annotations for each sentence in the corpus.
#
# ----------------------------

# %%
# Note that SRL is time-consuming, in particular on CPUs.
# To speed up the annotation, you can also use GPUs via the "cuda_device" argument of the "run_srl()" function. 

from relatio.wrappers import run_srl

srl_res = run_srl(
    path="https://storage.googleapis.com/allennlp-public-models/openie-model.2020.03.26.tar.gz", # pre-trained model
    sentences=split_sentences[1],
    progress_bar=True,
)
# Out:
# /home/germain/Desktop/narratives/relatio/venv/lib/python3.8/site-packages/allennlp/tango/__init__.py:17: UserWarning: AllenNLP Tango is an experimental API and parts of it might change or disappear every time we release a new version.
#   warnings.warn(
# 2021-09-20 13:52:47,222 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2021-09-20 13:52:47,503 - INFO - allennlp.common.file_utils - cache of https://storage.googleapis.com/allennlp-public-models/openie-model.2020.03.26.tar.gz is up-to-date
# 2021-09-20 13:52:47,505 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/openie-model.2020.03.26.tar.gz from cache at /home/germain/.allennlp/cache/60314a853eb0aaa774d176d878c62469d49872feb4f2bfd071a75c77f6d76707.1b91cc27e347f2df04ce771a304bee2b70a2c487626b67e277d44c593b868c25
# 2021-09-20 13:52:47,507 - INFO - allennlp.models.archival - extracting archive file /home/germain/.allennlp/cache/60314a853eb0aaa774d176d878c62469d49872feb4f2bfd071a75c77f6d76707.1b91cc27e347f2df04ce771a304bee2b70a2c487626b67e277d44c593b868c25 to temp dir /tmp/tmp_6r29oh3
# 2021-09-20 13:52:47,916 - INFO - allennlp.common.params - dataset_reader.type = srl
# 2021-09-20 13:52:47,916 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2021-09-20 13:52:47,917 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2021-09-20 13:52:47,917 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2021-09-20 13:52:47,917 - INFO - allennlp.common.params - dataset_reader.token_indexers = None
# 2021-09-20 13:52:47,918 - INFO - allennlp.common.params - dataset_reader.domain_identifier = None
# 2021-09-20 13:52:47,918 - INFO - allennlp.common.params - dataset_reader.bert_model_name = None
# 2021-09-20 13:52:47,918 - INFO - allennlp.common.params - dataset_reader.type = srl
# 2021-09-20 13:52:47,919 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2021-09-20 13:52:47,919 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2021-09-20 13:52:47,919 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2021-09-20 13:52:47,920 - INFO - allennlp.common.params - dataset_reader.token_indexers = None
# 2021-09-20 13:52:47,920 - INFO - allennlp.common.params - dataset_reader.domain_identifier = None
# 2021-09-20 13:52:47,920 - INFO - allennlp.common.params - dataset_reader.bert_model_name = None
# 2021-09-20 13:52:47,921 - INFO - allennlp.common.params - type = from_instances
# 2021-09-20 13:52:47,921 - INFO - allennlp.data.vocabulary - Loading token dictionary from /tmp/tmp_6r29oh3/vocabulary.
# 2021-09-20 13:52:47,980 - INFO - allennlp.common.params - model.type = srl
# 2021-09-20 13:52:47,981 - INFO - allennlp.common.params - model.regularizer = None
# 2021-09-20 13:52:47,981 - INFO - allennlp.common.params - model.ddp_accelerator = None
# 2021-09-20 13:52:47,982 - INFO - allennlp.common.params - model.text_field_embedder.type = ref
# 2021-09-20 13:52:47,983 - INFO - allennlp.common.params - model.text_field_embedder.type = basic
# 2021-09-20 13:52:47,984 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.type = ref
# 2021-09-20 13:52:47,985 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = embedding
# 2021-09-20 13:52:47,986 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.type = embedding
# 2021-09-20 13:52:47,986 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.embedding_dim = 100
# 2021-09-20 13:52:47,986 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.num_embeddings = None
# 2021-09-20 13:52:47,987 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.projection_dim = None
# 2021-09-20 13:52:47,987 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.weight = None
# 2021-09-20 13:52:47,987 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.padding_index = None
# 2021-09-20 13:52:47,988 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.trainable = True
# 2021-09-20 13:52:47,988 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.max_norm = None
# 2021-09-20 13:52:47,988 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.norm_type = 2.0
# 2021-09-20 13:52:47,989 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.scale_grad_by_freq = False
# 2021-09-20 13:52:47,989 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.sparse = False
# 2021-09-20 13:52:47,991 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.vocab_namespace = tokens
# 2021-09-20 13:52:47,991 - INFO - allennlp.common.params - model.text_field_embedder.token_embedders.tokens.pretrained_file = None
# 2021-09-20 13:52:48,067 - INFO - allennlp.common.params - model.encoder.type = alternating_lstm
# 2021-09-20 13:52:48,067 - INFO - allennlp.common.params - model.encoder.type = alternating_lstm
# 2021-09-20 13:52:48,068 - INFO - allennlp.common.params - model.encoder.input_size = 200
# 2021-09-20 13:52:48,068 - INFO - allennlp.common.params - model.encoder.hidden_size = 300
# 2021-09-20 13:52:48,069 - INFO - allennlp.common.params - model.encoder.num_layers = 8
# 2021-09-20 13:52:48,069 - INFO - allennlp.common.params - model.encoder.recurrent_dropout_probability = 0.1
# 2021-09-20 13:52:48,070 - INFO - allennlp.common.params - model.encoder.use_highway = True
# 2021-09-20 13:52:48,071 - INFO - allennlp.common.params - model.encoder.use_input_projection_bias = True
# 2021-09-20 13:52:48,071 - INFO - allennlp.common.params - model.encoder.stateful = False
# 2021-09-20 13:52:48,311 - INFO - allennlp.common.params - model.binary_feature_dim = 100
# 2021-09-20 13:52:48,312 - INFO - allennlp.common.params - model.embedding_dropout = 0.0
# 2021-09-20 13:52:48,312 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7f2d465a8250>
# 2021-09-20 13:52:48,313 - INFO - allennlp.common.params - model.label_smoothing = None
# 2021-09-20 13:52:48,313 - INFO - allennlp.common.params - model.ignore_span_metric = False
# 2021-09-20 13:52:48,313 - INFO - allennlp.common.params - model.srl_eval_path = /home/germain/Desktop/narratives/relatio/venv/lib/python3.8/site-packages/allennlp_models/structured_prediction/tools/srl-eval.pl
# 2021-09-20 13:52:48,315 - INFO - allennlp.nn.initializers - Initializing parameters
# 2021-09-20 13:52:48,317 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2021-09-20 13:52:48,317 - INFO - allennlp.nn.initializers -    binary_feature_embedding.weight
# 2021-09-20 13:52:48,318 - INFO - allennlp.nn.initializers -    encoder._module.layer_0.cell.input_linearity.bias
# 2021-09-20 13:52:48,318 - INFO - allennlp.nn.initializers -    encoder._module.layer_0.cell.input_linearity.weight
# 2021-09-20 13:52:48,318 - INFO - allennlp.nn.initializers -    encoder._module.layer_0.cell.state_linearity.bias
# 2021-09-20 13:52:48,319 - INFO - allennlp.nn.initializers -    encoder._module.layer_0.cell.state_linearity.weight
# 2021-09-20 13:52:48,319 - INFO - allennlp.nn.initializers -    encoder._module.layer_1.cell.input_linearity.bias
# 2021-09-20 13:52:48,319 - INFO - allennlp.nn.initializers -    encoder._module.layer_1.cell.input_linearity.weight
# 2021-09-20 13:52:48,320 - INFO - allennlp.nn.initializers -    encoder._module.layer_1.cell.state_linearity.bias
# 2021-09-20 13:52:48,320 - INFO - allennlp.nn.initializers -    encoder._module.layer_1.cell.state_linearity.weight
# 2021-09-20 13:52:48,320 - INFO - allennlp.nn.initializers -    encoder._module.layer_2.cell.input_linearity.bias
# 2021-09-20 13:52:48,321 - INFO - allennlp.nn.initializers -    encoder._module.layer_2.cell.input_linearity.weight
# 2021-09-20 13:52:48,321 - INFO - allennlp.nn.initializers -    encoder._module.layer_2.cell.state_linearity.bias
# 2021-09-20 13:52:48,321 - INFO - allennlp.nn.initializers -    encoder._module.layer_2.cell.state_linearity.weight
# 2021-09-20 13:52:48,322 - INFO - allennlp.nn.initializers -    encoder._module.layer_3.cell.input_linearity.bias
# 2021-09-20 13:52:48,322 - INFO - allennlp.nn.initializers -    encoder._module.layer_3.cell.input_linearity.weight
# 2021-09-20 13:52:48,322 - INFO - allennlp.nn.initializers -    encoder._module.layer_3.cell.state_linearity.bias
# 2021-09-20 13:52:48,323 - INFO - allennlp.nn.initializers -    encoder._module.layer_3.cell.state_linearity.weight
# 2021-09-20 13:52:48,323 - INFO - allennlp.nn.initializers -    encoder._module.layer_4.cell.input_linearity.bias
# 2021-09-20 13:52:48,323 - INFO - allennlp.nn.initializers -    encoder._module.layer_4.cell.input_linearity.weight
# 2021-09-20 13:52:48,324 - INFO - allennlp.nn.initializers -    encoder._module.layer_4.cell.state_linearity.bias
# 2021-09-20 13:52:48,324 - INFO - allennlp.nn.initializers -    encoder._module.layer_4.cell.state_linearity.weight
# 2021-09-20 13:52:48,325 - INFO - allennlp.nn.initializers -    encoder._module.layer_5.cell.input_linearity.bias
# 2021-09-20 13:52:48,325 - INFO - allennlp.nn.initializers -    encoder._module.layer_5.cell.input_linearity.weight
# 2021-09-20 13:52:48,325 - INFO - allennlp.nn.initializers -    encoder._module.layer_5.cell.state_linearity.bias
# 2021-09-20 13:52:48,326 - INFO - allennlp.nn.initializers -    encoder._module.layer_5.cell.state_linearity.weight
# 2021-09-20 13:52:48,326 - INFO - allennlp.nn.initializers -    encoder._module.layer_6.cell.input_linearity.bias
# 2021-09-20 13:52:48,326 - INFO - allennlp.nn.initializers -    encoder._module.layer_6.cell.input_linearity.weight
# 2021-09-20 13:52:48,327 - INFO - allennlp.nn.initializers -    encoder._module.layer_6.cell.state_linearity.bias
# 2021-09-20 13:52:48,327 - INFO - allennlp.nn.initializers -    encoder._module.layer_6.cell.state_linearity.weight
# 2021-09-20 13:52:48,327 - INFO - allennlp.nn.initializers -    encoder._module.layer_7.cell.input_linearity.bias
# 2021-09-20 13:52:48,328 - INFO - allennlp.nn.initializers -    encoder._module.layer_7.cell.input_linearity.weight
# 2021-09-20 13:52:48,328 - INFO - allennlp.nn.initializers -    encoder._module.layer_7.cell.state_linearity.bias
# 2021-09-20 13:52:48,328 - INFO - allennlp.nn.initializers -    encoder._module.layer_7.cell.state_linearity.weight
# 2021-09-20 13:52:48,329 - INFO - allennlp.nn.initializers -    tag_projection_layer._module.bias
# 2021-09-20 13:52:48,329 - INFO - allennlp.nn.initializers -    tag_projection_layer._module.weight
# 2021-09-20 13:52:48,329 - INFO - allennlp.nn.initializers -    text_field_embedder.token_embedder_tokens.weight
# 2021-09-20 13:52:48,333 - INFO - allennlp.modules.token_embedders.embedding - Loading a model trained before embedding extension was implemented; pass an explicit vocab namespace if you want to extend the vocabulary.
# 2021-09-20 13:52:48,370 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /tmp/tmp_6r29oh3
# Running SRL...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.91s/it]

# %%
# An example of SRL output

srl_res[0]
# Out:
# {'verbs': [{'verb': 'have',
#    'description': 'Republicans and Democrats [V: have] both created our economic problems .',
#    'tags': ['O', 'O', 'O', 'B-V', 'O', 'O', 'O', 'O', 'O', 'O']},
#   {'verb': 'created',
#    'description': '[ARG0: Republicans and Democrats] have both [V: created] [ARG1: our economic problems] .',
#    'tags': ['B-ARG0',
#     'I-ARG0',
#     'I-ARG0',
#     'O',
#     'O',
#     'B-V',
#     'B-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'O']}],
#  'words': ['Republicans',
#   'and',
#   'Democrats',
#   'have',
#   'both',
#   'created',
#   'our',
#   'economic',
#   'problems',
#   '.']}

# %%
# To save us some time, we download the results from the datasets module.

split_sentences = load_trump_data("split_sentences")
srl_res = load_trump_data("srl_res")

# %% [markdown]
# ## Step 3: Build the narrative model
#
# ----------------------------
#
# We are now ready to build a narrative model.
#
# The function `build_narrative_model` takes as input the split sentences the SRL annotations for the corpus. It builds a model of low-dimensional narrative statements which may then be used to obtain narrative statements  "out-of-sample".
#
# The function has sensible defaults for most arguments, but the user should at least specify:
# - the number of latent unnamed entities to recover (`n_clusters`)
# - the embeddings to be used (see here for further details)
#
# We specify 100 unnamed entities to uncover. The embeddings used are pre-trained glove embeddings.
#
# To speed up the model's training, we also focus on the top 100 most frequent named entities (the default is to mine all named entities).
#
# To improve interpretability, we remove common uninformative words in the corpus (the "stopwords"), as well as one-letter words.
#
# ----------------------------

# %%
# Get list of stopwords from SpaCy

import spacy
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

# NB: This step usually takes several minutes to run. You might want to grab a coffee.
 
from relatio.wrappers import build_narrative_model

narrative_model = build_narrative_model(
    srl_res=srl_res,
    sentences=split_sentences[1],
    embeddings_type="gensim_keyed_vectors",  # see documentation for a list of supported types
    embeddings_path="glove-wiki-gigaword-300",
    n_clusters=[[100]],
    top_n_entities=100,
    stop_words = spacy_stopwords,
    remove_n_letter_words = 1,
    progress_bar=True,
)
# Out:
# Processing SRL...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 68616/68616 [00:01<00:00, 39976.78it/s]
# Cleaning SRL...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 150213/150213 [01:07<00:00, 2223.05it/s]
# Computing role frequencies...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 150213/150213 [00:00<00:00, 985053.11it/s]
# Mining named entities...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 68616/68616 [05:40<00:00, 201.56it/s]
# Mapping named entities...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 150213/150213 [00:11<00:00, 13596.38it/s]
# 2021-09-20 14:02:25,795 - INFO - gensim.models.utils_any2vec - loading projection weights from /home/germain/gensim-data/glove-wiki-gigaword-300/glove-wiki-gigaword-300.gz
# Loading embeddings model...
# 2021-09-20 14:04:09,799 - INFO - gensim.models.utils_any2vec - loaded (400000, 300) matrix from /home/germain/gensim-data/glove-wiki-gigaword-300/glove-wiki-gigaword-300.gz
# /home/germain/Desktop/narratives/relatio/relatio/clustering.py:327: RuntimeWarning: Multiple labels for cluster 63- 2 shown: [('community', 29), ('fair', 29)]. First one is picked.
#   warnings.warn(
# /home/germain/Desktop/narratives/relatio/relatio/clustering.py:327: RuntimeWarning: Multiple labels for cluster 4- 2 shown: [('system', 58), ('information', 58)]. First one is picked.
#   warnings.warn(
# /home/germain/Desktop/narratives/relatio/relatio/clustering.py:327: RuntimeWarning: Multiple labels for cluster 53- 2 shown: [('tenacious', 15), ('stubborn', 15)]. First one is picked.
#   warnings.warn(
# /home/germain/Desktop/narratives/relatio/relatio/clustering.py:327: RuntimeWarning: Multiple labels for cluster 62- 2 shown: [('medicare', 14), ('fema', 14)]. First one is picked.
#   warnings.warn(
# 2021-09-20 14:07:28,636 - INFO - gensim.models.keyedvectors - precomputing L2-norms of word weight vectors

# %%
# The narrative model is simply a dictionary containing the narrative model's specifics.

print(narrative_model.keys())
# Out:
# dict_keys(['roles_considered', 'roles_with_entities', 'roles_with_embeddings', 'dimension_reduce_verbs', 'clean_text_options', 'verb_counts', 'entities', 'top_n_entities', 'embeddings_model', 'cluster_model', 'cluster_labels_most_similar', 'cluster_labels_most_freq'])

# %%
# Most common named entities

narrative_model['entities'].most_common()[:20]
# Out:
# [('democrat', 1476),
#  ('china', 929),
#  ('obama', 867),
#  ('american', 839),
#  ('republican', 837),
#  ('america', 558),
#  ('barackobama', 545),
#  ('united state', 476),
#  ('trump', 419),
#  ('dems', 415),
#  ('congress', 389),
#  ('russia', 386),
#  ('donald trump', 341),
#  ('iran', 328),
#  ('florida', 319),
#  ('cnn', 318),
#  ('usa', 314),
#  ('hillary', 308),
#  ('senate', 301),
#  ('hillary clinton', 287)]

# %%
# The unnamed entities uncovered in the corpus 
# (automatically labeled by the most frequent phrase in the cluster)

narrative_model['cluster_labels_most_freq']
# Out:
# [[{54: 'economy',
#    76: 'people',
#    97: 'stock market',
#    46: 'government',
#    84: 'fantastic',
#    86: 'email',
#    63: 'community',
#    70: 'day',
#    4: 'system',
#    90: 'vote',
#    95: 'disaster',
#    45: 'clue',
#    83: 'job',
#    0: 'kurd',
#    80: 'protester',
#    37: 'terrible',
#    47: 'thing',
#    65: 'flag',
#    21: 'fight',
#    82: 'election',
#    74: 'second amendment',
#    22: 'omarosa',
#    33: 'unemployment',
#    5: 'success',
#    15: 'amaze',
#    92: 'press',
#    3: 'global warm',
#    29: 'politician',
#    28: 'deal',
#    98: 'win',
#    77: 'bankrupt',
#    94: 'james comey',
#    42: 'ill',
#    87: 'courage',
#    50: 'life',
#    81: 'politically correct',
#    2: 'fraud',
#    12: 'president',
#    10: 'pocahontas',
#    7: 'hell',
#    31: 'twitter',
#    11: 'question',
#    25: 'man',
#    59: 'business',
#    35: 'city',
#    85: 'baltimore',
#    58: 'collusion',
#    36: 'terrorist',
#    8: 'case',
#    9: 'safe',
#    60: 'fine',
#    26: 'tv',
#    32: 'problem',
#    27: 'john bolton',
#    23: 'military',
#    43: 'crime',
#    38: 'transcript',
#    49: 'rod',
#    78: 'honor',
#    69: 'word',
#    61: 'ventilator',
#    16: 'crazy',
#    96: 'leader',
#    19: 'kim jong un',
#    53: 'tenacious',
#    51: 'nytimes',
#    66: 'medium',
#    40: 'money',
#    14: 'million',
#    24: 'best',
#    64: 'golf',
#    17: 'god',
#    57: 'comey',
#    91: 'obstructionist',
#    34: 'mess',
#    41: 'john',
#    89: 'jeb',
#    88: 'corrupt',
#    72: 'schiff',
#    30: 'swamp',
#    79: 'wall',
#    93: 'oil',
#    48: 'illegal immigrant',
#    1: 'story',
#    20: 'record',
#    56: 'tax',
#    75: 'team',
#    18: 'proud',
#    55: 'whistleblower',
#    6: 'school',
#    99: 'rosie',
#    62: 'medicare',
#    44: 'construction',
#    73: 'car',
#    68: 'nation',
#    52: 'november',
#    39: 'alternative',
#    13: 'farmer',
#    67: 'negative',
#    71: 'cruz'}]]

# %% [markdown]
# ----------------------------
#
# In practice, `build_narrative_model` is a flexible wrapper function which gives a lot of control to the user.
#
# Let's break the options down into four categories:
#
# 1. Basic utilities
#     - the semantic roles you're interested in (`roles_considered`)
#     - where you would like to save the model (`output_path`)
#     - whether you cant to track the function's progress (`progress_bar`)
#
#
# 2. Text preprocessing
#     - basic text preprocessing steps
#     (`remove_punctuation`, `remove_digits`, remove `stop_words`, `stem` or `lemmatize` words, etc.)
#     - would you like to replace verbs by their most common synonyms/antonyms? (`dimension_reduce_verbs`)
#
#
# 3. Named entities
#     - which semantic roles have named entities? (`roles_with_entities`)
#     - how many named entities would you like to keep? (`top_n_entities`)
#
# Technical details: under the hood, we work with SpaCy named entity recognizer to identify named entities.
# We consider tags related to places, organizations, people and events.
#
#
# 4. Unnamed entities (e.g., tax, government, dog, cat, etc.)
#     - which semantic roles have unnamed entities? (`roles_with_embeddings`)
#     - how many latent unnamed entities are there in the corpus? (`n_clusters`)
#
# Technical details: under the hood, we embed semantic phrases without named entities and cluster them with
# K-Means.
#
# ----------------------------

# %% [markdown]
# ## Step 4: Get narrative statements based on the narrative model.
#
# ----------------------------
#
# Once the narrative model is built, we can use it to extract narrative statements from any corpus (provided that the
# corpus is split into sentences and annotated for semantic roles).
#
# We call the function `get_narratives` for this purpose.
#
# ----------------------------

# %%
from relatio.wrappers import get_narratives

final_statements = get_narratives(
    srl_res=srl_res,
    doc_index=split_sentences[0],  # doc names
    narrative_model=narrative_model,
    n_clusters=[0],  
    progress_bar=True,
)
# Out:
# Processing SRL...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 68616/68616 [00:01<00:00, 39042.84it/s]
# Cleaning SRL...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 150213/150213 [01:18<00:00, 1923.34it/s]
# Processing raw arguments...
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 150213/150213 [00:00<00:00, 1054245.06it/s]
# Cleaning verbs...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 150213/150213 [00:02<00:00, 66995.87it/s]
# Mapping named entities...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 150213/150213 [00:11<00:00, 13232.48it/s]
# Assigning clusters to roles...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 150213/150213 [00:29<00:00, 5153.31it/s]

# %%
# The resulting pandas dataframe

print(final_statements.columns)

final_statements.head()
# Out:
# Index(['doc', 'sentence', 'statement', 'ARG0_highdim', 'ARG0_lowdim',
#        'B-V_highdim', 'B-V_lowdim', 'B-ARGM-NEG_highdim', 'B-ARGM-NEG_lowdim',
#        'B-ARGM-MOD_highdim', 'ARG1_highdim', 'ARG1_lowdim', 'ARG2_highdim',
#        'ARG2_lowdim'],
#       dtype='object')
#                    doc  sentence  statement         ARG0_highdim ARG0_lowdim  \
# 0    98454970654916608         0          0
# 1    98454970654916608         0          1  republican democrat  republican
# 2  1234653427789070336         1          2
# 3  1234653427789070336         1          3
# 4  1234653427789070336         1          4
#
#   B-V_highdim B-V_lowdim B-ARGM-NEG_highdim B-ARGM-NEG_lowdim  \
# 0
# 1      create     create
# 2
# 3      thrill     thrill
# 4
#
#   B-ARGM-MOD_highdim      ARG1_highdim ARG1_lowdim  \
# 0
# 1                     economic problem     economy
# 2
# 3
# 4
#
#                                         ARG2_highdim     ARG2_lowdim
# 0
# 1
# 2  thrill great city charlotte north carolina tho...  north carolina
# 3  great city charlotte north carolina thousand h...  north carolina
# 4                great city charlotte north carolina  north carolina

# %% [markdown]
# ### Trying out different clustering scenarios
#
# The choice of the number of clusters is corpus and application specific. Specifying a small number of latent entities leads to a large dimension reduction and may decrease entity coherence, whilst specifying a large number of latent entities may produce cluster redundancy.
#
# To help users try different clustering scenarios, the wrapper functions `build_narrative_model` and `get_narratives` allow users to experiment various clustering scenarios, which we detail below.
#
# ----------------------------
#
# In `build_narrative_model`, the arguments `roles_with_embeddings` and `n_clusters` are specified as lists of lists arguments. This implies that you can cluster semantic roles separately (or together) and with different numbers of clusters.
#
# For example, a user could specify:
# - `roles_with_embeddings = [["ARG0"],["ARG1"]]`
# - `n_clusters = [[10,20],[10]]`
#
# He/she would then cluster "ARG0" and "ARG1" separately and not consider "ARG2" for dimension reduction. For "ARG0", the clustering scenarios are a model with 10 and a model with 20 clusters. For "ARG1", the clustering scenario is a model with 10 clusters.
#
#
# ----------------------------
#
# To extract narrative statements based on a clustering scenario, the `get_narratives` function also has the
# `n_clusters` argument.
#
# `n_clusters` is a list for the clustering scenarios. For instance, in our previous example,
# semantic roles "ARG0" and "ARG1" are clustered separately, so `n_clusters` expects two indices: one for the
# clustering scenario to pick for "ARG0" and one for the clustering scenario to pick for "ARG1".
#
# For example, a user could specify:
# - `n_clusters = [0,0]`
#
# He/she would then extract narrative statements based on 10 clusters for "ARG0" and 10 clusters for "ARG1".
#
# ----------------------------

# %% [markdown]
# ## Step 5: Model validation and basic analysis
#
# ----------------------------
#
# The resulting `final_statments` object is a pandas dataframe which lists narrative statements found in documents and
# sentences of the corpus.
#
# It is straight-forward to manually inspect the quality of the resulting entities and narrative statements.
#
# ----------------------------

# %%
# Entity coherence
# Print most frequent phrases per entity

# Pool ARG0, ARG1 and ARG2 together

df1 = final_statements[['ARG0_lowdim', 'ARG0_highdim']]
df1.rename(columns={'ARG0_lowdim': 'ARG', 'ARG0_highdim': 'ARG-RAW'}, inplace=True)

df2 = final_statements[['ARG1_lowdim', 'ARG1_highdim']]
df2.rename(columns={'ARG1_lowdim': 'ARG', 'ARG1_highdim': 'ARG-RAW'}, inplace=True)

df3 = final_statements[['ARG2_lowdim', 'ARG2_highdim']]
df3.rename(columns={'ARG2_lowdim': 'ARG', 'ARG2_highdim': 'ARG-RAW'}, inplace=True)

df = df1.append(df2).reset_index(drop = True)
df = df.append(df3).reset_index(drop = True)

# Count semantic phrases

df = df.groupby(['ARG', 'ARG-RAW']).size().reset_index()
df.columns = ['ARG', 'ARG-RAW', 'count']

# Drop empty semantic phrases

df = df[df['ARG'] != ''] 

# Rearrange the data

df = df.groupby(['ARG']).apply(lambda x: x.sort_values(["count"], ascending = False))
df = df.reset_index(drop= True)
df = df.groupby(['ARG']).head(10)

df['ARG-RAW'] = df['ARG-RAW'] + ' - ' + df['count'].astype(str)
df['cluster_elements'] = df.groupby(['ARG'])['ARG-RAW'].transform(lambda x: ' | '.join(x))

df = df.drop_duplicates(subset=['ARG'])

df['cluster_elements'] = [', '.join(set(i.split(','))) for i in list(df['cluster_elements'])]

print('Entities to inspect:', len(df))

df = df[['ARG', 'cluster_elements']]
# Out:
# /home/germain/Desktop/narratives/relatio/venv/lib/python3.8/site-packages/pandas/core/frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# Entities to inspect: 196

# %%
for l in df.values.tolist():
    print('entity: \n %s \n' % l[0])
    print('most frequent phrases: \n %s \n' % l[1])
# Out:
# entity:
#  abc
#
# most frequent phrases:
#  abc - 16 | abc news - 4 | abc debate - 3 | people lose money stock market point base false dishonest reporting brian ross abc news suspend - 3 | abc washington post poll - 3 | fake news cnn msdnc abc nbc cbs fox desperately amp foolishly plead politically correct nytimes amp washingtonpost - 2 | big new abc poll - 2 | fake abc news - 2 | lonely brian ross abc news - 1 | lead big new abc poll week - 1
#
# entity:
#  administration
#
# most frequent phrases:
#  administration - 125 | obama administration - 59 | trump administration - 34 | previous administration - 8 | president administration - 5 | past administration - 4 | ig spent year obama administration report fail hn swine flu debacle people die - 3 | bloomberg administration - 3 | administration history country - 3 | trump administration anti trust division - 3
#
# entity:
#  alabama
#
# most frequent phrases:
#  alabama - 24 | great state alabama - 3 | people alabama - 3 | alabama receive hurt - 2 | miss alabama katherinewebb - 2 | plus treatment great state alabama wonderful people devastate tornado - 2 | florida georgia south carolina north carolina alabama possibly come play true - 2 | alabama primary race - 2 | great state alabama wonderful people devastate tornado - 2 | miss alabama katherine webb - 1
#
# entity:
#  alternative
#
# most frequent phrases:
#  alternative - 10 | substantially - 7 | flexible - 6 | harder - 5 | tougher - 5 | tougher smarter - 4 | faster - 4 | smarter - 4 | cleaner - 3 | car substantially safer - 3
#
# entity:
#  amaze
#
# most frequent phrases:
#  amaze - 114 | impeach - 14 | devastate - 12 | embarrass - 10 | amaze job - 9 | amaze people - 8 | highly overrate - 7 | defund police - 7 | obstruct - 6 | impeach president - 4
#
# entity:
#  america
#
# most frequent phrases:
#  america - 681 | america safe - 24 | copy book cripple america - 5 | rich bleeding america dry - 4 | big celebration history country salute america day event lincoln memorial culminate large scale flyover modern - 4 | cripple america - 3 | envy man america - 3 | america dry - 3 | job america - 3 | america work - 3
#
# entity:
#  american
#
# most frequent phrases:
#  american - 211 | american people - 101 | american dream - 20 | american worker - 20 | american public - 17 | african american - 16 | american patriot - 13 | american hero - 13 | million american - 12 | native american - 11
#
# entity:
#  apprenticenbc
#
# most frequent phrases:
#  apprenticenbc - 22 | star celebrity apprenticenbc - 9 | star apprenticenbc - 8 | sunday live finale apprenticenbc - 3 | apprenticenbc champion - 2 | week episode celebrity apprenticenbc - 2 | new apprenticenbc - 2 | apprenticenbc veteran george ross bretmichaels boardroom - 2 | apprenticenbc amp - 2 | premiere apprenticenbc - 1
#
# entity:
#  arizona
#
# most frequent phrases:
#  arizona - 20 | great state arizona - 2 | martha mcsally run arizona primary senate - 2 | governor dougducey arizona - 2 | sen jeff flakey unelectable great state arizona quit race anemic poll - 2 | brave fighter jet pilot warrior senator martha mcsally arizona - 2 | resort arizona - 2 | alaska arizona maine kentucky - 1 | pleased announce nomination barbara barrett arizona chairman aerospace corporation secretary air force - 1 | jeff flake set record low polling number arizona humiliatingly force senate seat fight nt clue - 1
#
# entity:
#  baltimore
#
# most frequent phrases:
#  baltimore - 16 | colorado - 14 | portland - 12 | indiana - 12 | boston killer - 11 | missouri - 10 | chicago - 10 | kentucky - 9 | tennessee - 8 | seattle - 7
#
# entity:
#  bankrupt
#
# most frequent phrases:
#  bankrupt - 36 | fortune - 34 | amp - 30 | apple - 26 | mini mike bloomberg - 20 | dow - 16 | ag - 13 | bankruptcy - 12 | parent - 11 | boeing - 10
#
# entity:
#  barackobama
#
# most frequent phrases:
#  barackobama - 440 | barackobama campaign - 9 | barackobama policy - 4 | barackobama birth certificate - 3 | barackobama recovery - 3 | habitual vacationer barackobama - 3 | able barackobama college law school application transcript - 2 | barackobama regret ask tax record - 2 | barackobama press secretary - 2 | china best friend barackobama - 2
#
# entity:
#  bernie
#
# most frequent phrases:
#  bernie - 39 | crazy bernie - 14 | bernie supporter - 6 | away bernie - 4 | hillary bernie - 4 | deal bernie - 3 | crazy bernie democrat - 2 | bernie people - 2 | good friend lawrence tabas amp bernadette bernie comfort - 2 | bernie voter - 2
#
# entity:
#  bernie sander
#
# most frequent phrases:
#  bernie sander - 54 | crazy bernie sander - 11 | bernie sander supporter - 3 | elizabeth warren race super tuesday crazy bernie sander win virtually state blowout close - 2 | crazy bernie sander sleepy joe biden finalist run maybe best economy history country great thing - 2 | castro lover bernie sander - 2 | write pact bernie sander amp sleepy joe - 2 | bernie sander democrat nomination - 1 | bernie sander endorse crooked hillary clinton - 1 | far left crazy bernie sander thought possible - 1
#
# entity:
#  best
#
# most frequent phrases:
#  best - 135 | apprentice - 51 | successful - 43 | celebrity apprentice - 39 | hero - 38 | veteran - 37 | star - 27 | young entrepreneur - 20 | career - 18 | young people - 9
#
# entity:
#  biden
#
# most frequent phrases:
#  biden - 195 | hunter biden - 11 | biden democrat - 9 | obama biden - 4 | biden scandal - 4 | biden obama - 4 | vote biden - 4 | obama amp biden - 3 | biden corruption - 3 | biden amp harris - 3
#
# entity:
#  bill
#
# most frequent phrases:
#  bill - 87 | bill clinton - 14 | tax cut bill - 7 | crime bill - 7 | defense bill - 5 | bill oreilly - 5 | farm bill - 4 | bill barr - 4 | bill nelson - 4 | massive tax cut bill - 3
#
# entity:
#  border
#
# most frequent phrases:
#  border - 153 | southern border - 39 | open border - 33 | border wall - 19 | strong crime border - 13 | strong border - 12 | border patrol - 9 | strong crime border second amendment - 9 | party high tax high crime open border late term abortion socialism blatant corruption - 4 | tough crime strong border - 4
#
# entity:
#  border security
#
# most frequent phrases:
#  border security - 40 | strong border security - 7 | border security wall - 5 | wall border security - 4 | necessary strong border security - 4 | border security military - 3 | border security amp wall - 3 | security wall southern border - 2 | tough border security tough - 2 | real border security - 2
#
# entity:
#  breitbartnews
#
# most frequent phrases:
#  breitbartnews - 3 | breitbartnews biden - 2 | likely democrat stole election breitbartnews rig election - 2 | absolutely right pardon michael flynn breitbartnews - 1 | kanye west trump want great president black american breitbartnews - 1 | trust promise eye voting process breitbartnews nt rely briankempga - 1 | trump want great president black american breitbartnews - 1 | tough smart new voice breitbartnews maybe - 1 | spy occur trump campaign breitbart breitbartnews - 1 | rioter state breitbartnews - 1
#
# entity:
#  bush
#
# most frequent phrases:
#  jeb bush - 46 | bush - 26 | george bush - 3 | bush family - 3 | life barbara bush - 2 | jeb bush george george hw - 2 | jeb bush campaign manager - 2 | president george hw bush - 2 | fan bush reason - 2 | george bush sends soldier combat severely wound - 1
#
# entity:
#  business
#
# most frequent phrases:
#  business - 132 | company - 108 | product - 39 | trade - 38 | trade deal - 21 | small business - 19 | bad trade deal - 13 | good business - 12 | firm - 11 | drug company - 11
#
# entity:
#  california
#
# most frequent phrases:
#  california - 45 | california great - 4 | california wildfire - 4 | governor california - 4 | state california - 3 | governor gavinnewsom california - 3 | california governor jerry brown - 2 | california sanctuary policy - 2 | grandstand governor california - 2 | california dangerous policy - 2
#
# entity:
#  canada
#
# most frequent phrases:
#  canada - 31 | mexico canada - 6 | mexico canada united state - 3 | mexico amp canada - 3 | canada pm - 3 | ally canada - 3 | united state mexico canada - 2 | canada surplus usnegotiating - 2 | pm justin trudeau canada - 2 | jenna talackovadoes miss universe canada - 2
#
# entity:
#  car
#
# most frequent phrases:
#  car - 25 | mini mike - 23 | caravan - 18 | brand - 13 | chrysler - 12 | ford - 10 | fiat chrysler - 9 | factory - 9 | manufacturer - 9 | car company - 8
#
# entity:
#  case
#
# most frequent phrases:
#  case - 85 | lawyer - 57 | court - 53 | impeachment - 47 | investigation - 40 | judge - 32 | justice - 29 | witness - 27 | trial - 27 | evidence - 25
#
# entity:
#  china
#
# most frequent phrases:
#  china - 577 | china virus - 13 | deal china - 7 | president xi china - 6 | president xi jinping china - 4 | china time poorly - 4 | china europe - 4 | china economy - 4 | trade china - 4 | tough china - 3
#
# entity:
#  chinese
#
# most frequent phrases:
#  chinese - 40 | chinese virus - 5 | chinese official - 3 | chinese company - 3 | chinese government - 2 | chinese company huawei buy product impact national security - 2 | chinese company huawei - 2 | servant chinese - 2 | allow chinese company huawei buy product impact national security - 2 | chinese company huawei buy product - 2
#
# entity:
#  city
#
# most frequent phrases:
#  city - 47 | thousand people - 26 | thousand - 25 | opposite - 18 | site - 13 | area - 13 | hospital - 11 | bar - 11 | section - 11 | hotel - 9
#
# entity:
#  clinton
#
# most frequent phrases:
#  hillary clinton - 120 | clinton - 33 | clinton campaign - 10 | obama clinton - 6 | obama amp clinton - 4 | defeat hillary clinton crony - 4 | hillary clinton crony - 4 | hillary clinton campaign - 4 | clinton team - 3 | clinton camp - 3
#
# entity:
#  clue
#
# most frequent phrases:
#  clue - 71 | careful - 46 | correct - 29 | classify information - 16 | detail - 14 | fault - 14 | bad judgement - 9 | acceptable - 9 | accurate - 8 | signature verification - 7
#
# entity:
#  cnn
#
# most frequent phrases:
#  cnn - 137 | cnn rating - 4 | cnn amp msdnc - 4 | cnn poll - 3 | msnbc amp cnn - 3 | fake cnn - 3 | new cnn poll - 2 | hatred extreme bias cnn - 2 | cnn international - 2 | cnn msnbc - 2
#
# entity:
#  collusion
#
# most frequent phrases:
#  collusion - 68 | disgrace - 21 | bias - 14 | shame - 9 | deepest condolence - 9 | outrage - 8 | disgust - 8 | travesty - 7 | anger - 7 | hatred - 6
#
# entity:
#  comey
#
# most frequent phrases:
#  comey - 37 | snowden - 26 | elijah cummings - 12 | graydon carter - 11 | mccabe - 10 | bret - 9 | mitch - 9 | brett kavanaugh - 7 | dennis rodman - 6 | bruce ohr - 5
#
# entity:
#  community
#
# most frequent phrases:
#  fair - 29 | community - 29 | progress - 19 | relationship - 16 | freedom - 16 | big progress - 16 | priority - 13 | foundation - 12 | path - 11 | tremendous progress - 11
#
# entity:
#  complete
#
# most frequent phrases:
#  complete total endorsement - 216 | complete amp total endorsement - 23 | complete endorsement - 13 | complete total disaster - 7 | complete disaster - 7 | complete - 6 | total complete endorsement - 4 | complete failure - 4 | agreement immigration complete - 2 | complete deal - 2
#
# entity:
#  congress
#
# most frequent phrases:
#  congress - 245 | democrat congress - 26 | dems congress - 6 | republican democrat congress - 5 | tom congress - 4 | new congress - 4 | republican congress - 4 | zero work congress - 3 | radical left democrat congress - 3 | regulation circulate include contemplate congress - 3
#
# entity:
#  construction
#
# most frequent phrases:
#  construction - 17 | plant - 16 | building - 13 | infrastructure - 11 | built - 10 | project - 8 | new plant - 8 | massive - 8 | renovation - 6 | capacity - 6
#
# entity:
#  cont
#
# most frequent phrases:
#  cont - 19 | bho school cont - 2 | president concerned pursue sort bizarre ideological cont - 2 | zero chance win cont - 2 | yuan overtake dollar international cont - 2 | like knicks found new point guard cont - 1 | pre exist medical cont - 1 | sell oil china cont - 1 | salary cont - 1 | republican cont - 1
#
# entity:
#  coronavirus
#
# most frequent phrases:
#  coronavirus - 25 | coronavirus situation - 4 | vaccine coronavirus - 4 | coronavirus origin - 3 | coronavirus number - 3 | plan coronavirus talk - 2 | congress distract phony impeachment witch hunt investigate coronavirus appear china - 2 | coronavirus start china spread country world slowly president trump close border end flight early - 2 | mr trump coronavirus update - 2 | million people dead coronavirus - 2
#
# entity:
#  corrupt
#
# most frequent phrases:
#  corrupt - 32 | dishonest medium - 21 | dishonest - 18 | corrupt medium - 16 | incompetent - 14 | accountable - 8 | totally corrupt - 5 | totally dishonest - 5 | dishonest today - 4 | inept - 4
#
# entity:
#  courage
#
# most frequent phrases:
#  courage - 22 | respect - 18 | instinct - 17 | sense - 14 | passion - 12 | spirit - 10 | prevail - 9 | fairness - 9 | ego - 9 | destiny - 9
#
# entity:
#  crazy
#
# most frequent phrases:
#  crazy - 66 | fool - 33 | stupid - 31 | joke - 28 | sad - 25 | ridiculous - 22 | pathetic - 18 | goofy elizabeth warren - 14 | total joke - 12 | dumb - 11
#
# entity:
#  crime
#
# most frequent phrases:
#  crime - 131 | charge - 33 | corruption - 21 | criminal - 18 | obstruction - 17 | jail - 17 | guilty - 14 | prison - 13 | innocent people - 10 | collusion obstruction - 9
#
# entity:
#  crooked hillary
#
# most frequent phrases:
#  crooked hillary - 127 | crooked hillary clinton - 92 | crooked hillary win - 5 | democrat crooked hillary - 4 | crooked hillary clinton democrat - 4 | dems crooked hillary - 3 | totally crooked hillary - 3 | stop crooked hillary clinton - 2 | crooked hillary try hard - 2 | crooked hillary investigation - 2
#
# entity:
#  cruz
#
# most frequent phrases:
#  cruz - 27 | puerto rico - 24 | marco rubio - 23 | lightweight senator marco rubio - 11 | la vega - 9 | angelo - 7 | oscar - 7 | people puerto rico - 6 | mark cuban - 6 | mar lago - 6
#
# entity:
#  day
#
# most frequent phrases:
#  day - 62 | speech - 51 | meeting - 49 | today - 48 | late - 35 | start - 27 | begin - 22 | rally - 21 | news conference - 20 | week - 16
#
# entity:
#  dc
#
# most frequent phrases:
#  dc - 35 | washington dc - 9 | dc police - 5 | trump intl washington dc - 4 | trump national golf club washington dc - 4 | wonderful washington dc - 2 | incompetent mayor washington dc mayorbowser - 2 | dc press corp - 2 | dc post office - 2 | dc fine hotel - 2
#
# entity:
#  deal
#
# most frequent phrases:
#  deal - 226 | process - 34 | negotiation - 34 | shutdown - 27 | big deal - 24 | peace - 21 | solution problem - 20 | nafta - 19 | agreement - 17 | contract - 15
#
# entity:
#  democrat
#
# most frequent phrases:
#  democrat - 1004 | radical left democrat - 61 | democrat party - 25 | angry democrat - 21 | obstructionist democrat - 12 | democrat vote - 8 | democrat scam - 7 | democrat run city - 7 | democrat nomination - 6 | democrat governor - 6
#
# entity:
#  dems
#
# most frequent phrases:
#  dems - 421 | radical left dems - 8 | dems swing district - 4 | schumer dems - 3 | nadler dems - 3 | mini mike bloomberg fool dems debate stage elizabeth warren amp simply apart - 3 | dems unlikely budge election year - 2 | dems case - 2 | dems citizen issue - 2 | dems corruption - 2
#
# entity:
#  disaster
#
# most frequent phrases:
#  disaster - 107 | help - 57 | charity - 26 | badly - 25 | desperate - 23 | total disaster - 17 | effort - 16 | aid - 13 | national emergency - 10 | relief - 7
#
# entity:
#  dnc
#
# most frequent phrases:
#  dnc - 30 | dnc server - 11 | crooked hillary dnc - 5 | crooked hillary amp dnc - 4 | dnc convention - 3 | crooked hillary clinton dnc - 3 | story like real story russia clinton amp dnc - 2 | result election impact change russian collusion russia crooked dnc dems - 2 | democrat operative dnc crooked hillary clinton - 2 | dnc democrat crooked hillary - 2
#
# entity:
#  donald trump
#
# most frequent phrases:
#  donald trump - 204 | president donald trump - 8 | donald trump signature collection tie amp shirt - 5 | donald trump campaign - 3 | support donald trump - 2 | favorite donald trump impersonator - 2 | hit song donald trump bonanza - 2 | donald trump signature mattress serta - 2 | donald trump signature collection - 2 | president donald trump commission school safety - 2
#
# entity:
#  economy
#
# most frequent phrases:
#  economy - 212 | strong - 115 | momentum - 39 | weak - 29 | growth - 18 | confidence - 15 | weakness - 13 | demand - 11 | recovery - 10 | consumer confidence - 10
#
# entity:
#  election
#
# most frequent phrases:
#  election - 265 | campaign - 117 | candidate - 49 | governor - 46 | elect - 33 | total endorsement - 31 | endorsement - 30 | presidential candidate - 24 | mayor - 21 | presidential - 21
#
# entity:
#  email
#
# most frequent phrases:
#  email - 44 | service - 24 | phone - 21 | mail - 18 | card - 17 | mail ballot - 16 | info - 14 | ticket - 13 | check - 9 | desk - 8
#
# entity:
#  fake news
#
# most frequent phrases:
#  fake news - 362 | fake news medium - 206 | fake news cnn - 23 | fake news nytimes - 8 | fake news medium partner democrat party - 7 | fake news medium democrat partner - 4 | fake news cnn msdnc - 4 | fake amp corrupt news - 4 | fake corrupt news - 4 | fake news partner radical left democrat - 3
#
# entity:
#  fantastic
#
# most frequent phrases:
#  fantastic - 65 | terrific - 41 | fantastic job - 37 | incredible - 31 | wonderful - 23 | incredible job - 17 | perfect - 15 | unbelievable - 14 | wonderful people - 11 | spectacular - 10
#
# entity:
#  farmer
#
# most frequent phrases:
#  farmer - 48 | citizen - 34 | worker - 27 | employee - 16 | wind farm - 15 | unemployed - 11 | migrant - 8 | employer - 8 | hispanic - 7 | incredible farmer - 6
#
# entity:
#  fbi
#
# most frequent phrases:
#  fbi - 120 | department justice fbi - 7 | fbi agent - 6 | fbi director - 6 | fbi lover agent lisa page - 4 | fbi brass - 4 | fbi doj - 4 | job fbi director - 4 | fbi law enforcement - 4 | justice department fbi - 3
#
# entity:
#  fed
#
# most frequent phrases:
#  fed - 77 | fed rate - 5 | fed reckless policy low interest flood market dollar - 2 | strong dollar weak fed - 2 | fed interest rate way high - 2 | fed high interest rate level - 2 | fed gotten right - 2 | jay powell fed - 1 | fed recklessness - 1 | fed tighten wait long undo mistake - 1
#
# entity:
#  federal government
#
# most frequent phrases:
#  federal government - 90 | president federal government - 3 | fema federal government - 2 | federal government fix terrible problem dems cause homeless horrendous effect city mess - 2 | blame federal government - 1 | military display great job federal government - 1 | nancy pelosis district san francisco horrible shape city violation sanitary amp environmental order cause owe federal government billion dollar work impeachment - 1 | open state president united state amp federal government - 1 | owe federal government billion dollar - 1 | power federal government - 1
#
# entity:
#  fight
#
# most frequent phrases:
#  fight - 45 | angry - 29 | war - 29 | racist - 27 | siege - 13 | coup - 11 | battle - 10 | protest - 8 | hostile - 7 | violence - 7
#
# entity:
#  fine
#
# most frequent phrases:
#  fine - 23 | beautiful - 20 | beautiful thing - 16 | art - 16 | piece - 14 | art deal - 12 | rich - 11 | soul - 9 | favorite president - 9 | favorite - 9
#
# entity:
#  flag
#
# most frequent phrases:
#  flag - 15 | hair - 11 | blue monster - 10 | mask - 10 | black community - 8 | signature - 8 | wig - 7 | hat - 6 | red hand - 6 | red line - 5
#
# entity:
#  florida
#
# most frequent phrases:
#  florida - 44 | florida power amp light - 3 | word june th tuesday announcement orlando florida request seat arena - 2 | brenda snipe charge voting broward county florida - 2 | florida highway patrol trooper - 2 | florida amp - 2 | people florida - 2 | florida shooter - 2 | florida venezuela - 2 | june th tuesday announcement orlando florida - 2
#
# entity:
#  fox
#
# most frequent phrases:
#  fox - 32 | fox amp friend - 27 | fox friend - 10 | fox news - 5 | new fox poll - 4 | fox amp friend foxandfriends - 2 | red tiger silver fox amp golden palm - 2 | fox board member paul ryan - 2 | vicente fox - 2 | fox poll - 2
#
# entity:
#  foxnews
#
# most frequent phrases:
#  foxnews - 134 | foxnews interview gretawire - 7 | foxnews poll - 6 | foxnews interview teamcavuto - 5 | foxnews interview - 3 | amaze watch foxnews - 2 | foxnews cable rating fair great favorite president - 2 | megynkelly overrate anchor foxnews - 2 | live foxnews - 2 | lamestream medium include foxnews checked - 2
#
# entity:
#  france
#
# most frequent phrases:
#  france - 13 | people france - 3 | great leader france - 2 | britain france germany european ally - 2 | president emmanuelmacron france - 2 | president macron france - 2 | president france emmanuelmacron wife brigitte - 1 | invite melania historic celebration france - 1 | italy france amp spain - 1 | lengthy discussion morning president macron france - 1
#
# entity:
#  fraud
#
# most frequent phrases:
#  fraud - 46 | impeachment hoax - 37 | hoax - 28 | scam - 26 | fake - 25 | false - 13 | total fraud - 10 | total hoax - 9 | impeachment scam - 8 | rumor - 7
#
# entity:
#  georgia
#
# most frequent phrases:
#  georgia - 24 | people georgia - 3 | incredible people georgia - 3 | governor briankempga hapless governor georgia - 3 | right great people georgia amp usa - 3 | governor georgia secretary state - 3 | great state georgia - 3 | florida georgia - 2 | georgia usa - 2 | governor briankempga georgia - 2
#
# entity:
#  global warm
#
# most frequent phrases:
#  global warm - 46 | wind turbine - 32 | hurricane - 20 | ice - 19 | climate change - 18 | storm - 15 | light - 15 | cool - 14 | cold - 11 | weather - 9
#
# entity:
#  god
#
# most frequent phrases:
#  god - 98 | thought prayer - 38 | prayer - 15 | luther strange - 12 | follower - 11 | bible - 8 | church - 7 | religious liberty - 7 | radical islam - 6 | religion - 6
#
# entity:
#  golf
#
# most frequent phrases:
#  golf - 50 | event - 35 | open - 29 | gold - 20 | champion - 14 | true champion - 10 | competition - 9 | olympics - 9 | wwe hall fame - 8 | elite - 8
#
# entity:
#  gop
#
# most frequent phrases:
#  gop - 52 | gop congress - 6 | house gop - 5 | gop candidate - 3 | gop establishment - 3 | gop nomination - 3 | gop field - 2 | gop nominee - 2 | karl rove amp gop establishment - 2 | nc gop - 2
#
# entity:
#  government
#
# most frequent phrases:
#  government - 98 | law - 87 | public - 53 | control - 43 | act - 42 | law enforcement - 25 | national security - 21 | special - 18 | security - 18 | criminal justice reform - 15
#
# entity:
#  great
#
# most frequent phrases:
#  america great - 529 | great - 429 | great job - 171 | great honor - 136 | great time - 42 | great people - 36 | great work - 36 | great country - 30 | great thing - 25 | great guy - 23
#
# entity:
#  healthcare
#
# most frequent phrases:
#  healthcare - 43 | healthcare plan - 22 | great healthcare - 11 | billion dollar left new infrastructure healthcare - 3 | healthcare american - 3 | totally engage healthcare - 3 | healthcare cost - 2 | truly great healthcare - 2 | important healthcare - 2 | great new healthcare program - 2
#
# entity:
#  hell
#
# most frequent phrases:
#  hell - 56 | crowd - 44 | big crowd - 25 | lucky - 22 | watch - 21 | wild - 20 | dream - 17 | kid - 17 | touch - 12 | steal election - 12
#
# entity:
#  hillary
#
# most frequent phrases:
#  hillary - 150 | hillary dems - 4 | hillary year - 2 | incompetent hillary - 2 | lyin hillary - 2 | maggie haberman hillary flunky - 2 | hillary people - 2 | hillary amp msm - 2 | wo nt beat hillary - 2 | hillary presidency - 2
#
# entity:
#  honor
#
# most frequent phrases:
#  honor - 55 | ovation - 13 | vacation - 9 | tribute - 9 | dinner - 8 | birthday - 8 | national anthem - 7 | happy birthday - 6 | holiday - 5 | keynote address - 5
#
# entity:
#  house
#
# most frequent phrases:
#  white house - 94 | house - 71 | house republican - 22 | house democrat - 13 | democrat house - 10 | house representative - 9 | white house press conference - 8 | house intelligence committee - 8 | house senate - 7 | maga night white house - 6
#
# entity:
#  ill
#
# most frequent phrases:
#  ill - 40 | drug - 30 | ebola - 29 | vaccine - 28 | heart - 23 | virus - 19 | animal - 12 | patient - 11 | plague - 9 | sick - 8
#
# entity:
#  illegal immigrant
#
# most frequent phrases:
#  illegal immigrant - 46 | illegal immigration - 41 | illegals - 32 | amnesty - 21 | illegal - 13 | illegal alien - 11 | immigration - 11 | immigration law - 11 | weak illegal immigration - 9 | criminal alien - 6
#
# entity:
#  iowa
#
# most frequent phrases:
#  iowa - 44 | people iowa - 4 | iowa poll - 3 | council bluff iowa - 2 | tremendous advocate people iowa - 2 | amaze root family join iowa - 2 | friend iowa - 2 | number iowa - 2 | iowa vote count - 2 | new iowa poll - 1
#
# entity:
#  iran
#
# most frequent phrases:
#  iran - 182 | iran deal - 10 | deal iran - 6 | sanction iran - 5 | iran nuclear program - 3 | iran nuclear drive - 3 | attack iran - 3 | china iran amp foreign country - 2 | china russia iran - 2 | obama appointee responsible load airplane billion dollar cash amp send iran horrific iran nuclear deal terminate approve little bob corker - 2
#
# entity:
#  iraq
#
# most frequent phrases:
#  iraq - 58 | iraq war - 7 | people iraq - 4 | disastrous iraq war - 2 | iraq weapon mass destruction - 2 | oil iraq - 2 | iraq libya - 2 | new leader iraq - 2 | mommy brother quicksand iraq - 2 | isi iraq - 2
#
# entity:
#  isi
#
# most frequent phrases:
#  isi - 95 | isi fighter - 9 | isi caliphate - 6 | fight isi - 5 | isi prisoner - 4 | isi video - 3 | politician like cruz graham watch isi problem develop year - 2 | estimate isi fighter - 2 | enemy isi - 2 | leader isi - 2
#
# entity:
#  israel
#
# most frequent phrases:
#  israel - 60 | friend israel - 3 | action israel - 2 | time officially recognize jerusalem capital israel - 2 | leader israel united arab emirate andthe kingdom ofbahrain - 2 | obamas steady support israel crisis - 2 | israel jewish people - 2 | people support israel - 2 | israel feel abandon - 2 | concerned contain israel - 2
#
# entity:
#  james comey
#
# most frequent phrases:
#  james comey - 30 | kevin - 15 | michael - 15 | sean - 12 | paul ryan - 10 | general flynn - 10 | tom brady - 9 | john brennan - 8 | andrew mccabe - 8 | ed gillespie - 7
#
# entity:
#  japan
#
# most frequent phrases:
#  japan - 21 | prime minister abe japan - 8 | prime minister abeshinzo japan - 5 | deal big nation japan hit hard trade year - 2 | masa softbank japan - 2 | japan currency manipulation - 2 | honor behalf united state majesty emperor japan - 2 | great trade deal china mexico canada japan south korea - 2 | friend prime minister abeshinzo japan - 2 | majesty emperor japan - 2
#
# entity:
#  jeb
#
# most frequent phrases:
#  jeb - 39 | mitt romney - 35 | pelosi - 30 | mitt - 30 | romney - 28 | senator - 27 | john mccain - 25 | john kasich - 20 | kasich - 19 | governor cuomo - 16
#
# entity:
#  job
#
# most frequent phrases:
#  job - 463 | bad - 255 | good - 244 | way - 157 | big - 112 | smart - 104 | tough - 81 | like - 70 | guy - 68 | fun - 57
#
# entity:
#  joe
#
# most frequent phrases:
#  joe biden - 134 | sleepy joe - 66 | sleepy joe biden - 60 | joe - 46 | corrupt joe biden - 9 | joe hiden - 8 | joe biden democrat socialist - 8 | joe scarborough - 4 | real power joe - 4 | joe bidens - 3
#
# entity:
#  john
#
# most frequent phrases:
#  john - 50 | david - 17 | george - 17 | elizabeth warren - 16 | scott - 15 | ben carson - 14 | justice robert - 11 | ronald reagan - 9 | henry - 8 | christopher steele - 8
#
# entity:
#  john bolton
#
# most frequent phrases:
#  john bolton - 11 | tate - 8 | rand paul - 8 | goofy elizabeth warren refer pocahontas - 7 | elizabeth warren refer pocahontas - 7 | bolton - 7 | hurricane dorian - 7 | woodward book - 6 | elizabeth pocahontas warren - 6 | harley davidson - 6
#
# entity:
#  kim jong un
#
# most frequent phrases:
#  kim jong un - 35 | putin - 33 | un - 16 | official - 15 | european union - 12 | eu - 12 | ukrainian president - 11 | summit - 10 | union - 10 | foreign country - 9
#
# entity:
#  kurd
#
# most frequent phrases:
#  kurd - 26 | saudi arabia - 21 | iranian - 15 | egypt - 14 | benghazi - 14 | libya - 13 | embassy - 12 | arab league - 9 | assad - 8 | jerusalem - 6
#
# entity:
#  leader
#
# most frequent phrases:
#  leader - 73 | support - 66 | party - 55 | radical left - 51 | power - 45 | leadership - 43 | mainstream medium - 34 | movement - 34 | politics - 29 | ally - 16
#
# entity:
#  life
#
# most frequent phrases:
#  life - 126 | family - 90 | woman - 78 | friend - 63 | child - 44 | love - 37 | husband - 25 | wife - 22 | father - 22 | son - 20
#
# entity:
#  louisiana
#
# most frequent phrases:
#  louisiana - 11 | great people texas louisiana arkansas - 2 | rep steve scalise louisiana true friend patriot - 2 | louisiana republican - 2 | louisiana economy second amendment right - 2 | baton rouge louisiana - 2 | cameron lng export facility louisiana - 1 | louisiana night north carolina - 1 | state amp local leader assist great people alabama louisiana mississippi - 1 | senator represent louisiana - 1
#
# entity:
#  man
#
# most frequent phrases:
#  man - 82 | dead - 59 | gun - 49 | police - 45 | caught - 42 | fire - 40 | soldier - 37 | attack - 24 | death - 18 | victim - 14
#
# entity:
#  medicare
#
# most frequent phrases:
#  medicare - 14 | fema - 14 | taxpayer - 9 | loophole - 8 | donor - 7 | cbo - 7 | fema responder - 6 | super pac - 6 | audit - 5 | unlimited - 4
#
# entity:
#  medium
#
# most frequent phrases:
#  medium - 198 | tea party - 17 | nut - 14 | fake medium - 10 | bad food restaurant - 8 | food - 8 | lunch - 6 | wine - 5 | deal preferably big deal - 4 | pan flight - 4
#
# entity:
#  melania
#
# most frequent phrases:
#  melania - 78 | flotus melania - 27 | wife melania - 8 | gq model photo post melania - 3 | melania trump - 3 | beautiful wife melania - 2 | wife melania trump - 2 | forensic analysis melania speech - 2 | lady melania - 2 | ready land japan lady melania - 1
#
# entity:
#  mess
#
# most frequent phrases:
#  mess - 51 | water - 24 | fix - 15 | garbage - 11 | total mess - 8 | drain swamp - 8 | dirty work - 8 | carbon footprint - 7 | total waste time - 7 | dirt - 6
#
# entity:
#  mexico
#
# most frequent phrases:
#  mexico - 157 | new mexico - 3 | deal mexico - 3 | mexico massive crime problem - 2 | sign agreement mexico - 2 | mexico police military - 2 | big deal mexico - 2 | murder case mexico - 2 | new trade deal mexico - 2 | people country include mexico - 2
#
# entity:
#  miami
#
# most frequent phrases:
#  miami - 7 | trump national doral miami - 5 | doral miami - 3 | beautiful acre center miami - 2 | miami heat - 2 | great miami area numerous - 2 | miami trump national doral - 2 | flgovscott game miami - 2 | million rebuild doral miami - 1 | miami doral - 1
#
# entity:
#  michigan
#
# most frequent phrases:
#  michigan - 34 | great state michigan - 6 | people michigan - 5 | democrat trump hater secretary state michigan - 3 | great people michigan - 3 | hold funding michigan want voter fraud path - 3 | grand rapid michigan - 3 | funding michigan - 3 | governor michigan - 3 | new plant built michigan plus - 2
#
# entity:
#  military
#
# most frequent phrases:
#  military - 109 | enemy - 54 | troop - 43 | military vet - 41 | national guard - 33 | enemy people - 24 | marine - 18 | plane - 17 | military amp vet - 17 | air force - 16
#
# entity:
#  million
#
# most frequent phrases:
#  million - 79 | billion dollar - 67 | billion - 59 | million people - 50 | debt - 46 | dollar - 32 | million dollar - 19 | billion dollar year - 16 | worth - 14 | trillion dollar - 14
#
# entity:
#  minnesota
#
# most frequent phrases:
#  minnesota - 10 | great state minnesota - 4 | people minnesota - 4 | congress minnesota - 3 | country great state minnesota - 3 | vote minnesota - 3 | minnesota michigan - 2 | opening mining lead best employment amp economic year minnesota long beautiful history - 2 | incredible senator state minnesota - 2 | incredible advocate minnesota - 2
#
# entity:
#  mittromney
#
# most frequent phrases:
#  mittromney - 136 | fail presidential candidate mittromney - 3 | elect mittromney november - 2 | concerned actually passing budget spread lie mittromney tax - 2 | know mittromney - 2 | know mittromney way know - 2 | presidential candidate mittromney - 2 | nasty mittromney - 2 | mittromney vp - 2 | endorsement mittromney - 2
#
# entity:
#  money
#
# most frequent phrases:
#  money - 285 | payment - 14 | offer - 14 | premium - 13 | wage - 13 | paid - 11 | cost - 11 | pay - 10 | option - 8 | benefit - 7
#
# entity:
#  mueller
#
# most frequent phrases:
#  mueller - 47 | mueller report - 38 | robert mueller - 26 | bob mueller - 26 | mueller investigation - 9 | mueller witch hunt - 8 | mueller angry democrat - 4 | mueller scam - 4 | mueller team - 3 | highly conflict robert mueller - 3
#
# entity:
#  nancy pelosi
#
# most frequent phrases:
#  nancy pelosi - 78 | nervous nancy pelosi - 13 | crazy nancy pelosi - 12 | nancy pelosi chuck schumer - 7 | nancy pelosi democrat - 6 | nancy pelosi dems - 5 | nancy pelosi lose house amp speakership amp lose - 4 | american fraud puppet crazy nancy pelosi - 4 | hard sell nancy pelosi - 2 | nancy pelosi chuck schumer democrat john bel edward - 2
#
# entity:
#  nation
#
# most frequent phrases:
#  nation - 95 | europe - 32 | germany - 31 | south korea - 21 | united - 17 | middle east - 14 | uk - 14 | india - 10 | flight west africa - 9 | atlantic city - 9
#
# entity:
#  nato
#
# most frequent phrases:
#  nato - 21 | nato country - 7 | country nato expect defend - 2 | nato commander - 2 | nato china russia japan entire world - 2 | nato spending - 2 | germany rich nato nation pay protection russia - 2 | great meeting nato - 2 | nato trade - 2 | pay fair share nato - 2
#
# entity:
#  nbc
#
# most frequent phrases:
#  nbc - 27 | nbc news - 5 | uncomfortable look nbc reporter willie geist - 3 | comcast nbc - 2 | today bias nbc - 2 | folk nbc - 2 | executive nbc amp comcast - 2 | control boss nbc amp comcast - 2 | new nbc poll - 2 | bad rating nbc - 2
#
# entity:
#  negative
#
# most frequent phrases:
#  negative - 16 | positive - 14 | publicity - 9 | negative ad - 9 | effect - 7 | positive think - 6 | big impact - 5 | impact - 5 | big factor - 4 | outcome election - 3
#
# entity:
#  nevada
#
# most frequent phrases:
#  nevada - 20 | governor nevada - 3 | people nevada - 2 | incredible congressman nevada - 2 | la vega nevada - 2 | nevada clubhouse governor - 1 | thousand noncitizen vote nevada - 1 | state nevada - 1 | reno nevada - 1 | nia sanchez nevada - 1
#
# entity:
#  new hampshire
#
# most frequent phrases:
#  new hampshire - 32 | big political rally new hampshire history - 2 | new hampshire primary vote incumbent president party history great state - 2 | people new hampshire - 2 | ad new hampshire - 1 | register new hampshire amp - 1 | new hampshire poll - 1 | new hampshire republican party - 1 | new hampshire tomorrow - 1 | portsmouth new hampshire rally - 1
#
# entity:
#  new york
#
# most frequent phrases:
#  new york - 55 | fail new york time - 30 | new york time - 24 | new york fine - 12 | new york city - 10 | upstate new york - 3 | governor andrew cuomo new york - 3 | frumpy dumb gail collins editorial writer new york time - 2 | cuomo new york - 2 | new york time rate reporter maggie haberman know crooked flunkie nt speak - 2
#
# entity:
#  north carolina
#
# most frequent phrases:
#  north carolina - 29 | governor north carolina roycoopernc - 3 | north carolina emergency declaration - 2 | beautiful north carolina - 2 | republican win north carolina - 1 | north carolina solid mittromney - 1 | north carolina thousand loyal hardworking american patriot - 1 | north carolina tomorrow night - 1 | north carolina way - 1 | people north carolina - 1
#
# entity:
#  north korea
#
# most frequent phrases:
#  north korea - 95 | kim jong un north korea - 5 | deal north korea - 4 | north korea leader - 3 | chairman kim north korea - 3 | want north korea - 2 | war north korea - 2 | sooo north korea met - 2 | president obama north korea war million people kill - 2 | north korea progress - 2
#
# entity:
#  november
#
# most frequent phrases:
#  november - 5 | win november - 4 | date - 4 | officially open - 3 | march th - 3 | june th - 2 | extend best wish hater loser special date september th - 2 | december th - 2 | date news - 2 | course best month june history - 2
#
# entity:
#  nyc
#
# most frequent phrases:
#  nyc - 26 | private lunch eric trump amp tour campaign hq trump tower nyc - 6 | nyc politician - 4 | nyc safe - 3 | hospital nyc - 2 | nyc cop - 2 | nyc terrorist - 2 | express warm regard best wish condolence family victim horrible bombing nyc - 2 | atrium nyc landmark - 1 | pander nyc politician - 1
#
# entity:
#  nytimes
#
# most frequent phrases:
#  nytimes - 86 | vet - 46 | fail nytimes - 44 | nd amendment - 28 | wh - 23 | pres - 22 | pol - 21 | vp - 18 | govt - 17 | president xi - 15
#
# entity:
#  obama
#
# most frequent phrases:
#  obama - 699 | president obama - 194 | barack obama - 21 | obama care - 11 | democrat president obama - 5 | obama release birth certificate - 4 | obama campaign - 4 | obama democrat - 4 | obama wh - 4 | obama policy - 4
#
# entity:
#  obamacare
#
# most frequent phrases:
#  obamacare - 216 | obamacare website - 26 | obamacare disaster - 8 | obamacare premium - 7 | obamacare romneycare architect gruber - 3 | billion dollar obamacare website - 3 | decide vote obamacare - 3 | use obamacare - 3 | fail obamacare replacement approve - 2 | obamacare rollout - 2
#
# entity:
#  obstructionist
#
# most frequent phrases:
#  obstructionist - 12 | personable - 9 | luckier - 8 | complacent - 6 | legit - 5 | unwatchable - 5 | delusional - 5 | totally unhinged - 5 | disgraceful - 4 | abysmal - 4
#
# entity:
#  ohio
#
# most frequent phrases:
#  ohio - 32 | people ohio - 10 | troybalderson ohio - 3 | people dayton ohio - 2 | congressman tim ryan ohio - 2 | lordstown ohio plant - 2 | dayton ohio shooter - 2 | cincinnati ohio - 2 | toledo ohio - 2 | lordstown ohio best economy history - 2
#
# entity:
#  oil
#
# most frequent phrases:
#  oil - 62 | opec - 45 | gas price - 29 | energy - 25 | keystone pipeline - 11 | gas - 11 | barrel - 10 | crude - 10 | oil price - 9 | gallon gas - 8
#
# entity:
#  omarosa
#
# most frequent phrases:
#  omarosa - 33 | macys - 20 | usdot - 19 | fracking - 17 | potus - 15 | bidens - 13 | tpp - 10 | leaker - 8 | wsj - 8 | windfarms - 6
#
# entity:
#  pennsylvania
#
# most frequent phrases:
#  pennsylvania - 34 | people pennsylvania - 4 | miss pennsylvania - 3 | president stand america stand pennsylvania - 3 | old post office pennsylvania avenue - 3 | tremendous advocate pennsylvania - 2 | vibrant manufacturing area pennsylvania - 2 | president apologize america president stand america stand pennsylvania - 2 | small crowd hillary draw today pennsylvania - 2 | economic death sentence pennsylvania - 2
#
# entity:
#  people
#
# most frequent phrases:
#  people - 1266 | country - 912 | time - 201 | right - 183 | place - 180 | work - 146 | year - 101 | number - 94 | home - 58 | point - 52
#
# entity:
#  pocahontas
#
# most frequent phrases:
#  pocahontas - 26 | cryin chuck schumer - 17 | ronny - 13 | ig report - 12 | cryin chuck - 10 | obamas - 10 | james clapper - 9 | ig - 8 | paul manafort - 7 | rasmussen - 7
#
# entity:
#  politically correct
#
# most frequent phrases:
#  politically correct - 26 | unfair - 12 | irrelevant - 9 | incorrect - 9 | inaccurate - 8 | totally - 5 | unnecessary negative detrimental - 4 | obsolete - 4 | wasteful - 4 | unacceptable - 4
#
# entity:
#  politician
#
# most frequent phrases:
#  politician - 77 | entrepreneur - 55 | supporter - 35 | billionaire - 26 | corrupt politician - 19 | expert - 13 | critic - 10 | writer - 9 | lobbyist - 9 | author - 8
#
# entity:
#  president
#
# most frequent phrases:
#  president - 511 | office - 88 | head - 19 | chairman kim - 17 | member - 15 | general - 12 | executive order - 11 | special council - 11 | staff - 10 | committee - 10
#
# entity:
#  press
#
# most frequent phrases:
#  press - 66 | report - 46 | news - 35 | reporter - 32 | interview - 23 | article - 22 | paper - 20 | magazine - 19 | ap - 13 | newspaper - 12
#
# entity:
#  problem
#
# most frequent phrases:
#  problem - 153 | possible - 77 | result - 59 | trouble - 25 | risk - 24 | failure - 24 | pressure - 22 | big problem - 21 | situation - 21 | face - 17
#
# entity:
#  protester
#
# most frequent phrases:
#  protester - 24 | crooked - 19 | hater loser - 18 | moron - 16 | liar - 16 | anarchist - 15 | thug - 15 | lowlife - 14 | hello - 13 | hater - 11
#
# entity:
#  proud
#
# most frequent phrases:
#  proud - 75 | happy - 67 | ashamed - 35 | surprised - 14 | helpful - 13 | satisfied - 7 | disappointed - 7 | interested - 7 | greatly - 6 | new yorkers - 6
#
# entity:
#  question
#
# most frequent phrases:
#  question - 85 | debate - 84 | important - 60 | decision - 53 | change - 52 | focus - 43 | action - 39 | agenda - 33 | future - 27 | policy - 26
#
# entity:
#  record
#
# most frequent phrases:
#  record - 89 | rating - 68 | high - 57 | low - 47 | time high - 30 | zero - 25 | level - 17 | record high - 16 | standard - 12 | year low - 11
#
# entity:
#  republican
#
# most frequent phrases:
#  republican - 440 | republican senator - 36 | republican democrat - 23 | republican president - 9 | republican national convention - 6 | republican candidate - 6 | republican vote - 6 | republican convention - 5 | republican amp democrat - 5 | republican voter - 5
#
# entity:
#  republican party
#
# most frequent phrases:
#  republican party - 84 | republican party president - 3 | republican party fealty - 3 | absolutely impossible republican party convention - 3 | able mid term election hurt republican party - 2 | hurt republican party president - 2 | republican party unify - 2 | republican party track pick seat senate epic victory - 2 | republican party new york - 2 | republican party look bad - 2
#
# entity:
#  rod
#
# most frequent phrases:
#  rod - 49 | mike - 31 | tom - 28 | steve - 25 | matt - 22 | dan - 21 | jim - 19 | chris - 17 | lance armstrong - 17 | chris wallace - 16
#
# entity:
#  rosie
#
# most frequent phrases:
#  rosie - 30 | crazy nancy - 25 | nancy - 19 | greta - 15 | michelle - 9 | cindy - 8 | barbara - 7 | cher - 7 | carly fiorina - 7 | hurricane florence - 6
#
# entity:
#  russia
#
# most frequent phrases:
#  russia - 102 | collusion russia - 22 | russia hoax - 9 | president putin russia - 7 | russia russia russia - 7 | collusion trump campaign russia - 7 | china russia - 7 | russia china - 5 | agent russia - 4 | second investigation schumer pelosi close tie russia lie - 3
#
# entity:
#  russian
#
# most frequent phrases:
#  russian - 28 | russian collusion - 13 | russian meddling - 9 | russian operative - 4 | russian witch hunt hoax - 4 | russian meddling election - 3 | russian meddling time - 3 | russian witch hunt - 3 | russian hoax investigation - 2 | new russian strategy - 2
#
# entity:
#  safe
#
# most frequent phrases:
#  safe - 55 | ready - 39 | necessary - 28 | stop - 25 | soon - 22 | try - 20 | promise - 19 | prepared - 18 | able - 17 | hope - 17
#
# entity:
#  schiff
#
# most frequent phrases:
#  schiff - 32 | adam schiff - 27 | karl rove - 16 | mark levin - 15 | lightweight ag eric schneiderman - 11 | michael cohen - 10 | congressman adam schiff - 10 | jerry nadler - 9 | anthony weiner - 8 | rep adam schiff - 8
#
# entity:
#  school
#
# most frequent phrases:
#  school - 30 | award - 17 | outstanding job - 16 | achievement - 14 | program - 11 | merit - 10 | student - 8 | school choice - 8 | class - 7 | excellence - 6
#
# entity:
#  scotland
#
# most frequent phrases:
#  scotland - 26 | people scotland - 4 | trump intl golf link scotland - 3 | scotland course - 2 | windfarm approval scotland - 2 | fm alexsalmond scotland - 2 | scotland golf course aberdeen - 2 | ugly windfarms built scotland - 2 | turnberry scotland - 2 | aberdeen scotland - 1
#
# entity:
#  second amendment
#
# most frequent phrases:
#  second amendment - 57 | constitution - 27 | sanction - 21 | rule - 20 | quid pro quo - 16 | ban - 12 | rule law - 11 | waiver product - 8 | fisa court - 8 | repeal amp replace - 6
#
# entity:
#  senate
#
# most frequent phrases:
#  senate - 118 | republican senate - 11 | senate republican - 6 | democrat senate - 6 | senate democrat - 5 | majority republican senate - 3 | seat senate - 3 | trial senate - 3 | run majority republican senate - 3 | senate hearing - 3
#
# entity:
#  south carolina
#
# most frequent phrases:
#  south carolina - 21 | people south carolina - 9 | governor henrymcmaster south carolina - 3 | great state south carolina - 3 | columbia south carolina - 3 | great job governor south carolina - 2 | great south carolina - 2 | governor great state south carolina marksanford - 2 | support south carolina - 2 | representative katie arrington south carolina - 1
#
# entity:
#  state
#
# most frequent phrases:
#  united state - 203 | state - 166 | president united state - 22 | united state america - 19 | swing state - 12 | state department - 11 | secretary state - 8 | secretary state mike pompeo - 8 | great state - 7 | united state congress - 6
#
# entity:
#  stock market
#
# most frequent phrases:
#  stock market - 66 | interest - 52 | market - 49 | federal reserve - 48 | credit - 48 | bank - 37 | price - 28 | stock - 27 | drug price - 20 | property - 19
#
# entity:
#  story
#
# most frequent phrases:
#  story - 121 | book - 71 | picture - 23 | big picture - 19 | new book - 14 | write - 13 | real story - 11 | movie - 10 | big story - 9 | documentary - 7
#
# entity:
#  success
#
# most frequent phrases:
#  success - 73 | advantage - 57 | credibility - 39 | opportunity - 33 | talent - 21 | thanks - 13 | zero credibility - 12 | tremendous success - 10 | reputation - 9 | tremendous job - 8
#
# entity:
#  supreme court
#
# most frequent phrases:
#  supreme court - 44 | united state supreme court - 13 | great supreme court justice - 5 | supreme court justice - 4 | supreme court united state - 3 | excite monday supreme court oral argument decision - 2 | potential great supreme court justice - 2 | rinos stupid people nt want great judge amp supreme court justice new amp powerful military choice vet protection big regulationcuts life amp - 2 | justice supreme court - 2 | justice ginsburg supreme court - 2
#
# entity:
#  swamp
#
# most frequent phrases:
#  swamp - 34 | sanctuary city - 15 | keystone - 11 | plateau - 11 | pier - 11 | windmill - 8 | doral - 7 | palos - 5 | skyline - 5 | dune - 4
#
# entity:
#  syria
#
# most frequent phrases:
#  syria - 45 | attack syria - 6 | russia syria iran - 4 | people syria - 2 | terrorist syria - 2 | syria assad - 2 | involve syria - 2 | freedom fighter syria - 2 | isi fighter capture syria trial - 2 | syria chose help - 2
#
# entity:
#  system
#
# most frequent phrases:
#  information - 58 | system - 58 | source - 40 | test - 24 | involve - 23 | use - 22 | available - 19 | rig system - 11 | resource - 10 | big tech - 9
#
# entity:
#  tax
#
# most frequent phrases:
#  tax - 157 | tariff - 100 | care - 77 | plan - 48 | budget - 30 | tax cut - 22 | regulation - 16 | raise tax - 15 | legislation - 14 | big tax cut - 12
#
# entity:
#  team
#
# most frequent phrases:
#  team - 77 | game - 74 | yankee - 46 | player - 33 | fan - 31 | nfl - 22 | play - 22 | arena - 14 | field - 9 | season - 8
#
# entity:
#  ted cruz
#
# most frequent phrases:
#  ted cruz - 73 | lyin ted cruz - 16 | lie ted cruz lightweight choker marco rubio - 2 | lyin ted cruz kasich - 2 | senator ted cruz - 2 | anybody watch ted cruz far long ramble overly flamboyant speech nite - 1 | ted cruz far long ramble overly flamboyant speech - 1 | ted cruz forgot - 1 | ted cruz great people iowa vote - 1 | ted cruz john kasich - 1
#
# entity:
#  tenacious
#
# most frequent phrases:
#  tenacious - 15 | stubborn - 15 | honest - 12 | passionate - 9 | wise decision - 6 | brave soldier - 6 | brave men woman - 6 | brave responder - 5 | wise - 5 | courageous leader - 5
#
# entity:
#  terrible
#
# most frequent phrases:
#  terrible - 61 | terrible thing - 17 | consequence - 15 | terrible job - 10 | chaos - 8 | horrible thing - 8 | horrendous - 6 | tragedy - 6 | total meltdown - 5 | tragic - 5
#
# entity:
#  terrorist
#
# most frequent phrases:
#  terrorist - 37 | afghanistan - 15 | taliban - 15 | muslim brotherhood - 14 | terrorism - 12 | bin laden - 11 | islamist - 7 | pakistan - 7 | muslim - 7 | al qaeda - 5
#
# entity:
#  texas
#
# most frequent phrases:
#  texas - 28 | texas amp florida - 3 | church texas - 2 | highly respect congressman john ratcliffe texas - 2 | texas friend - 2 | people el paso texas - 2 | dallas texas - 2 | texas rep roger williams reprwilliams - 2 | today shoot el paso texas - 2 | people sutherland spring texas - 2
#
# entity:
#  thing
#
# most frequent phrases:
#  thing - 310 | wrong - 197 | everybody - 115 | happen - 105 | fact - 87 | person - 85 | true - 82 | truth - 76 | lie - 66 | mistake - 59
#
# entity:
#  transcript
#
# most frequent phrases:
#  transcript - 57 | statement - 55 | letter - 24 | copy - 20 | document - 20 | message - 19 | read - 17 | anonymous source - 16 | apology - 14 | note - 9
#
# entity:
#  trump
#
# most frequent phrases:
#  trump - 302 | president trump - 140 | trump campaign - 33 | trump tower - 14 | trump election poll watcher - 11 | mr trump - 11 | trump organization - 10 | trump national doral - 8 | trump signature collection exclusively available macys - 7 | trump intl golf link amp hotel ireland - 5
#
# entity:
#  turkey
#
# most frequent phrases:
#  turkey - 34 | local country include turkey - 3 | istanbul turkey - 2 | president rterdogan turkey - 2 | economy turkey - 2 | terror attack turkey switzerland germany - 1 | president turkey recep tayyip erdoan - 1 | relation turkey - 1 | result investigation saudi turkey - 1 | saudi turkey - 1
#
# entity:
#  tv
#
# most frequent phrases:
#  tv - 23 | network - 21 | video - 19 | reality - 19 | live - 18 | msnbc - 18 | miss universe pageant - 16 | cnbc - 15 | tonight - 14 | television - 13
#
# entity:
#  twitter
#
# most frequent phrases:
#  twitter - 54 | ad - 32 | google - 20 | tweet - 18 | server - 14 | politico - 13 | excite - 13 | amazon - 10 | website - 10 | facebook - 9
#
# entity:
#  ukraine
#
# most frequent phrases:
#  ukraine - 21 | president ukraine - 7 | ukraine hoax - 2 | totally phony conversation ukraine president president - 2 | president petro poroshenko ukraine - 2 | phone president ukraine include perfect - 2 | phone president ukraine - 2 | president amp foreign minister ukraine - 2 | conversation president ukraine - 2 | version conversation president ukraine nt exist - 2
#
# entity:
#  unemployment
#
# most frequent phrases:
#  unemployment - 33 | rate - 26 | gdp - 20 | unemployment rate - 11 | inflation - 11 | interest rate - 11 | unemployment number - 8 | rise - 7 | cent - 6 | percent - 6
#
# entity:
#  usa
#
# most frequent phrases:
#  usa - 147 | miss usa pageant - 16 | bad usa - 5 | right wonderful usa - 3 | reign miss universe miss usa - 2 | good usa - 2 | china usa - 2 | usa amp look bad possible - 2 | usa amp - 2 | induct tonight pm usa - 2
#
# entity:
#  ventilator
#
# most frequent phrases:
#  ventilator - 23 | dummy - 16 | achiever - 13 | tester - 10 | doj - 9 | responder - 7 | keystone xl pipeline - 7 | boardroom - 7 | firework - 6 | impeachable - 6
#
# entity:
#  virginia
#
# most frequent phrases:
#  virginia - 10 | west virginia - 7 | great people west virginia - 5 | great state virginia - 5 | governor virginia - 3 | people west virginia - 3 | republican party virginia - 3 | surprised amp disappointed senator joe manchin west virginia vote democrat totally partisan impeachment hoax - 2 | senator joe manchin west virginia - 2 | fighter virginia - 2
#
# entity:
#  vote
#
# most frequent phrases:
#  vote - 167 | poll - 102 | ballot - 58 | voter - 56 | poll number - 27 | early voting - 22 | count - 16 | absentee ballot - 16 | rig election - 13 | electoral college - 10
#
# entity:
#  wall
#
# most frequent phrases:
#  wall - 213 | hand - 23 | room - 13 | debt ceiling - 11 | camera - 10 | table - 10 | bust - 9 | broken - 9 | eye - 9 | ball - 7
#
# entity:
#  washington
#
# most frequent phrases:
#  washington - 72 | washington post - 19 | amazon washington post - 5 | like typical washington politician - 5 | fake washington post - 4 | washington redskin - 3 | washington dems - 3 | small group washington insider - 3 | story amazon washington post - 2 | washington swamp - 2
#
# entity:
#  whistleblower
#
# most frequent phrases:
#  whistleblower - 64 | spy - 29 | dossier - 19 | fake dossier - 15 | cia - 11 | investigator - 11 | scandal - 11 | intelligence - 10 | leak - 9 | secret service - 8
#
# entity:
#  whitehouse
#
# most frequent phrases:
#  whitehouse - 55 | whitehouse statedept - 2 | whitehouse infrastructure summit - 2 | announce final decision united state supreme court justice pme tomorrow night whitehouse - 1 | welcome president alsisiofficial arab republic egypt whitehouse - 1 | welcome prezydentpl andrzej duda poland whitehouse - 1 | welcome president republic kenya ukenyatta mr margaret kenyatta whitehouse today - 1 | welcome president petro poroshenko ukraine whitehouse today vp penny - 1 | welcome president nursultan nazarbayev kazakhstan whitehouse - 1 | welcome president moon jae republic korea whitehouse - 1
#
# entity:
#  win
#
# most frequent phrases:
#  win - 137 | winner - 68 | loser - 54 | race - 53 | opponent - 48 | chance - 38 | victory - 30 | goal - 23 | lead - 21 | challenge - 17
#
# entity:
#  wisconsin
#
# most frequent phrases:
#  wisconsin - 27 | deep root wisconsin - 4 | great advocate incredible people wisconsin wi - 4 | kenosha wisconsin - 4 | great state wisconsin - 4 | people wisconsin - 2 | republican wisconsin - 2 | entire state wisconsin proud - 2 | milwaukee wisconsin - 2 | national guard activate kenosha wisconsin - 2
#
# entity:
#  witch hunt
#
# most frequent phrases:
#  witch hunt - 91 | rig witch hunt - 12 | phony witch hunt - 9 | witch hunt hoax - 5 | leak polling campaign way despite phony end witch hunt best number - 4 | illegal witch hunt - 3 | rig russia witch hunt - 3 | russia witch hunt - 3 | witch hunt alive - 2 | heard begin witch hunt hoax - 2
#
# entity:
#  word
#
# most frequent phrases:
#  word - 83 | different - 16 | example - 13 | big difference - 12 | certain people - 11 | simple - 10 | difference - 10 | common core - 8 | individual - 8 | exist - 7
#
# entity:
#  world
#
# most frequent phrases:
#  world - 133 | country world - 13 | rest world - 9 | great golf course world - 9 | best world - 6 | envy world - 6 | world cup - 6 | world war - 5 | world richest country - 4 | honor fire jim mattis world overrate general - 4

# %%
# Low-dimensional vs. high-dimensional narrative statements

# Replace negated verbs by "not-verb"

import numpy as np

final_statements['B-V_lowdim_with_neg'] = np.where(final_statements['B-ARGM-NEG_lowdim'] == True, 
                                          'not-' + final_statements['B-V_lowdim'], 
                                          final_statements['B-V_lowdim'])

final_statements['B-V_highdim_with_neg'] = np.where(final_statements['B-ARGM-NEG_highdim'] == True, 
                                           'not-' + final_statements['B-V_lowdim'], 
                                           final_statements['B-V_highdim'])

# Concatenate high-dimensional narratives (with text preprocessing but no clustering)

final_statements['narrative_highdim'] = (final_statements['ARG0_highdim'] + ' ' + 
                                         final_statements['B-V_highdim_with_neg'] + ' ' +  
                                         final_statements['ARG1_highdim'])

# Concatenate low-dimensional narratives (with clustering)

final_statements['narrative_lowdim'] = (final_statements['ARG0_lowdim'] + ' ' + 
                                        final_statements['B-V_highdim_with_neg'] + ' ' + 
                                        final_statements['ARG1_lowdim'])

# Focus on narratives with a ARG0-VERB-ARG1 structure (i.e. "complete narratives")

indexNames = final_statements[(final_statements['ARG0_lowdim'] == '')|
                             (final_statements['ARG1_lowdim'] == '')|
                             (final_statements['B-V_lowdim_with_neg'] == '')].index

complete_narratives = final_statements.drop(indexNames)

complete_narratives
# Out:
#                         doc  sentence  statement  \
# 1         98454970654916608         0          1
# 6       1234653427789070336         1          6
# 7       1234653427789070336         1          7
# 8       1234653427789070336         1          8
# 13      1304875170860015617         4         13
# ...                     ...       ...        ...
# 150179  1213149809378578432     68602     150179
# 150193  1213078681750573056     68606     150193
# 150194  1213078681750573056     68606     150194
# 150209  1319384118849949702     68612     150209
# 150211  1319345719829008387     68614     150211
#
#                         ARG0_highdim ARG0_lowdim B-V_highdim B-V_lowdim  \
# 1                republican democrat  republican      create     create
# 6       hardworking american patriot    american        love       know
# 7       hardworking american patriot    american     cherish    cherish
# 8       hardworking american patriot    american     respect      honor
# 13                   recent election         day         use        use
# ...                              ...         ...         ...        ...
# 150179                        motion        case     dismiss       fire
# 150193                          iran        iran         won       lose
# 150194                          iran        iran        lose        win
# 150209                   obama biden       biden        fail       fail
# 150211                suburban woman        city        want       want
#
#        B-ARGM-NEG_highdim B-ARGM-NEG_lowdim B-ARGM-MOD_highdim  \
# 1
# 6
# 7
# 8
# 13
# ...                   ...               ...                ...
# 150179
# 150193               True
# 150194               True
# 150209
# 150211
#
#                ARG1_highdim   ARG1_lowdim ARG2_highdim ARG2_lowdim  \
# 1          economic problem       economy
# 6                   country        people
# 7                     value  stock market
# 8                       law    government
# 13                   system        system
# ...                     ...           ...          ...         ...
# 150179    impeachment trial          case
# 150193                  war         fight
# 150194          negotiation          deal
# 150209        worker delphi      bankrupt
# 150211  safety amp security    government
#
#        B-V_lowdim_with_neg B-V_highdim_with_neg  \
# 1                   create               create
# 6                     know                 love
# 7                  cherish              cherish
# 8                    honor              respect
# 13                     use                  use
# ...                    ...                  ...
# 150179                fire              dismiss
# 150193                lose             not-lose
# 150194                 win              not-win
# 150209                fail                 fail
# 150211                want                 want
#
#                                   narrative_highdim  \
# 1       republican democrat create economic problem
# 6         hardworking american patriot love country
# 7        hardworking american patriot cherish value
# 8          hardworking american patriot respect law
# 13                       recent election use system
# ...                                             ...
# 150179             motion dismiss impeachment trial
# 150193                            iran not-lose war
# 150194                     iran not-win negotiation
# 150209               obama biden fail worker delphi
# 150211      suburban woman want safety amp security
#
#                      narrative_lowdim
# 1           republican create economy
# 6                american love people
# 7       american cherish stock market
# 8         american respect government
# 13                     day use system
# ...                               ...
# 150179              case dismiss case
# 150193            iran not-lose fight
# 150194              iran not-win deal
# 150209            biden fail bankrupt
# 150211           city want government
#
# [11940 rows x 18 columns]

# %%
# Top high-dimensional complete narrative statements

complete_narratives['narrative_highdim'].value_counts().head(10)
# Out:
# god bless usa                                  13
# think small negate lot                          9
# establishment special interest kill country     8
# thing look good                                 7
# democrat want open border                       6
# stock market hit time high                      6
# success breed success                           6
# china steal job                                 6
# biden raise tax                                 6
# successful require concentrate effort           5
# Name: narrative_highdim, dtype: int64

# %%
# Top low-dimensional complete narrative statements

complete_narratives['narrative_lowdim'].value_counts().head(10)
# Out:
# stock market hit record         17
# democrat want border            16
# god bless usa                   13
# thing look job                   9
# people negate job                9
# crooked hillary delete email     8
# community kill people            8
# biden raise tax                  6
# success breed success            6
# china steal job                  6
# Name: narrative_lowdim, dtype: int64

# %%
# Print ten random complete narratives with and without dimension reduction
#
# Specifying a small number of clusters leads to a large dimension reduction 
# and may decrease cluster coherence, whilst specifying a large number of clusters
# may produce cluster redundancy. 
#
# The choice of the number of clusters is corpus and application specific 
# (and was chosen at random in this notebook).

sample = complete_narratives.sample(10, random_state = 123).to_dict('records')

for d in sample:
    print('Original raw tweet: \n %s \n' %split_sentences[1][d['sentence']])
    print('High-dimensional narrative: \n %s \n' %d['narrative_highdim'])
    print('Low-dimensional narrative: \n %s \n' %d['narrative_lowdim'])
    print('--------------------------------------------------- \n')
# Out:
# Original raw tweet:
#  After Solyndra, BarackObama is stil intent on wasting our tax dollars on unproven technologies and risky companies.
#
# High-dimensional narrative:
#  barackobama waste tax dollar unproven technology risky company
#
# Low-dimensional narrative:
#  barackobama waste politically correct
#
# ---------------------------------------------------
#
# Original raw tweet:
#  Both Senators became totally unelectable, couldnt come even close to winning their primaries, and decided to drop out of politics and gracefully RETIRE.
#
# High-dimensional narrative:
#  senator decide drop politics gracefully retire
#
# Low-dimensional narrative:
#  jeb decide ventilator
#
# ---------------------------------------------------
#
# Original raw tweet:
#  The Republicans never should have agreed to this past summer's debt deal.
#
# High-dimensional narrative:
#  republican not-disagree past summer debt deal
#
# Low-dimensional narrative:
#  republican not-disagree people
#
# ---------------------------------------------------
#
# Original raw tweet:
#  Sebelius is trying to force private companies to finance implementation
#
# High-dimensional narrative:
#  sebelius force private company
#
# Low-dimensional narrative:
#  jeb force business
#
# ---------------------------------------------------
#
# Original raw tweet:
#  Businesses have already started massive layoffs and reducing employees hours due to Obama Care.
#
# High-dimensional narrative:
#  business start massive layoff
#
# Low-dimensional narrative:
#  business start ventilator
#
# ---------------------------------------------------
#
# Original raw tweet:
#  Funny to watch the Democrats criticize Trade Deals being negotiated by me when they dont even know what the deals are and when for 8 years the Obama Administration did NOTHING on trade except let other countries rip off the United States.
#
# High-dimensional narrative:
#  democrat criticize trade deal negotiate
#
# Low-dimensional narrative:
#  democrat criticize deal
#
# ---------------------------------------------------
#
# Original raw tweet:
#  Just landed - a long trip, but everybody can now feel much safer than the day I took office.
#
# High-dimensional narrative:
#  everybody feel safer day office
#
# Low-dimensional narrative:
#  thing feel alternative
#
# ---------------------------------------------------
#
# Original raw tweet:
#  The Federal Government provided tremendous help to the Great People of Michigan.
#
# High-dimensional narrative:
#  federal government provide tremendous help
#
# Low-dimensional narrative:
#  federal government provide success
#
# ---------------------------------------------------
#
# Original raw tweet:
#  Didnt Obama, whose Administration has now been caught cold illegally spying on the Trump campaign, recently also get caught playing golf on a course in Virginia, despite his wife Michelle urging people to stay home, before and after his round, in a major public service message?
#
# High-dimensional narrative:
#  wife michelle urge people
#
# Low-dimensional narrative:
#  rosie urge people
#
# ---------------------------------------------------
#
# Original raw tweet:
#  Trump vows to fight 'epidemic' of human trafficking
#
# High-dimensional narrative:
#  trump fight epidemic human traffic
#
# Low-dimensional narrative:
#  trump fight ill
#
# ---------------------------------------------------

# %% [markdown]
# ## Step 6: Visualization // Plotting narrative graphs
# ----------------------------
#
# A collection of narrative statements has an intuitive network structure, in which the edges are verbs and the nodes are entities.
#
# Here, we plot Trump's narrative statements on Twitter.
#
# ----------------------------

# %%
# Plot low-dimensional complete narrative statements in a directed multi-graph

from relatio.graphs import build_graph, draw_graph

temp = complete_narratives[["ARG0_lowdim", "ARG1_lowdim", "B-V_lowdim"]]
temp.columns = ["ARG0", "ARG1", "B-V"]
temp = temp[(temp["ARG0"] != "") & (temp["ARG1"] != "") & (temp["B-V"] != "")]
temp = temp.groupby(["ARG0", "ARG1", "B-V"]).size().reset_index(name="weight")
temp = temp.sort_values(by="weight", ascending=False).iloc[
    0:100
]  # pick top 100 most frequent narratives
temp = temp.to_dict(orient="records")

for l in temp:
    l["color"] = None

G = build_graph(
    dict_edges=temp, dict_args={}, edge_size=None, node_size=10, prune_network=True
)

draw_graph(G, notebook=True, output_filename="trump_worldview.html")
# Out:
#         <iframe
#             width="1000px"
#             height="1000px"
#             src="trump_worldview.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# As a final comment, note that you can look up the specifics of any function with the help command.

help(build_narrative_model)
# Out:
# Help on function build_narrative_model in module relatio.wrappers:
#
# build_narrative_model(srl_res: List[dict], sentences: List[str], roles_considered: List[str] = ['ARG0', 'B-V', 'B-ARGM-NEG', 'B-ARGM-MOD', 'ARG1', 'ARG2'], output_path: Union[str, NoneType] = None, max_length: Union[int, NoneType] = None, remove_punctuation: bool = True, remove_digits: bool = True, remove_chars: str = '', stop_words: Union[List[str], NoneType] = None, lowercase: bool = True, strip: bool = True, remove_whitespaces: bool = True, lemmatize: bool = True, stem: bool = False, tags_to_keep: Union[List[str], NoneType] = None, remove_n_letter_words: Union[int, NoneType] = None, roles_with_embeddings: List[List[str]] = [['ARG0', 'ARG1', 'ARG2']], embeddings_type: Union[str, NoneType] = None, embeddings_path: Union[str, NoneType] = None, n_clusters: List[List[int]] = [[1]], verbose: int = 0, random_state: int = 0, roles_with_entities: List[str] = ['ARG0', 'ARG1', 'ARG2'], ent_labels: List[str] = ['PERSON', 'NORP', 'ORG', 'GPE', 'EVENT'], top_n_entities: Union[int, NoneType] = None, dimension_reduce_verbs: Union[bool, NoneType] = True, progress_bar: bool = False)
#     A wrapper function to build the narrative model from a sample of the corpus.
#
#     Args:
#         srl_res: sentences labeled with their semantic roles
#         sentences: list of sentences
#         roles_considered: list of semantic roles to consider
#         output_path: path to save the narrative model (default is None, which means no saving to disk)
#         preprocessing_options: see clean_text() function
#         roles_with_embeddings: list of lists of semantic roles to embed and cluster
#         (i.e. each list represents semantic roles that should be clustered together)
#         embeddings_type: whether the user wants to use USE / Keyed Vectors or a custom pre-trained Word2Vec
#         (e.g. "USE" / "gensim_keyed_vectors" / "gensim_full_model")
#         embeddings_path: path for the trained embeddings model
#         n_clusters: number of clusters for the clustering model
#         verbose: see sklearn.KMeans documentation for details
#         roles_with_entities: list of semantic roles with named entities
#         ent_labels: list of entity labels to be considered (see SPaCy documentation)
#         top_n_entities: number of named entities to keep (default is all and is specified with top_n = 0)
#         dimension_reduce_verbs: if True, verbs are replaced by their most frequent synonyms/antonyms
#         progress_bar: print a progress bar (default is False)
#
#     Returns:
#         A dictionary with the details of the pipeline to extract narratives from text

# %% [markdown]
# ## Miscellaneous
#
# ----------------------------
#
# For a detailed discussion of semantic role annotations, please refer to: [Speech and Language Processing. Daniel Jurafsky & James H. Martin (2019)](https://web.stanford.edu/~jurafsky/slp3/old_oct19/20.pdf)
#
# ----------------------------
#
# The package is still under development. We welcome comments, suggestions and bug reports:
# [File an issue](https://github.com/relatio-nlp/relatio/issues)
#
# ----------------------------
